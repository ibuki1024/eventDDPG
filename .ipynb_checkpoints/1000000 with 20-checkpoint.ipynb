# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Model
from keras.layers import concatenate, Dense, Input, Flatten
from keras.optimizers import *
import gym
from rl.agents import eventDDPGAgent
from rl.memory import SequentialMemory

# %%
# GymのPendulum環境を作成
env = gym.make("Pendulum-v0")

# 取りうる”打ち手”のアクション数と値の定義
nb_actions = 2
ACT_ID_TO_VALUE = {0: [-1], 1: [+1]}

# %%
def actor_net(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input)
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(3, activation="tanh")(x)
    actor = Model(inputs=action_input, outputs=x)
    return actor

def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

# %%
def agent(a_shape, s_shape):
    actor = actor_net(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = eventDDPGAgent(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        clip_com=0.01
    )
    return agent

# %%
#通信によるコストの強さを設定
l = 20
agent = agent((3,), env.observation_space.shape) #agent((actor output dim),(state_dim))
opt = 'adam'

if opt == 'adam':
    #adam optimizer
    agent.compile(Adam(lr=0.001, clipnorm=1., decay = 0), metrics=["mse"])
elif opt == 'adadelta':
    #adadelta optimizer
    agent.compile(Adadelta(), metrics=['mse'])
elif opt == 'adagrad':
    #adagrad optimizer
    agent.compile(Adagrad(), metrics=['mse'])
else:
    assert False

agent.fit(env, lam=l, nb_steps=1000000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
print('Finish Learning. We start test phase.')
#agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200)
# Out:
# Training for 1000000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -8.0129
# 50 episodes - episode_reward: -1602.587 [-3733.224, -953.718] - loss: 14.343 - mean_squared_error: 28.685 - mean_q: -32.056
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -8.5140
# 50 episodes - episode_reward: -1702.808 [-3270.786, -882.531] - loss: 22.119 - mean_squared_error: 44.239 - mean_q: -80.059
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: -6.8732
# 50 episodes - episode_reward: -1374.634 [-1808.075, -999.054] - loss: 49.210 - mean_squared_error: 98.420 - mean_q: -127.710
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -6.6349
# 50 episodes - episode_reward: -1326.977 [-1768.104, -967.903] - loss: 83.049 - mean_squared_error: 166.098 - mean_q: -168.658
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -6.6039
# 50 episodes - episode_reward: -1320.778 [-1726.737, -848.336] - loss: 106.083 - mean_squared_error: 212.165 - mean_q: -199.329
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 92s 9ms/step - reward: -6.7964
# 50 episodes - episode_reward: -1359.281 [-1728.554, -903.186] - loss: 129.081 - mean_squared_error: 258.162 - mean_q: -223.815
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -6.8665
# 50 episodes - episode_reward: -1373.300 [-1845.903, -901.777] - loss: 148.171 - mean_squared_error: 296.343 - mean_q: -239.420
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -6.3477
# 50 episodes - episode_reward: -1269.530 [-1835.425, -868.634] - loss: 166.656 - mean_squared_error: 333.312 - mean_q: -254.040
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -6.4076
# 50 episodes - episode_reward: -1281.526 [-1762.970, -749.608] - loss: 177.577 - mean_squared_error: 355.154 - mean_q: -267.204
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.4613
# 50 episodes - episode_reward: -1292.253 [-1755.126, -889.917] - loss: 201.495 - mean_squared_error: 402.989 - mean_q: -283.692
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.3442
# 50 episodes - episode_reward: -1268.845 [-1808.265, -763.411] - loss: 225.209 - mean_squared_error: 450.419 - mean_q: -300.066
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: -6.5949
# 50 episodes - episode_reward: -1318.990 [-1754.577, -746.366] - loss: 242.279 - mean_squared_error: 484.559 - mean_q: -314.345
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.2913
# 50 episodes - episode_reward: -1258.268 [-1778.932, -726.368] - loss: 262.168 - mean_squared_error: 524.335 - mean_q: -327.656
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.5476
# 50 episodes - episode_reward: -1309.528 [-1770.037, -739.390] - loss: 270.486 - mean_squared_error: 540.972 - mean_q: -339.952
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.5315
# 50 episodes - episode_reward: -1306.302 [-1837.597, -739.718] - loss: 293.417 - mean_squared_error: 586.834 - mean_q: -345.230
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.7584
# 50 episodes - episode_reward: -1351.679 [-1738.513, -1077.752] - loss: 307.139 - mean_squared_error: 614.278 - mean_q: -351.000
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.6231
# 50 episodes - episode_reward: -1324.611 [-1804.085, -876.849] - loss: 314.464 - mean_squared_error: 628.928 - mean_q: -357.561
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.3667
# 50 episodes - episode_reward: -1273.343 [-1723.435, -740.205] - loss: 311.905 - mean_squared_error: 623.809 - mean_q: -362.944
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.6084
# 50 episodes - episode_reward: -1321.683 [-1677.905, -1018.767] - loss: 333.553 - mean_squared_error: 667.107 - mean_q: -368.255
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.4975
# 50 episodes - episode_reward: -1299.499 [-1709.221, -804.756] - loss: 340.215 - mean_squared_error: 680.431 - mean_q: -374.083
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.4124
# 50 episodes - episode_reward: -1282.481 [-1783.155, -773.115] - loss: 353.931 - mean_squared_error: 707.861 - mean_q: -378.842
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.5037
# 50 episodes - episode_reward: -1300.747 [-1763.011, -767.069] - loss: 348.481 - mean_squared_error: 696.961 - mean_q: -378.018
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.3359
# 50 episodes - episode_reward: -1267.175 [-1762.376, -859.824] - loss: 360.361 - mean_squared_error: 720.721 - mean_q: -381.393
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.1229
# 50 episodes - episode_reward: -1224.576 [-1763.746, -854.628] - loss: 358.449 - mean_squared_error: 716.898 - mean_q: -383.111
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.3000
# 50 episodes - episode_reward: -1259.995 [-1811.828, -739.152] - loss: 368.093 - mean_squared_error: 736.186 - mean_q: -384.015
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.5768
# 50 episodes - episode_reward: -1315.360 [-1741.051, -964.250] - loss: 380.615 - mean_squared_error: 761.230 - mean_q: -386.643
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.7908
# 50 episodes - episode_reward: -1358.165 [-1759.057, -857.744] - loss: 379.994 - mean_squared_error: 759.987 - mean_q: -388.462
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.7856
# 50 episodes - episode_reward: -1357.122 [-1725.871, -882.413] - loss: 410.506 - mean_squared_error: 821.011 - mean_q: -390.943
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.7393
# 50 episodes - episode_reward: -1347.870 [-1754.782, -739.946] - loss: 417.691 - mean_squared_error: 835.382 - mean_q: -393.014
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.6087
# 50 episodes - episode_reward: -1321.746 [-1750.168, -860.864] - loss: 439.392 - mean_squared_error: 878.783 - mean_q: -392.228
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.5078
# 50 episodes - episode_reward: -1301.562 [-1755.222, -741.452] - loss: 414.448 - mean_squared_error: 828.896 - mean_q: -384.952
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.8963
# 50 episodes - episode_reward: -1379.269 [-1755.466, -972.605] - loss: 396.067 - mean_squared_error: 792.134 - mean_q: -368.766
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.9027
# 50 episodes - episode_reward: -1380.547 [-2772.500, -813.990] - loss: 852.884 - mean_squared_error: 1705.768 - mean_q: -291.457
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -7.2598
# 50 episodes - episode_reward: -1451.964 [-1784.085, -1087.329] - loss: 524.997 - mean_squared_error: 1049.993 - mean_q: -112.105
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: -7.5495
# 50 episodes - episode_reward: -1509.902 [-1787.823, -1153.719] - loss: 207.992 - mean_squared_error: 415.983 - mean_q: -97.031
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 75s 8ms/step - reward: -7.0519
# 50 episodes - episode_reward: -1410.378 [-1803.397, -962.104] - loss: 218.344 - mean_squared_error: 436.688 - mean_q: -89.799
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -7.3736
# 50 episodes - episode_reward: -1474.720 [-1800.191, -1126.547] - loss: 151.934 - mean_squared_error: 303.869 - mean_q: -98.680
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: -7.5468
# 50 episodes - episode_reward: -1509.358 [-1778.625, -1024.344] - loss: 118.856 - mean_squared_error: 237.712 - mean_q: -108.573
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -7.2620
# 50 episodes - episode_reward: -1452.398 [-1791.457, -915.041] - loss: 91.002 - mean_squared_error: 182.004 - mean_q: -102.511
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.6598
# 50 episodes - episode_reward: -1331.960 [-1757.019, -860.092] - loss: 81.607 - mean_squared_error: 163.215 - mean_q: -113.912
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -6.7724
# 50 episodes - episode_reward: -1354.475 [-1755.437, -1095.016] - loss: 76.793 - mean_squared_error: 153.586 - mean_q: -133.866
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -6.8233
# 50 episodes - episode_reward: -1364.668 [-1754.329, -1000.113] - loss: 82.782 - mean_squared_error: 165.564 - mean_q: -157.146
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -7.0557
# 50 episodes - episode_reward: -1411.132 [-1815.967, -1090.407] - loss: 111.129 - mean_squared_error: 222.259 - mean_q: -194.880
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -6.9721
# 50 episodes - episode_reward: -1394.415 [-1812.261, -965.835] - loss: 138.035 - mean_squared_error: 276.070 - mean_q: -227.161
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -6.6785
# 50 episodes - episode_reward: -1335.699 [-1800.820, -739.462] - loss: 174.954 - mean_squared_error: 349.907 - mean_q: -257.117
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -6.5040
# 50 episodes - episode_reward: -1300.792 [-1762.085, -905.167] - loss: 207.072 - mean_squared_error: 414.144 - mean_q: -283.702
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -6.6869
# 50 episodes - episode_reward: -1337.384 [-1792.160, -668.182] - loss: 235.749 - mean_squared_error: 471.498 - mean_q: -307.923
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -6.6231
# 50 episodes - episode_reward: -1324.620 [-1829.331, -930.432] - loss: 261.915 - mean_squared_error: 523.831 - mean_q: -328.286
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.6749
# 50 episodes - episode_reward: -1334.981 [-1758.339, -886.698] - loss: 292.100 - mean_squared_error: 584.200 - mean_q: -343.694
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.4049
# 50 episodes - episode_reward: -1280.983 [-1751.352, -732.474] - loss: 318.607 - mean_squared_error: 637.214 - mean_q: -358.280
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.4937
# 50 episodes - episode_reward: -1298.741 [-1735.915, -749.389] - loss: 350.036 - mean_squared_error: 700.072 - mean_q: -369.797
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 82s 8ms/step - reward: -6.6196
# 50 episodes - episode_reward: -1323.916 [-1753.398, -857.013] - loss: 353.458 - mean_squared_error: 706.917 - mean_q: -379.476
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: -6.3662
# 50 episodes - episode_reward: -1273.234 [-1713.148, -785.916] - loss: 377.024 - mean_squared_error: 754.049 - mean_q: -386.922
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.4090
# 50 episodes - episode_reward: -1281.793 [-1691.780, -747.292] - loss: 375.854 - mean_squared_error: 751.708 - mean_q: -392.625
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.7299
# 50 episodes - episode_reward: -1345.980 [-1735.933, -944.277] - loss: 403.064 - mean_squared_error: 806.128 - mean_q: -398.857
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: -6.3755
# 50 episodes - episode_reward: -1275.091 [-1669.325, -739.591] - loss: 411.440 - mean_squared_error: 822.881 - mean_q: -403.350
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.1362
# 50 episodes - episode_reward: -1227.247 [-1725.906, -747.543] - loss: 408.128 - mean_squared_error: 816.257 - mean_q: -406.287
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.4933
# 50 episodes - episode_reward: -1298.654 [-1726.877, -740.307] - loss: 401.209 - mean_squared_error: 802.419 - mean_q: -407.367
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.7491
# 50 episodes - episode_reward: -1349.829 [-1749.415, -743.908] - loss: 423.201 - mean_squared_error: 846.403 - mean_q: -411.495
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.2616
# 50 episodes - episode_reward: -1252.316 [-1709.288, -547.097] - loss: 433.157 - mean_squared_error: 866.314 - mean_q: -410.213
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.5953
# 50 episodes - episode_reward: -1319.055 [-1766.502, -801.262] - loss: 420.057 - mean_squared_error: 840.113 - mean_q: -407.084
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.5535
# 50 episodes - episode_reward: -1310.694 [-1839.732, -867.484] - loss: 436.712 - mean_squared_error: 873.424 - mean_q: -404.573
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.3350
# 50 episodes - episode_reward: -1266.990 [-1613.534, -946.215] - loss: 399.972 - mean_squared_error: 799.943 - mean_q: -397.973
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.3615
# 50 episodes - episode_reward: -1272.298 [-1633.248, -779.053] - loss: 411.569 - mean_squared_error: 823.138 - mean_q: -386.939
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.5566
# 50 episodes - episode_reward: -1311.317 [-1751.818, -837.564] - loss: 381.052 - mean_squared_error: 762.105 - mean_q: -377.113
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.4351
# 50 episodes - episode_reward: -1287.011 [-1677.379, -857.847] - loss: 358.719 - mean_squared_error: 717.438 - mean_q: -367.298
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.3361
# 50 episodes - episode_reward: -1267.229 [-1745.289, -829.113] - loss: 349.132 - mean_squared_error: 698.264 - mean_q: -357.757
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.3077
# 50 episodes - episode_reward: -1261.540 [-1757.192, -861.771] - loss: 351.487 - mean_squared_error: 702.974 - mean_q: -351.638
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.4698
# 50 episodes - episode_reward: -1293.965 [-1758.611, -795.199] - loss: 337.314 - mean_squared_error: 674.628 - mean_q: -343.711
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: -6.4554
# 50 episodes - episode_reward: -1291.088 [-1753.780, -993.943] - loss: 307.128 - mean_squared_error: 614.256 - mean_q: -330.949
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -6.4699
# 50 episodes - episode_reward: -1293.980 [-1757.901, -865.259] - loss: 297.272 - mean_squared_error: 594.544 - mean_q: -316.194
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -6.6806
# 50 episodes - episode_reward: -1336.118 [-1751.110, -870.865] - loss: 271.667 - mean_squared_error: 543.334 - mean_q: -303.030
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -6.4093
# 50 episodes - episode_reward: -1281.860 [-1661.039, -790.044] - loss: 243.656 - mean_squared_error: 487.311 - mean_q: -287.129
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: -6.6101
# 50 episodes - episode_reward: -1322.022 [-1701.260, -770.469] - loss: 237.917 - mean_squared_error: 475.835 - mean_q: -277.810
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: -6.5282
# 50 episodes - episode_reward: -1305.641 [-1765.795, -972.312] - loss: 226.704 - mean_squared_error: 453.408 - mean_q: -273.694
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.4762
# 50 episodes - episode_reward: -1295.236 [-1760.024, -811.161] - loss: 226.508 - mean_squared_error: 453.016 - mean_q: -277.481
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.9051
# 50 episodes - episode_reward: -1381.030 [-1782.749, -945.990] - loss: 229.742 - mean_squared_error: 459.484 - mean_q: -287.806
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.4268
# 50 episodes - episode_reward: -1285.368 [-1757.446, -766.664] - loss: 268.394 - mean_squared_error: 536.788 - mean_q: -301.776
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.9283
# 50 episodes - episode_reward: -1385.661 [-1751.909, -966.900] - loss: 701.074 - mean_squared_error: 1402.147 - mean_q: -244.151
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.5744
# 50 episodes - episode_reward: -1314.881 [-1753.692, -738.896] - loss: 401.778 - mean_squared_error: 803.556 - mean_q: -189.847
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.7608
# 50 episodes - episode_reward: -1352.152 [-1752.780, -969.246] - loss: 390.664 - mean_squared_error: 781.327 - mean_q: -169.995
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -7.1598
# 50 episodes - episode_reward: -1431.961 [-1795.609, -990.592] - loss: 183.346 - mean_squared_error: 366.692 - mean_q: -126.483
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.7243
# 50 episodes - episode_reward: -1344.853 [-1608.945, -873.624] - loss: 153.048 - mean_squared_error: 306.097 - mean_q: -136.373
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -7.1914
# 50 episodes - episode_reward: -1438.273 [-1657.714, -1178.296] - loss: 130.032 - mean_squared_error: 260.065 - mean_q: -156.894
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 84s 8ms/step - reward: -7.0569
# 50 episodes - episode_reward: -1411.373 [-1760.172, -743.680] - loss: 126.434 - mean_squared_error: 252.869 - mean_q: -180.049
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.8107
# 50 episodes - episode_reward: -1362.139 [-1761.135, -916.050] - loss: 150.887 - mean_squared_error: 301.774 - mean_q: -204.414
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.8128
# 50 episodes - episode_reward: -1362.554 [-1757.621, -740.566] - loss: 169.503 - mean_squared_error: 339.006 - mean_q: -225.703
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.7704
# 50 episodes - episode_reward: -1354.085 [-1753.750, -801.363] - loss: 201.293 - mean_squared_error: 402.586 - mean_q: -256.383
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: -6.8838
# 50 episodes - episode_reward: -1376.754 [-1795.695, -1045.807] - loss: 215.476 - mean_squared_error: 430.952 - mean_q: -280.148
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 79s 8ms/step - reward: -6.6197
# 50 episodes - episode_reward: -1323.934 [-1755.391, -903.798] - loss: 219.842 - mean_squared_error: 439.684 - mean_q: -294.886
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: -6.4461
# 50 episodes - episode_reward: -1289.219 [-1754.999, -966.510] - loss: 240.962 - mean_squared_error: 481.924 - mean_q: -300.629
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: -6.4246
# 50 episodes - episode_reward: -1284.928 [-1743.880, -903.129] - loss: 244.010 - mean_squared_error: 488.019 - mean_q: -306.792
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.1294
# 50 episodes - episode_reward: -1225.875 [-1470.065, -906.785] - loss: 257.967 - mean_squared_error: 515.934 - mean_q: -311.973
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 78s 8ms/step - reward: -6.5298
# 50 episodes - episode_reward: -1305.960 [-1760.060, -1021.285] - loss: 273.527 - mean_squared_error: 547.055 - mean_q: -321.200
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.4401
# 50 episodes - episode_reward: -1288.017 [-1752.869, -972.607] - loss: 294.265 - mean_squared_error: 588.531 - mean_q: -329.902
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: -6.4939
# 50 episodes - episode_reward: -1298.781 [-1758.020, -793.725] - loss: 308.819 - mean_squared_error: 617.637 - mean_q: -342.012
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: -6.5397
# 50 episodes - episode_reward: -1307.945 [-1757.342, -1090.899] - loss: 310.435 - mean_squared_error: 620.870 - mean_q: -351.783
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: -6.6334
# 50 episodes - episode_reward: -1326.671 [-1712.620, -921.223] - loss: 317.338 - mean_squared_error: 634.677 - mean_q: -360.490
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 82s 8ms/step - reward: -6.4846
# 50 episodes - episode_reward: -1296.927 [-1771.299, -891.923] - loss: 325.063 - mean_squared_error: 650.126 - mean_q: -364.544
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 77s 8ms/step - reward: -6.6146
# done, took 7653.127 seconds
# Finish Learning. We start test phase.

# %%
#agent.fit(env, lam=l, nb_steps=50000, visualize=True, verbose=1, nb_max_episode_steps=200)
print('Finish Learning. We start test phase.')
agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Finish Learning. We start test phase.
# Testing for 5 episodes ...
# Episode 1: reward: -1086.904, steps: 200
# Episode 2: reward: -1731.041, steps: 200
# Episode 3: reward: -1664.114, steps: 200
# Episode 4: reward: -1314.094, steps: 200
# Episode 5: reward: -1208.620, steps: 200

# %%
agent.fit(env, lam=l, nb_steps=10000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
#  5249/10000 [==============>...............] - ETA: 30s - reward: nandone, took 33.188 seconds

# %%
agent.save_weights('0.5free_model_verygood.h5')

# %% [markdown]
# $\lambda = 1$だと15万ステップ学習してもダメ
#
# $\lambda = 0.1$だと1万5千くらいから立ち始める。その時はたってからは毎回通信。

# %%
for i in range(11):
    l = i*0.2
    def agent(a_shape, s_shape):
        actor = actor_net(a_shape, s_shape)
        critic,  critic_action_input = critic_net(a_shape, s_shape)
        memory = SequentialMemory(limit = 50000, window_length = 1)
        agent = eventDDPGAgent(
            a_shape[0],
            actor,
            critic,
            critic_action_input,
            memory
        )
        return agent

    a = agent((3,), env.observation_space.shape)
    a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
    a.fit(env, lam=l, nb_steps=50000, visualize=1, verbose=1, nb_max_episode_steps=200)
    a.save_weights(f'learned_models/normal{l}.h5')
# Out:
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 152s 15ms/step - reward: -7.6021
# 50 episodes - episode_reward: -1520.418 [-1848.082, -926.173] - loss: 3.034 - mean_absolute_error: 0.515 - mean_q: -32.362
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6.1389
# 50 episodes - episode_reward: -1227.779 [-1853.759, -752.904] - loss: 19.983 - mean_absolute_error: 1.015 - mean_q: -85.907
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 168s 17ms/step - reward: -4.3081
# 50 episodes - episode_reward: -861.618 [-1656.482, -226.366] - loss: 39.277 - mean_absolute_error: 1.756 - mean_q: -112.669
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3.9846
# 50 episodes - episode_reward: -796.920 [-1477.454, -451.134] - loss: 53.780 - mean_absolute_error: 2.436 - mean_q: -125.479
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3.5808
# done, took 820.047 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 169s 17ms/step - reward: -6.9265
# 50 episodes - episode_reward: -1385.296 [-1793.580, -958.647] - loss: 2.422 - mean_absolute_error: 0.507 - mean_q: -30.773
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6.4775
# 50 episodes - episode_reward: -1295.506 [-1660.541, -771.035] - loss: 16.305 - mean_absolute_error: 0.975 - mean_q: -82.472
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.9276
# 50 episodes - episode_reward: -985.513 [-1277.214, -23.609] - loss: 35.243 - mean_absolute_error: 1.585 - mean_q: -118.089
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.3162
# 50 episodes - episode_reward: -863.241 [-1526.610, -22.312] - loss: 51.568 - mean_absolute_error: 2.012 - mean_q: -142.503
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 138s 14ms/step - reward: -3.0766
# done, took 806.960 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: -6.8396
# 50 episodes - episode_reward: -1367.927 [-1842.018, -802.512] - loss: 2.179 - mean_absolute_error: 0.448 - mean_q: -29.767
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: -5.8350
# 50 episodes - episode_reward: -1166.993 [-1545.299, -56.587] - loss: 16.105 - mean_absolute_error: 0.942 - mean_q: -79.090
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: -3.9622
# 50 episodes - episode_reward: -792.435 [-1470.038, -53.082] - loss: 32.951 - mean_absolute_error: 1.602 - mean_q: -108.587
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: -3.0114
# 50 episodes - episode_reward: -602.277 [-1331.238, -56.860] - loss: 45.169 - mean_absolute_error: 2.113 - mean_q: -119.309
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 148s 15ms/step - reward: -3.2255
# done, took 489.464 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 170s 17ms/step - reward: -6.6729
# 50 episodes - episode_reward: -1334.571 [-1830.241, -734.704] - loss: 1.943 - mean_absolute_error: 0.504 - mean_q: -27.631
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -5.2680
# 50 episodes - episode_reward: -1053.591 [-1466.354, -527.913] - loss: 14.001 - mean_absolute_error: 1.028 - mean_q: -73.800
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -2.5724
# 50 episodes - episode_reward: -514.483 [-1350.451, -72.423] - loss: 26.681 - mean_absolute_error: 1.633 - mean_q: -93.336
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.6016
# 50 episodes - episode_reward: -920.329 [-1303.512, -301.871] - loss: 35.657 - mean_absolute_error: 2.171 - mean_q: -101.557
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 169s 17ms/step - reward: -4.7704
# done, took 838.365 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 170s 17ms/step - reward: -6.6949
# 50 episodes - episode_reward: -1338.972 [-1825.693, -865.638] - loss: 2.533 - mean_absolute_error: 0.558 - mean_q: -27.291
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6.2555
# 50 episodes - episode_reward: -1251.105 [-1730.692, -682.787] - loss: 14.034 - mean_absolute_error: 1.063 - mean_q: -75.143
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3.7248
# 50 episodes - episode_reward: -744.962 [-1567.315, -296.714] - loss: 33.162 - mean_absolute_error: 1.910 - mean_q: -105.035
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.5632
# 50 episodes - episode_reward: -912.637 [-1613.496, -120.750] - loss: 43.838 - mean_absolute_error: 2.551 - mean_q: -116.764
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.6130
# done, took 836.444 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 171s 17ms/step - reward: -7.2607
# 50 episodes - episode_reward: -1452.132 [-1896.382, -1014.270] - loss: 2.710 - mean_absolute_error: 0.561 - mean_q: -30.879
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 168s 17ms/step - reward: -6.1511
# 50 episodes - episode_reward: -1230.227 [-1741.070, -490.540] - loss: 16.476 - mean_absolute_error: 1.075 - mean_q: -80.265
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -5.0315
# 50 episodes - episode_reward: -1006.291 [-1652.869, -547.885] - loss: 34.289 - mean_absolute_error: 1.882 - mean_q: -112.503
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 143s 14ms/step - reward: -4.6580
# 50 episodes - episode_reward: -931.604 [-1689.278, -535.096] - loss: 51.408 - mean_absolute_error: 2.544 - mean_q: -129.796
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: -5.0606
# done, took 748.119 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: -6.8751
# 50 episodes - episode_reward: -1375.017 [-1869.416, -977.412] - loss: 3.003 - mean_absolute_error: 0.630 - mean_q: -29.523
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: -6.5544
# 50 episodes - episode_reward: -1310.890 [-1741.991, -807.589] - loss: 17.223 - mean_absolute_error: 1.081 - mean_q: -81.376
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: -5.7740
# 50 episodes - episode_reward: -1154.808 [-1598.778, -665.128] - loss: 39.847 - mean_absolute_error: 1.802 - mean_q: -121.463
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: -6.1639
# 50 episodes - episode_reward: -1232.789 [-1604.357, -962.908] - loss: 61.756 - mean_absolute_error: 2.466 - mean_q: -149.861
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: -6.2856
# done, took 489.033 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: -7.2125
# 50 episodes - episode_reward: -1442.499 [-1945.023, -737.797] - loss: 2.727 - mean_absolute_error: 0.628 - mean_q: -29.996
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: -6.4870
# 50 episodes - episode_reward: -1297.395 [-1766.722, -854.976] - loss: 18.239 - mean_absolute_error: 1.172 - mean_q: -82.044
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: -6.2200
# 50 episodes - episode_reward: -1244.000 [-1799.134, -804.532] - loss: 37.778 - mean_absolute_error: 1.847 - mean_q: -119.928
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: -5.5366
# 50 episodes - episode_reward: -1107.320 [-1343.298, -851.263] - loss: 57.968 - mean_absolute_error: 2.463 - mean_q: -145.937
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 105s 10ms/step - reward: -5.4941
# done, took 518.219 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 114s 11ms/step - reward: -7.1733
# 50 episodes - episode_reward: -1434.669 [-1958.030, -740.277] - loss: 3.324 - mean_absolute_error: 0.638 - mean_q: -31.406
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 149s 15ms/step - reward: -6.7973
# 50 episodes - episode_reward: -1359.464 [-1770.383, -1016.542] - loss: 20.893 - mean_absolute_error: 1.180 - mean_q: -85.954
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 148s 15ms/step - reward: -6.6217
# 50 episodes - episode_reward: -1324.330 [-1734.293, -777.904] - loss: 46.382 - mean_absolute_error: 1.749 - mean_q: -134.099
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 117s 12ms/step - reward: -6.1058
# 50 episodes - episode_reward: -1221.157 [-1689.485, -262.294] - loss: 69.329 - mean_absolute_error: 2.007 - mean_q: -162.902
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: -6.2247
# done, took 637.321 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: -7.1459
# 50 episodes - episode_reward: -1429.170 [-1913.444, -949.538] - loss: 2.232 - mean_absolute_error: 0.651 - mean_q: -29.575
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 133s 13ms/step - reward: -6.5019
# 50 episodes - episode_reward: -1300.373 [-1734.675, -644.505] - loss: 15.871 - mean_absolute_error: 1.145 - mean_q: -80.055
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 128s 13ms/step - reward: -5.6845
# 50 episodes - episode_reward: -1136.890 [-1644.355, -302.340] - loss: 36.972 - mean_absolute_error: 1.725 - mean_q: -119.976
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 122s 12ms/step - reward: -6.2013
# 50 episodes - episode_reward: -1240.256 [-1718.371, -523.167] - loss: 63.401 - mean_absolute_error: 2.175 - mean_q: -152.729
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 140s 14ms/step - reward: -5.4404
# done, took 624.828 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 170s 17ms/step - reward: -6.8628
# 50 episodes - episode_reward: -1372.568 [-1827.537, -954.353] - loss: 2.521 - mean_absolute_error: 0.707 - mean_q: -29.889
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -6.6865
# 50 episodes - episode_reward: -1337.309 [-1741.633, -768.716] - loss: 14.999 - mean_absolute_error: 1.117 - mean_q: -78.690
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 123s 12ms/step - reward: -5.8406
# 50 episodes - episode_reward: -1168.113 [-1659.201, -770.333] - loss: 39.343 - mean_absolute_error: 1.923 - mean_q: -118.606
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 124s 12ms/step - reward: -5.5608
# 50 episodes - episode_reward: -1112.152 [-1788.749, -612.351] - loss: 57.550 - mean_absolute_error: 2.469 - mean_q: -142.914
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -4.6330
# done, took 651.197 seconds

# %%
agent.fit(env, lam=l, nb_steps=150000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 150000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -1.5935
# 50 episodes - episode_reward: -318.692 [-727.146, -1.055] - loss: 30.884 - mean_squared_error: 61.767 - mean_q: -66.899
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -1.6722
# 50 episodes - episode_reward: -334.447 [-644.433, -0.792] - loss: 22.827 - mean_squared_error: 45.653 - mean_q: -39.455
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.0309
# 50 episodes - episode_reward: -406.185 [-1731.487, -0.861] - loss: 20.777 - mean_squared_error: 41.554 - mean_q: -27.843
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.3320
# 50 episodes - episode_reward: -466.399 [-1734.120, -1.240] - loss: 19.490 - mean_squared_error: 38.980 - mean_q: -20.356
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.4213
# 50 episodes - episode_reward: -484.259 [-1214.853, -2.351] - loss: 17.543 - mean_squared_error: 35.086 - mean_q: -18.006
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: -2.9297
# 50 episodes - episode_reward: -585.942 [-1327.066, -1.363] - loss: 18.398 - mean_squared_error: 36.797 - mean_q: -18.254
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -2.7039
# 50 episodes - episode_reward: -540.785 [-1430.529, -2.663] - loss: 13.138 - mean_squared_error: 26.276 - mean_q: -17.249
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.5461
# 50 episodes - episode_reward: -709.227 [-1706.684, -1.296] - loss: 14.086 - mean_squared_error: 28.172 - mean_q: -21.296
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 676s 68ms/step - reward: -2.7057
# 50 episodes - episode_reward: -541.134 [-1457.064, -0.427] - loss: 14.624 - mean_squared_error: 29.247 - mean_q: -25.297
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -3.0200
# 50 episodes - episode_reward: -603.997 [-1735.811, -1.230] - loss: 15.225 - mean_squared_error: 30.451 - mean_q: -26.373
#
# Interval 11 (100000 steps performed)
#  1046/10000 [==>...........................] - ETA: 1:13 - reward: -2.4960done, took 664.227 seconds

# %%
agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Testing for 5 episodes ...
# Episode 1: reward: -392.520, steps: 200
# Episode 2: reward: -400.598, steps: 200
# Episode 3: reward: -25.208, steps: 200
# Episode 4: reward: -505.319, steps: 200
# Episode 5: reward: -1006.071, steps: 200

# %%
np.clip(2,-1,1)
# Out:
# 1
