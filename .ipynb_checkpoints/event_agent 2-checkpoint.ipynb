# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Model
from keras.layers import concatenate, Dense, Input, Flatten
from keras.optimizers import Adam
import gym
from rl.agents import eventDDPGAgent
from rl.memory import SequentialMemory
# Out:
# Using TensorFlow backend.
# /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# GymのPendulum環境を作成
env = gym.make("Pendulum-v0")

# 取りうる”打ち手”のアクション数と値の定義
nb_actions = 2
ACT_ID_TO_VALUE = {0: [-1], 1: [+1]}

# %%
def actor_net(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input)
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(3, activation="tanh")(x)
    actor = Model(inputs=action_input, outputs=x)
    return actor

def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

# %%
def agent(a_shape, s_shape):
    actor = actor_net(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = eventDDPGAgent(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        clip_com = 0.01
    )
    return agent

# %%
#event-base learning with time-based initial agent
l = 1.0
a =  agent((3,), env.observation_space.shape)
a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mse"])
a.load_weights('./0.5standup-agent.h5')
a.fit(env, lam=l, nb_steps=60000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
print('Finish Learning. We start test phase.')
aaa
a.test(env, lam=l, nb_episodes=5, visualize=True, nb_max_episode_steps=200)
a.save_weights(f'learned_models/good{l}.h5')
# Out:
# Training for 60000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 55s 5ms/step - reward: -2.7877
# 50 episodes - episode_reward: -557.541 [-1558.021, -205.247] - loss: 16.722 - mean_squared_error: 33.444 - mean_q: -54.367
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -3.0073
# 50 episodes - episode_reward: -601.458 [-1339.700, -206.927] - loss: 12.230 - mean_squared_error: 24.460 - mean_q: -54.769
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -3.2875
# 50 episodes - episode_reward: -657.498 [-1933.171, -206.437] - loss: 25.421 - mean_squared_error: 50.842 - mean_q: -70.187
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -2.2906
# 50 episodes - episode_reward: -458.117 [-1034.233, -207.709] - loss: 18.795 - mean_squared_error: 37.589 - mean_q: -69.563
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -3.1653
# 50 episodes - episode_reward: -633.065 [-1018.268, -315.702] - loss: 16.597 - mean_squared_error: 33.194 - mean_q: -66.671
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -4.2301
# done, took 383.651 seconds
# Finish Learning. We start test phase.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b705e4c5c493> in <module>
#       6 a.fit(env, lam=l, nb_steps=60000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
#       7 print('Finish Learning. We start test phase.')
# ----> 8 aaa
#       9 a.test(env, lam=l, nb_episodes=5, visualize=True, nb_max_episode_steps=200)
#      10 a.save_weights(f'learned_models/good{l}.h5')
#
# NameError: name 'aaa' is not defined

# %%
a.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Testing for 5 episodes ...
# Episode 1: reward: -887.948, steps: 200
# Episode 2: reward: -1539.987, steps: 200
# Episode 3: reward: -863.973, steps: 200
# Episode 4: reward: -268.202, steps: 200
# Episode 5: reward: -639.098, steps: 200

# %%
a.fit(env, lam=l, nb_steps=10000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 55s 6ms/step - reward: -3.9847
# done, took 55.141 seconds

# %%
l = 0.8
a =  agent((3,), env.observation_space.shape)
a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
#a.load_weights(f'./learned_models/good{l}.h5')
a.load_weights(f'./learned_models/normal{l}.h5')
a.test(env, lam=l, nb_episodes=5, visualize=True, nb_max_episode_steps=200, graph=1)
# Out:
# Testing for 5 episodes ...
# Episode 1: reward: -19.937, steps: 200
# Episode 2: reward: -861.145, steps: 200
# Episode 3: reward: -1154.588, steps: 200
# Episode 4: reward: -1118.710, steps: 200
# Episode 5: reward: -646.907, steps: 200

# %%
a.test(env, lam=l, nb_episodes=1, visualize=True, nb_max_episode_steps=200, graph=1, action_view=1)
# Out:
# Testing for 1 episodes ...
# step =  1 , output of actor network =  [ 0.9999989 -0.7795443 -0.9999991]
# step =  2 , output of actor network =  [ 0.84119976 -0.9998244  -0.99999994]
# step =  3 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  4 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  5 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  6 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  7 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  8 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  9 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  10 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  11 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  12 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  13 , output of actor network =  [-0.9999999 -0.9999993 -1.       ]
# step =  14 , output of actor network =  [-0.19686122 -0.99997985 -1.        ]
# step =  15 , output of actor network =  [ 0.9717341 -0.9999975 -1.       ]
# step =  16 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  17 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  18 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  19 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  20 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  21 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  22 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  23 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  24 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  25 , output of actor network =  [-0.994943  -0.9999287 -1.       ]
# step =  26 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  27 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  28 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  29 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  30 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  31 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  32 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  33 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  34 , output of actor network =  [ 1.         -0.97246087 -0.99999195]
# step =  35 , output of actor network =  [-0.5008968   1.          0.99999964]
# step =  36 , output of actor network =  [-0.7390542  1.         0.9575971]
# step =  37 , output of actor network =  [ 0.32586098  1.         -0.98179406]
# step =  38 , output of actor network =  [ 0.97571456  0.9999999  -0.99987316]
# step =  39 , output of actor network =  [ 0.96321577  0.9999263  -0.9999891 ]
# step =  40 , output of actor network =  [ 0.5162211   0.9998329  -0.99999326]
# step =  41 , output of actor network =  [-0.5750934  0.9997802 -0.9999948]
# step =  42 , output of actor network =  [ 0.3939542  0.9974496 -0.9999977]
# step =  43 , output of actor network =  [ 0.7982323  0.9926417 -0.9999981]
# step =  44 , output of actor network =  [ 0.83274645  0.99556077 -0.9999993 ]
# step =  45 , output of actor network =  [ 0.80524415  0.99766165 -0.9999997 ]
# step =  46 , output of actor network =  [ 0.72225314  0.9987756  -0.9999999 ]
# step =  47 , output of actor network =  [ 0.5447559   0.99934125 -0.9999998 ]
# step =  48 , output of actor network =  [ 0.37098506  0.99963117 -0.99999964]
# step =  49 , output of actor network =  [ 0.24673247  0.99976933 -0.9999994 ]
# step =  50 , output of actor network =  [ 0.16219023  0.999833   -0.99999875]
# step =  51 , output of actor network =  [ 0.11897595  0.99986535 -0.99999785]
# step =  52 , output of actor network =  [ 0.10644729  0.9998834  -0.9999962 ]
# step =  53 , output of actor network =  [ 0.10644729  0.9998834  -0.9999962 ]
# step =  54 , output of actor network =  [ 0.13013165  0.99990565 -0.99999106]
# step =  55 , output of actor network =  [ 0.14564987  0.99991435 -0.9999885 ]
# step =  56 , output of actor network =  [ 0.15942943  0.99992055 -0.99998575]
# step =  57 , output of actor network =  [ 0.17133889  0.9999268  -0.9999837 ]
# step =  58 , output of actor network =  [ 0.18144606  0.9999333  -0.9999826 ]
# step =  59 , output of actor network =  [ 0.18144606  0.9999333  -0.9999826 ]
# step =  60 , output of actor network =  [ 0.20228904  0.9999408  -0.99998105]
# step =  61 , output of actor network =  [ 0.20228904  0.9999408  -0.99998105]
# step =  62 , output of actor network =  [ 0.20228904  0.9999408  -0.99998105]
# step =  63 , output of actor network =  [ 0.21956302  0.9999469  -0.9999792 ]
# step =  64 , output of actor network =  [ 0.21956302  0.9999469  -0.9999792 ]
# step =  65 , output of actor network =  [ 0.21956302  0.9999469  -0.9999792 ]
# step =  66 , output of actor network =  [ 0.21956302  0.9999469  -0.9999792 ]
# step =  67 , output of actor network =  [ 0.21956302  0.9999469  -0.9999792 ]
# step =  68 , output of actor network =  [ 0.21956302  0.9999469  -0.9999792 ]
# step =  69 , output of actor network =  [ 0.21956302  0.9999469  -0.9999792 ]
# step =  70 , output of actor network =  [ 0.23195821  0.99995124 -0.9999778 ]
# step =  71 , output of actor network =  [ 0.23195821  0.99995124 -0.9999778 ]
# step =  72 , output of actor network =  [ 0.23195821  0.99995124 -0.9999778 ]
# step =  73 , output of actor network =  [ 0.23195821  0.99995124 -0.9999778 ]
# step =  74 , output of actor network =  [ 0.21854216  0.99995285 -0.9999782 ]
# step =  75 , output of actor network =  [ 0.21854216  0.99995285 -0.9999782 ]
# step =  76 , output of actor network =  [ 0.21854216  0.99995285 -0.9999782 ]
# step =  77 , output of actor network =  [ 0.23087333  0.9999525  -0.99997765]
# step =  78 , output of actor network =  [ 0.23087333  0.9999525  -0.99997765]
# step =  79 , output of actor network =  [ 0.23087333  0.9999525  -0.99997765]
# step =  80 , output of actor network =  [ 0.23087333  0.9999525  -0.99997765]
# step =  81 , output of actor network =  [ 0.23087333  0.9999525  -0.99997765]
# step =  82 , output of actor network =  [ 0.21931006  0.99995327 -0.9999781 ]
# step =  83 , output of actor network =  [ 0.21931006  0.99995327 -0.9999781 ]
# step =  84 , output of actor network =  [ 0.21931006  0.99995327 -0.9999781 ]
# step =  85 , output of actor network =  [ 0.23140405  0.99995273 -0.9999777 ]
# step =  86 , output of actor network =  [ 0.23140405  0.99995273 -0.9999777 ]
# step =  87 , output of actor network =  [ 0.23140405  0.99995273 -0.9999777 ]
# step =  88 , output of actor network =  [ 0.23140405  0.99995273 -0.9999777 ]
# step =  89 , output of actor network =  [ 0.23140405  0.99995273 -0.9999777 ]
# step =  90 , output of actor network =  [ 0.21905872  0.9999532  -0.9999782 ]
# step =  91 , output of actor network =  [ 0.21905872  0.9999532  -0.9999782 ]
# step =  92 , output of actor network =  [ 0.21905872  0.9999532  -0.9999782 ]
# step =  93 , output of actor network =  [ 0.23169358  0.99995273 -0.9999774 ]
# step =  94 , output of actor network =  [ 0.23169358  0.99995273 -0.9999774 ]
# step =  95 , output of actor network =  [ 0.23169358  0.99995273 -0.9999774 ]
# step =  96 , output of actor network =  [ 0.23169358  0.99995273 -0.9999774 ]
# step =  97 , output of actor network =  [ 0.23169358  0.99995273 -0.9999774 ]
# step =  98 , output of actor network =  [ 0.21860433  0.99995345 -0.999978  ]
# step =  99 , output of actor network =  [ 0.21860433  0.99995345 -0.999978  ]
# step =  100 , output of actor network =  [ 0.21860433  0.99995345 -0.999978  ]
# step =  101 , output of actor network =  [ 0.23195481  0.99995273 -0.99997747]
# step =  102 , output of actor network =  [ 0.23195481  0.99995273 -0.99997747]
# step =  103 , output of actor network =  [ 0.23195481  0.99995273 -0.99997747]
# step =  104 , output of actor network =  [ 0.23195481  0.99995273 -0.99997747]
# step =  105 , output of actor network =  [ 0.23195481  0.99995273 -0.99997747]
# step =  106 , output of actor network =  [ 0.2180904  0.9999536 -0.9999782]
# step =  107 , output of actor network =  [ 0.2180904  0.9999536 -0.9999782]
# step =  108 , output of actor network =  [ 0.2180904  0.9999536 -0.9999782]
# step =  109 , output of actor network =  [ 0.23222348  0.99995285 -0.99997765]
# step =  110 , output of actor network =  [ 0.23222348  0.99995285 -0.99997765]
# step =  111 , output of actor network =  [ 0.23222348  0.99995285 -0.99997765]
# step =  112 , output of actor network =  [ 0.23222348  0.99995285 -0.99997765]
# step =  113 , output of actor network =  [ 0.2217733  0.9999533 -0.999978 ]
# step =  114 , output of actor network =  [ 0.2217733  0.9999533 -0.999978 ]
# step =  115 , output of actor network =  [ 0.2217733  0.9999533 -0.999978 ]
# step =  116 , output of actor network =  [ 0.2217733  0.9999533 -0.999978 ]
# step =  117 , output of actor network =  [ 0.23451369  0.99995244 -0.99997747]
# step =  118 , output of actor network =  [ 0.23451369  0.99995244 -0.99997747]
# step =  119 , output of actor network =  [ 0.23451369  0.99995244 -0.99997747]
# step =  120 , output of actor network =  [ 0.22398253  0.9999531  -0.99997795]
# step =  121 , output of actor network =  [ 0.22398253  0.9999531  -0.99997795]
# step =  122 , output of actor network =  [ 0.22398253  0.9999531  -0.99997795]
# step =  123 , output of actor network =  [ 0.22398253  0.9999531  -0.99997795]
# step =  124 , output of actor network =  [ 0.22398253  0.9999531  -0.99997795]
# step =  125 , output of actor network =  [ 0.23468438  0.99995244 -0.9999776 ]
# step =  126 , output of actor network =  [ 0.23468438  0.99995244 -0.9999776 ]
# step =  127 , output of actor network =  [ 0.23468438  0.99995244 -0.9999776 ]
# step =  128 , output of actor network =  [ 0.22379406  0.99995303 -0.99997795]
# step =  129 , output of actor network =  [ 0.22379406  0.99995303 -0.99997795]
# step =  130 , output of actor network =  [ 0.22379406  0.99995303 -0.99997795]
# step =  131 , output of actor network =  [ 0.22379406  0.99995303 -0.99997795]
# step =  132 , output of actor network =  [ 0.22379406  0.99995303 -0.99997795]
# step =  133 , output of actor network =  [ 0.2349809   0.99995244 -0.9999776 ]
# step =  134 , output of actor network =  [ 0.2349809   0.99995244 -0.9999776 ]
# step =  135 , output of actor network =  [ 0.2349809   0.99995244 -0.9999776 ]
# step =  136 , output of actor network =  [ 0.22362612  0.9999529  -0.999978  ]
# step =  137 , output of actor network =  [ 0.22362612  0.9999529  -0.999978  ]
# step =  138 , output of actor network =  [ 0.22362612  0.9999529  -0.999978  ]
# step =  139 , output of actor network =  [ 0.22362612  0.9999529  -0.999978  ]
# step =  140 , output of actor network =  [ 0.22362612  0.9999529  -0.999978  ]
# step =  141 , output of actor network =  [ 0.23530838  0.99995255 -0.99997747]
# step =  142 , output of actor network =  [ 0.23530838  0.99995255 -0.99997747]
# step =  143 , output of actor network =  [ 0.23530838  0.99995255 -0.99997747]
# step =  144 , output of actor network =  [ 0.22345828  0.9999531  -0.999978  ]
# step =  145 , output of actor network =  [ 0.22345828  0.9999531  -0.999978  ]
# step =  146 , output of actor network =  [ 0.22345828  0.9999531  -0.999978  ]
# step =  147 , output of actor network =  [ 0.22345828  0.9999531  -0.999978  ]
# step =  148 , output of actor network =  [ 0.22345828  0.9999531  -0.999978  ]
# step =  149 , output of actor network =  [ 0.23565342  0.99995244 -0.99997765]
# step =  150 , output of actor network =  [ 0.23565342  0.99995244 -0.99997765]
# step =  151 , output of actor network =  [ 0.23565342  0.99995244 -0.99997765]
# step =  152 , output of actor network =  [ 0.22328442  0.9999531  -0.99997795]
# step =  153 , output of actor network =  [ 0.22328442  0.9999531  -0.99997795]
# step =  154 , output of actor network =  [ 0.22328442  0.9999531  -0.99997795]
# step =  155 , output of actor network =  [ 0.22328442  0.9999531  -0.99997795]
# step =  156 , output of actor network =  [ 0.22328442  0.9999531  -0.99997795]
# step =  157 , output of actor network =  [ 0.23601097  0.9999524  -0.9999775 ]
# step =  158 , output of actor network =  [ 0.23601097  0.9999524  -0.9999775 ]
# step =  159 , output of actor network =  [ 0.23601097  0.9999524  -0.9999775 ]
# step =  160 , output of actor network =  [ 0.22310403  0.99995303 -0.9999779 ]
# step =  161 , output of actor network =  [ 0.22310403  0.99995303 -0.9999779 ]
# step =  162 , output of actor network =  [ 0.22310403  0.99995303 -0.9999779 ]
# step =  163 , output of actor network =  [ 0.22310403  0.99995303 -0.9999779 ]
# step =  164 , output of actor network =  [ 0.22310403  0.99995303 -0.9999779 ]
# step =  165 , output of actor network =  [ 0.23638399  0.99995226 -0.99997735]
# step =  166 , output of actor network =  [ 0.23638399  0.99995226 -0.99997735]
# step =  167 , output of actor network =  [ 0.23638399  0.99995226 -0.99997735]
# step =  168 , output of actor network =  [ 0.22291589  0.99995327 -0.99997795]
# step =  169 , output of actor network =  [ 0.22291589  0.99995327 -0.99997795]
# step =  170 , output of actor network =  [ 0.22291589  0.99995327 -0.99997795]
# step =  171 , output of actor network =  [ 0.22291589  0.99995327 -0.99997795]
# step =  172 , output of actor network =  [ 0.22291589  0.99995327 -0.99997795]
# step =  173 , output of actor network =  [ 0.236771    0.99995226 -0.9999774 ]
# step =  174 , output of actor network =  [ 0.236771    0.99995226 -0.9999774 ]
# step =  175 , output of actor network =  [ 0.236771    0.99995226 -0.9999774 ]
# step =  176 , output of actor network =  [ 0.22272323  0.99995315 -0.9999778 ]
# step =  177 , output of actor network =  [ 0.22272323  0.99995315 -0.9999778 ]
# step =  178 , output of actor network =  [ 0.22272323  0.99995315 -0.9999778 ]
# step =  179 , output of actor network =  [ 0.22272323  0.99995315 -0.9999778 ]
# step =  180 , output of actor network =  [ 0.23302238  0.99995255 -0.9999775 ]
# step =  181 , output of actor network =  [ 0.23302238  0.99995255 -0.9999775 ]
# step =  182 , output of actor network =  [ 0.23302238  0.99995255 -0.9999775 ]
# step =  183 , output of actor network =  [ 0.23302238  0.99995255 -0.9999775 ]
# step =  184 , output of actor network =  [ 0.22047257  0.9999532  -0.9999781 ]
# step =  185 , output of actor network =  [ 0.22047257  0.9999532  -0.9999781 ]
# step =  186 , output of actor network =  [ 0.22047257  0.9999532  -0.9999781 ]
# step =  187 , output of actor network =  [ 0.23087543  0.99995273 -0.9999776 ]
# step =  188 , output of actor network =  [ 0.23087543  0.99995273 -0.9999776 ]
# step =  189 , output of actor network =  [ 0.23087543  0.99995273 -0.9999776 ]
# step =  190 , output of actor network =  [ 0.23087543  0.99995273 -0.9999776 ]
# step =  191 , output of actor network =  [ 0.23087543  0.99995273 -0.9999776 ]
# step =  192 , output of actor network =  [ 0.22022015  0.9999534  -0.9999781 ]
# step =  193 , output of actor network =  [ 0.22022015  0.9999534  -0.9999781 ]
# step =  194 , output of actor network =  [ 0.22022015  0.9999534  -0.9999781 ]
# step =  195 , output of actor network =  [ 0.23110761  0.99995285 -0.9999775 ]
# step =  196 , output of actor network =  [ 0.23110761  0.99995285 -0.9999775 ]
# step =  197 , output of actor network =  [ 0.23110761  0.99995285 -0.9999775 ]
# step =  198 , output of actor network =  [ 0.23110761  0.99995285 -0.9999775 ]
# step =  199 , output of actor network =  [ 0.23110761  0.99995285 -0.9999775 ]
# Episode 1: reward: -282.006, steps: 200

# %%
l = 0
a =  agent((3,), env.observation_space.shape)
a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
a.load_weights('./learned_models/0.model.h5')
a.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200,graph=1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1009 18:32:28.364133 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1009 18:32:28.388212 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1009 18:32:28.407072 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4158: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1009 18:32:28.529716 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1009 18:32:28.530754 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1009 18:32:28.793010 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Testing for 5 episodes ...
# Episode 1: reward: -0.404, steps: 200
# Episode 2: reward: -123.135, steps: 200
# Episode 3: reward: -239.054, steps: 200
# Episode 4: reward: -484.315, steps: 200
# Episode 5: reward: -493.129, steps: 200

# %%
def actor_net(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input)
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(3, activation="linear")(x)
    actor = Model(inputs=action_input, outputs=x)
    return actor

def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(32, activation="relu")(x)
    x = Dense(32, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

def agent(a_shape, s_shape):
    actor = actor_net(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = eventDDPGAgent(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        clip_com = 0.01
    )
    return agent

l = 0.4
a =  agent((3,), env.observation_space.shape)
a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mse"])
a.load_weights('./0.4free_model.h5')
a.test(env, lam=l, nb_episodes=1, visualize=0, nb_max_episode_steps=200, graph=1,action_view=1)
# Out:
# Testing for 1 episodes ...
# step =  1 , output of actor network =  [ 940.4695   483.00555 -366.91855]
# step =  2 , output of actor network =  [ 860.20215  561.45807 -411.98712]
# step =  3 , output of actor network =  [ 761.56616  654.6302  -465.692  ]
# step =  4 , output of actor network =  [ 571.39734  772.54376 -531.1121 ]
# step =  5 , output of actor network =  [ 232.91211  825.325   -646.49036]
# step =  6 , output of actor network =  [-184.82008  837.3417  -770.9497 ]
# step =  7 , output of actor network =  [-314.34958  830.44354 -767.7302 ]
# step =  8 , output of actor network =  [-478.92856  856.05634 -760.9333 ]
# step =  9 , output of actor network =  [-408.44138  894.9359  -709.1968 ]
# step =  10 , output of actor network =  [-295.68332  932.6889  -652.5583 ]
# step =  11 , output of actor network =  [-155.94226  937.71173 -604.06354]
# step =  12 , output of actor network =  [  -3.324278  937.04016  -557.27155 ]
# step =  13 , output of actor network =  [ 368.8251   936.89386 -437.80597]
# step =  14 , output of actor network =  [1085.9641   814.87067 -394.96356]
# step =  15 , output of actor network =  [1623.114    734.279   -346.20508]
# step =  16 , output of actor network =  [2037.5835  688.8432 -331.7442]
# step =  17 , output of actor network =  [2423.4392   600.9567  -323.43533]
# step =  18 , output of actor network =  [2691.0906   479.30035 -352.51913]
# step =  19 , output of actor network =  [2719.201    336.57883 -430.4444 ]
# step =  20 , output of actor network =  [2449.2188  286.8518 -469.4283]
# step =  21 , output of actor network =  [1961.317    332.74594 -666.22107]
# step =  22 , output of actor network =  [1463.2689  422.0758 -924.0482]
# step =  23 , output of actor network =  [ 1066.4781    506.26422 -1108.3441 ]
# step =  24 , output of actor network =  [  852.3381   564.9676 -1178.6482]
# step =  25 , output of actor network =  [  511.2888    584.22784 -1273.7758 ]
# step =  26 , output of actor network =  [  -44.463715   617.1374   -1397.9197  ]
# step =  27 , output of actor network =  [ -147.16899   752.41266 -1290.7004 ]
# step =  28 , output of actor network =  [ -213.74347   841.9256  -1174.1042 ]
# step =  29 , output of actor network =  [ -305.6332   858.043  -1089.0415]
# step =  30 , output of actor network =  [ -468.12534   864.7374  -1039.3595 ]
# step =  31 , output of actor network =  [ -561.6014   878.1118 -1013.5622]
# step =  32 , output of actor network =  [-441.26172  893.52606 -946.5564 ]
# step =  33 , output of actor network =  [-290.1392   916.25836 -871.3453 ]
# step =  34 , output of actor network =  [-110.08148  956.9506  -779.2256 ]
# step =  35 , output of actor network =  [ 174.49649  973.8522  -683.0392 ]
# step =  36 , output of actor network =  [ 959.19147  954.794   -580.4367 ]
# step =  37 , output of actor network =  [1574.6823  845.7238 -519.1886]
# step =  38 , output of actor network =  [2042.6855   787.19794 -472.88956]
# step =  39 , output of actor network =  [2474.102    681.8441  -438.69635]
# step =  40 , output of actor network =  [2764.3403  540.9021 -453.135 ]
# step =  41 , output of actor network =  [2704.511    322.2049  -432.52734]
# step =  42 , output of actor network =  [2417.8093   288.49744 -480.72968]
# step =  43 , output of actor network =  [1922.2123   337.87946 -683.5143 ]
# step =  44 , output of actor network =  [1424.8326   430.33328 -945.5512 ]
# step =  45 , output of actor network =  [ 1050.8534   511.143  -1114.9335]
# step =  46 , output of actor network =  [  838.41705   569.73895 -1184.3303 ]
# step =  47 , output of actor network =  [  451.86935   577.4729  -1292.7363 ]
# step =  48 , output of actor network =  [  -56.70565   627.37836 -1402.4266 ]
# step =  49 , output of actor network =  [ -172.65549   763.57135 -1295.3766 ]
# step =  50 , output of actor network =  [ -247.2973   847.1597 -1182.6199]
# step =  51 , output of actor network =  [ -348.11612   860.0963  -1101.2987 ]
# step =  52 , output of actor network =  [ -543.8402   870.3015 -1059.4946]
# step =  53 , output of actor network =  [ -528.0028   889.5107 -1010.7914]
# step =  54 , output of actor network =  [-395.10098  903.5787  -941.6111 ]
# step =  55 , output of actor network =  [-234.07469  938.1058  -858.2334 ]
# step =  56 , output of actor network =  [ -31.024427  961.7359   -765.0145  ]
# step =  57 , output of actor network =  [ 380.41714  999.4321  -653.20636]
# step =  58 , output of actor network =  [1123.6149   921.80505 -547.3292 ]
# step =  59 , output of actor network =  [1692.7784   830.63794 -500.60892]
# step =  60 , output of actor network =  [2157.111    760.97833 -456.09885]
# step =  61 , output of actor network =  [2562.3086   645.5721  -431.21466]
# step =  62 , output of actor network =  [2785.0203   490.56506 -448.04047]
# step =  63 , output of actor network =  [2653.5986   290.20593 -434.9132 ]
# step =  64 , output of actor network =  [2304.9578   296.22968 -523.2352 ]
# step =  65 , output of actor network =  [1794.223    358.02722 -746.87   ]
# step =  66 , output of actor network =  [ 1290.5599    457.92993 -1016.9365 ]
# step =  67 , output of actor network =  [  997.3121   527.0412 -1135.5583]
# step =  68 , output of actor network =  [  800.65717   582.46136 -1199.6951 ]
# step =  69 , output of actor network =  [  278.65384   580.17694 -1333.2184 ]
# step =  70 , output of actor network =  [  -92.4794   660.7555 -1414.0991]
# step =  71 , output of actor network =  [ -257.40094   797.2042  -1310.1616 ]
# step =  72 , output of actor network =  [ -360.64297   861.61334 -1210.4719 ]
# step =  73 , output of actor network =  [ -470.91025   866.36707 -1137.4324 ]
# step =  74 , output of actor network =  [ -536.65216   900.13983 -1070.9921 ]
# step =  75 , output of actor network =  [-408.88925  922.9622  -998.0498 ]
# step =  76 , output of actor network =  [-233.58347  931.03424 -920.97235]
# step =  77 , output of actor network =  [ -24.143614  966.67413  -817.47845 ]
# step =  78 , output of actor network =  [ 444.1745  1016.73346 -691.8071 ]
# step =  79 , output of actor network =  [1180.9462  935.2342 -588.599 ]
# step =  80 , output of actor network =  [1738.3455  852.0286 -536.7821]
# step =  81 , output of actor network =  [2214.0571   773.40314 -485.08752]
# step =  82 , output of actor network =  [2616.0896   648.65717 -458.86432]
# step =  83 , output of actor network =  [2783.089    461.5983  -440.17493]
# step =  84 , output of actor network =  [2631.0337   286.73532 -431.5511 ]
# step =  85 , output of actor network =  [2248.8066   300.98965 -545.33826]
# step =  86 , output of actor network =  [1732.3392   368.21448 -777.60675]
# step =  87 , output of actor network =  [ 1224.2426    469.52008 -1047.499  ]
# step =  88 , output of actor network =  [  970.3984    532.71906 -1141.6942 ]
# step =  89 , output of actor network =  [  781.68835   586.3853  -1203.0466 ]
# step =  90 , output of actor network =  [  200.71898   580.2858  -1346.7249 ]
# step =  91 , output of actor network =  [ -106.05513   673.39874 -1414.8849 ]
# step =  92 , output of actor network =  [ -278.6653    809.87885 -1309.7888 ]
# step =  93 , output of actor network =  [ -400.54178   865.6685  -1216.8651 ]
# step =  94 , output of actor network =  [ -511.6124    874.65765 -1144.5754 ]
# step =  95 , output of actor network =  [ -505.4168    911.83417 -1065.9307 ]
# step =  96 , output of actor network =  [-364.16437  932.46735 -990.66174]
# step =  97 , output of actor network =  [-178.6933   951.75665 -905.3467 ]
# step =  98 , output of actor network =  [  76.99225  976.3647  -798.1814 ]
# step =  99 , output of actor network =  [ 885.26843 1045.3274  -680.07367]
# step =  100 , output of actor network =  [1530.3257   908.0983  -619.10156]
# step =  101 , output of actor network =  [2028.6804   844.60846 -554.50464]
# step =  102 , output of actor network =  [2489.34     731.2403  -504.26465]
# step =  103 , output of actor network =  [2774.3333  559.0595 -473.2894]
# step =  104 , output of actor network =  [2708.203   325.6473 -431.9528]
# step =  105 , output of actor network =  [2425.5015  288.0719 -477.9382]
# step =  106 , output of actor network =  [1931.7227   336.61493 -679.292  ]
# step =  107 , output of actor network =  [1434.1774   428.3196  -940.32654]
# step =  108 , output of actor network =  [ 1054.6244    509.94684 -1113.3179 ]
# step =  109 , output of actor network =  [  841.76044   568.5704  -1182.9347 ]
# step =  110 , output of actor network =  [  466.10898   579.07074 -1288.1545 ]
# step =  111 , output of actor network =  [  -53.843636   624.8679   -1401.348   ]
# step =  112 , output of actor network =  [ -166.32556   760.9     -1294.1722 ]
# step =  113 , output of actor network =  [ -238.98273   845.9117  -1180.4784 ]
# step =  114 , output of actor network =  [ -337.60938   859.62836 -1098.2388 ]
# step =  115 , output of actor network =  [ -525.104     868.98004 -1054.5122 ]
# step =  116 , output of actor network =  [ -536.39233   886.74854 -1011.49927]
# step =  117 , output of actor network =  [-406.60144  901.16583 -942.8668 ]
# step =  118 , output of actor network =  [-248.01773  932.7728  -861.5329 ]
# step =  119 , output of actor network =  [ -50.656113  960.679    -768.59607 ]
# step =  120 , output of actor network =  [ 329.43164  993.274   -660.6638 ]
# step =  121 , output of actor network =  [1083.1332  930.1464 -555.5691]
# step =  122 , output of actor network =  [1664.0509   834.55743 -505.1379 ]
# step =  123 , output of actor network =  [2129.6963   767.6121  -460.06033]
# step =  124 , output of actor network =  [2541.877   654.5562 -432.7027]
# step =  125 , output of actor network =  [2784.479    505.1499  -452.66083]
# step =  126 , output of actor network =  [2663.3904   292.26892 -437.3692 ]
# step =  127 , output of actor network =  [2332.014    294.13974 -512.7978 ]
# step =  128 , output of actor network =  [1824.319    353.1364  -731.84735]
# step =  129 , output of actor network =  [ 1323.1749   452.3258 -1001.9447]
# step =  130 , output of actor network =  [ 1010.8357   524.3852 -1132.7444]
# step =  131 , output of actor network =  [  810.3496   580.6689 -1198.272 ]
# step =  132 , output of actor network =  [  318.7971    580.64355 -1326.3942 ]
# step =  133 , output of actor network =  [  -83.36797   655.1761  -1413.2063 ]
# step =  134 , output of actor network =  [ -245.89491   790.7206  -1310.6597 ]
# step =  135 , output of actor network =  [ -342.7963   859.5026 -1208.15  ]
# step =  136 , output of actor network =  [ -456.0119   863.9069 -1134.8788]
# step =  137 , output of actor network =  [ -550.33716   894.63324 -1073.3934 ]
# step =  138 , output of actor network =  [ -428.7194    918.44165 -1001.4706 ]
# step =  139 , output of actor network =  [-260.15005  927.7305  -925.61194]
# step =  140 , output of actor network =  [ -58.675415  964.42035  -825.1567  ]
# step =  141 , output of actor network =  [ 354.82724 1005.8586  -706.15356]
# step =  142 , output of actor network =  [1105.7158   956.87555 -597.42126]
# step =  143 , output of actor network =  [1688.0399   859.73663 -545.93933]
# step =  144 , output of actor network =  [2167.0354   785.82214 -492.7992 ]
# step =  145 , output of actor network =  [2582.6555   664.9112  -461.64807]
# step =  146 , output of actor network =  [2784.993    486.4148  -446.80484]
# step =  147 , output of actor network =  [2650.624    289.65674 -434.30585]
# step =  148 , output of actor network =  [2297.1128   296.86124 -526.2882 ]
# step =  149 , output of actor network =  [1785.532    359.44745 -751.1989 ]
# step =  150 , output of actor network =  [ 1281.1869    459.5523  -1021.24976]
# step =  151 , output of actor network =  [  993.461     527.82117 -1136.392  ]
# step =  152 , output of actor network =  [  797.91614   582.99316 -1200.1316 ]
# step =  153 , output of actor network =  [  267.33896   580.1062  -1335.1572 ]
# step =  154 , output of actor network =  [  -94.97736   662.39435 -1414.35   ]
# step =  155 , output of actor network =  [ -260.4002    799.03815 -1310.025  ]
# step =  156 , output of actor network =  [ -365.98618   862.20667 -1211.2393 ]
# step =  157 , output of actor network =  [ -477.0145   867.4854 -1138.449 ]
# step =  158 , output of actor network =  [ -532.5198   901.7539 -1070.2932]
# step =  159 , output of actor network =  [-402.93204  924.2825  -997.04285]
# step =  160 , output of actor network =  [-225.90262  932.82623 -919.2709 ]
# step =  161 , output of actor network =  [ -13.802702  967.2923   -815.1896  ]
# step =  162 , output of actor network =  [ 470.88376 1019.9151  -687.5186 ]
# step =  163 , output of actor network =  [1203.6272  928.8149 -585.9203]
# step =  164 , output of actor network =  [1753.1724  849.6712 -534.1039]
# step =  165 , output of actor network =  [2227.752   769.657  -482.8866]
# step =  166 , output of actor network =  [2625.5493   643.821   -458.19507]
# step =  167 , output of actor network =  [2781.9514   454.35583 -438.49347]
# step =  168 , output of actor network =  [2624.7139   286.00357 -431.0396 ]
# step =  169 , output of actor network =  [2234.2405   302.31213 -551.1636 ]
# step =  170 , output of actor network =  [1716.4039   370.86523 -785.48975]
# step =  171 , output of actor network =  [ 1207.32      472.51898 -1055.3146 ]
# step =  172 , output of actor network =  [  963.65405   534.22736 -1143.3486 ]
# step =  173 , output of actor network =  [  777.0049    587.44684 -1204.0002 ]
# step =  174 , output of actor network =  [  181.62231   580.542   -1350.0918 ]
# step =  175 , output of actor network =  [ -109.40219   676.67773 -1415.1638 ]
# step =  176 , output of actor network =  [ -284.1066    812.99774 -1309.9152 ]
# step =  177 , output of actor network =  [ -405.33807   866.7494  -1217.7397 ]
# step =  178 , output of actor network =  [ -509.07245   878.2232  -1143.4963 ]
# step =  179 , output of actor network =  [ -496.6782    914.91437 -1064.588  ]
# step =  180 , output of actor network =  [-351.7618   934.9423  -988.66724]
# step =  181 , output of actor network =  [-163.37314  956.97626 -901.0909 ]
# step =  182 , output of actor network =  [ 121.32251  982.7164  -791.32294]
# step =  183 , output of actor network =  [ 920.5858  1037.6958  -672.74634]
# step =  184 , output of actor network =  [1557.628    904.93097 -614.1343 ]
# step =  185 , output of actor network =  [2055.686   838.8461 -549.8679]
# step =  186 , output of actor network =  [2510.9417   723.03064 -501.64648]
# step =  187 , output of actor network =  [2778.139   545.1213 -467.4404]
# step =  188 , output of actor network =  [2696.8782   315.4022  -433.80984]
# step =  189 , output of actor network =  [2402.2754   289.39948 -486.4108 ]
# step =  190 , output of actor network =  [1903.4307   340.49277 -692.1095 ]
# step =  191 , output of actor network =  [1406.0931   434.38266 -956.0216 ]
# step =  192 , output of actor network =  [ 1043.3444   513.5608 -1118.199 ]
# step =  193 , output of actor network =  [  832.8503    571.79456 -1186.9236 ]
# step =  194 , output of actor network =  [  424.29498   575.17316 -1301.2352 ]
# step =  195 , output of actor network =  [  -62.225677   632.4522   -1404.5565  ]
# step =  196 , output of actor network =  [ -185.60635   768.84784 -1297.923  ]
# step =  197 , output of actor network =  [ -264.2753    849.61383 -1187.0518 ]
# step =  198 , output of actor network =  [ -369.5341    860.97235 -1107.5891 ]
# step =  199 , output of actor network =  [ -562.4963    873.21686 -1066.1112 ]
# Episode 1: reward: -1270.215, steps: 200
