# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Model
from keras.layers import concatenate, Dense, Input, Flatten
from keras.optimizers import *
import gym
from rl.agents import eventDDPGAgent
from rl.memory import SequentialMemory

# %%
# GymのPendulum環境を作成
env = gym.make("Pendulum-v0")

# 取りうる”打ち手”のアクション数と値の定義
nb_actions = 2
ACT_ID_TO_VALUE = {0: [-1], 1: [+1]}

# %%
def actor_net(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input)
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(3, activation="tanh")(x)
    actor = Model(inputs=action_input, outputs=x)
    return actor

def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

# %%
def agent(a_shape, s_shape):
    actor = actor_net(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = eventDDPGAgent(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        clip_com=0.01
    )
    return agent

# %%
#通信によるコストの強さを設定
l = 1
agent = agent((3,), env.observation_space.shape) #agent((actor output dim),(state_dim))
opt = 'adam'

if opt == 'adam':
    #adam optimizer
    agent.compile(Adam(lr=0.001, clipnorm=1., decay = 0), metrics=["mse"])
elif opt == 'adadelta':
    #adadelta optimizer
    agent.compile(Adadelta(), metrics=['mse'])
elif opt == 'adagrad':
    #adagrad optimizer
    agent.compile(Adagrad(), metrics=['mse'])
else:
    assert False

agent.fit(env, lam=l, nb_steps=1000000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
print('Finish Learning. We start test phase.')
#agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200)
# Out:
# Training for 1000000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 54s 5ms/step - reward: -6.4916
# 50 episodes - episode_reward: -1298.322 [-1777.435, -923.727] - loss: 2.488 - mean_squared_error: 4.975 - mean_q: -27.013
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -6.5419
# 50 episodes - episode_reward: -1308.374 [-1764.249, -841.687] - loss: 16.000 - mean_squared_error: 32.001 - mean_q: -75.433
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 54s 5ms/step - reward: -6.2671
# 50 episodes - episode_reward: -1253.428 [-1578.724, -802.090] - loss: 34.794 - mean_squared_error: 69.589 - mean_q: -115.040
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -6.3918
# 50 episodes - episode_reward: -1278.352 [-1733.361, -566.227] - loss: 57.033 - mean_squared_error: 114.066 - mean_q: -148.600
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -6.2179
# 50 episodes - episode_reward: -1243.581 [-1689.095, -818.876] - loss: 85.244 - mean_squared_error: 170.489 - mean_q: -178.221
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -6.1131
# 50 episodes - episode_reward: -1222.625 [-1724.174, -819.387] - loss: 109.904 - mean_squared_error: 219.807 - mean_q: -200.782
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -6.0773
# 50 episodes - episode_reward: -1215.465 [-1737.203, -742.276] - loss: 124.979 - mean_squared_error: 249.957 - mean_q: -208.928
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -5.3547
# 50 episodes - episode_reward: -1070.934 [-1685.074, -201.831] - loss: 139.313 - mean_squared_error: 278.625 - mean_q: -214.231
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.7828
# 50 episodes - episode_reward: -756.557 [-1699.583, -201.856] - loss: 138.329 - mean_squared_error: 276.657 - mean_q: -201.276
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -4.1288
# 50 episodes - episode_reward: -825.762 [-1751.275, -201.372] - loss: 106.113 - mean_squared_error: 212.225 - mean_q: -177.613
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -5.7091
# 50 episodes - episode_reward: -1141.818 [-1690.149, -703.182] - loss: 94.603 - mean_squared_error: 189.206 - mean_q: -165.550
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -4.7026
# 50 episodes - episode_reward: -940.523 [-1527.699, -425.611] - loss: 87.888 - mean_squared_error: 175.776 - mean_q: -153.214
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -4.7575
# 50 episodes - episode_reward: -951.500 [-1352.127, -676.998] - loss: 61.270 - mean_squared_error: 122.540 - mean_q: -130.057
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -5.4349
# 50 episodes - episode_reward: -1086.986 [-1464.464, -569.823] - loss: 54.072 - mean_squared_error: 108.145 - mean_q: -129.646
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -5.1110
# 50 episodes - episode_reward: -1022.192 [-1446.164, -637.408] - loss: 58.261 - mean_squared_error: 116.522 - mean_q: -138.278
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -5.7847
# 50 episodes - episode_reward: -1156.942 [-1473.895, -787.129] - loss: 59.326 - mean_squared_error: 118.652 - mean_q: -139.452
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -5.7935
# 50 episodes - episode_reward: -1158.692 [-1770.797, -793.468] - loss: 63.515 - mean_squared_error: 127.031 - mean_q: -138.205
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -6.0396
# 50 episodes - episode_reward: -1207.910 [-1445.368, -535.944] - loss: 71.221 - mean_squared_error: 142.441 - mean_q: -143.578
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -5.9148
# 50 episodes - episode_reward: -1182.968 [-1511.598, -738.357] - loss: 79.070 - mean_squared_error: 158.140 - mean_q: -139.341
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -5.7970
# 50 episodes - episode_reward: -1159.405 [-1426.112, -675.265] - loss: 76.846 - mean_squared_error: 153.692 - mean_q: -130.442
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -5.2892
# 50 episodes - episode_reward: -1057.835 [-1645.607, -671.711] - loss: 85.261 - mean_squared_error: 170.523 - mean_q: -115.213
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -5.1896
# 50 episodes - episode_reward: -1037.920 [-1545.975, -674.374] - loss: 89.957 - mean_squared_error: 179.913 - mean_q: -97.669
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -4.8419
# 50 episodes - episode_reward: -968.386 [-1338.974, -541.522] - loss: 107.220 - mean_squared_error: 214.440 - mean_q: -61.288
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -5.4106
# 50 episodes - episode_reward: -1082.126 [-1936.088, -592.006] - loss: 122.309 - mean_squared_error: 244.617 - mean_q: -16.061
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -5.4460
# 50 episodes - episode_reward: -1089.209 [-1935.852, -281.365] - loss: 140.672 - mean_squared_error: 281.343 - mean_q: 18.155
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -3.5451
# 50 episodes - episode_reward: -709.019 [-1740.769, -203.387] - loss: 158.404 - mean_squared_error: 316.807 - mean_q: 42.227
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -4.6338
# 50 episodes - episode_reward: -926.759 [-1304.398, -204.943] - loss: 163.994 - mean_squared_error: 327.988 - mean_q: 83.338
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -6.1108
# 50 episodes - episode_reward: -1222.152 [-1512.916, -897.442] - loss: 134.685 - mean_squared_error: 269.371 - mean_q: 88.152
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -6.4068
# 50 episodes - episode_reward: -1281.369 [-1931.715, -967.284] - loss: 106.070 - mean_squared_error: 212.141 - mean_q: 80.108
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -6.3070
# 50 episodes - episode_reward: -1261.408 [-1410.327, -983.515] - loss: 88.807 - mean_squared_error: 177.614 - mean_q: 75.923
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -6.1465
# 50 episodes - episode_reward: -1229.297 [-1511.694, -936.315] - loss: 65.949 - mean_squared_error: 131.899 - mean_q: 63.735
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -5.9277
# 50 episodes - episode_reward: -1185.535 [-1563.758, -779.756] - loss: 44.294 - mean_squared_error: 88.589 - mean_q: 33.482
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -5.8113
# 50 episodes - episode_reward: -1162.267 [-1556.155, -830.494] - loss: 40.991 - mean_squared_error: 81.983 - mean_q: 7.606
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -5.0703
# 50 episodes - episode_reward: -1014.059 [-1449.516, -684.326] - loss: 34.972 - mean_squared_error: 69.945 - mean_q: -7.086
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -5.4649
# 50 episodes - episode_reward: -1092.981 [-1740.249, -397.632] - loss: 34.351 - mean_squared_error: 68.703 - mean_q: -28.119
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -6.1091
# 50 episodes - episode_reward: -1221.815 [-1698.160, -886.612] - loss: 36.081 - mean_squared_error: 72.162 - mean_q: -47.714
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -6.1388
# 50 episodes - episode_reward: -1227.752 [-1709.191, -651.591] - loss: 42.416 - mean_squared_error: 84.831 - mean_q: -66.702
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -5.7853
# 50 episodes - episode_reward: -1157.057 [-1514.428, -773.478] - loss: 46.801 - mean_squared_error: 93.602 - mean_q: -77.406
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -5.6963
# 50 episodes - episode_reward: -1139.250 [-1424.970, -782.344] - loss: 49.275 - mean_squared_error: 98.549 - mean_q: -84.861
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -5.3745
# 50 episodes - episode_reward: -1074.902 [-1714.192, -812.262] - loss: 48.402 - mean_squared_error: 96.805 - mean_q: -85.101
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -5.9245
# 50 episodes - episode_reward: -1184.895 [-1418.147, -922.583] - loss: 43.283 - mean_squared_error: 86.567 - mean_q: -81.894
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -6.6650
# 50 episodes - episode_reward: -1333.008 [-1481.587, -1090.414] - loss: 36.181 - mean_squared_error: 72.363 - mean_q: -80.643
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -6.6042
# 50 episodes - episode_reward: -1320.836 [-1472.982, -937.520] - loss: 34.217 - mean_squared_error: 68.434 - mean_q: -82.995
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -6.6851
# 50 episodes - episode_reward: -1337.010 [-1460.967, -1013.797] - loss: 30.269 - mean_squared_error: 60.538 - mean_q: -83.524
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -6.5977
# 50 episodes - episode_reward: -1319.536 [-1491.416, -979.087] - loss: 29.871 - mean_squared_error: 59.742 - mean_q: -85.376
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -6.4479
# 50 episodes - episode_reward: -1289.572 [-1518.804, -722.350] - loss: 28.782 - mean_squared_error: 57.564 - mean_q: -86.270
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -6.3816
# 50 episodes - episode_reward: -1276.320 [-1492.637, -953.132] - loss: 27.906 - mean_squared_error: 55.813 - mean_q: -80.581
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -5.9394
# 50 episodes - episode_reward: -1187.884 [-1457.600, -791.643] - loss: 24.897 - mean_squared_error: 49.793 - mean_q: -72.391
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -6.2022
# 50 episodes - episode_reward: -1240.430 [-1748.474, -747.502] - loss: 27.236 - mean_squared_error: 54.471 - mean_q: -74.604
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -6.5972
# 50 episodes - episode_reward: -1319.442 [-1637.598, -924.453] - loss: 45.490 - mean_squared_error: 90.979 - mean_q: -95.962
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -5.8797
# 50 episodes - episode_reward: -1175.947 [-1629.320, -753.056] - loss: 63.847 - mean_squared_error: 127.694 - mean_q: -115.879
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.1803
# 50 episodes - episode_reward: -1236.066 [-1732.849, -881.071] - loss: 79.907 - mean_squared_error: 159.814 - mean_q: -130.704
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -6.5176
# 50 episodes - episode_reward: -1303.520 [-1746.595, -859.505] - loss: 95.840 - mean_squared_error: 191.680 - mean_q: -148.715
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.1590
# 50 episodes - episode_reward: -1231.795 [-1895.243, -847.308] - loss: 104.559 - mean_squared_error: 209.119 - mean_q: -159.185
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.2186
# 50 episodes - episode_reward: -1243.721 [-1740.259, -922.464] - loss: 96.711 - mean_squared_error: 193.421 - mean_q: -152.058
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -6.3972
# 50 episodes - episode_reward: -1279.437 [-1754.428, -884.457] - loss: 100.289 - mean_squared_error: 200.577 - mean_q: -151.491
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.5564
# 50 episodes - episode_reward: -1311.277 [-1739.041, -738.554] - loss: 106.685 - mean_squared_error: 213.369 - mean_q: -156.617
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.3798
# 50 episodes - episode_reward: -1275.955 [-1740.788, -932.406] - loss: 115.325 - mean_squared_error: 230.650 - mean_q: -149.897
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.0232
# 50 episodes - episode_reward: -1204.641 [-1769.186, -837.982] - loss: 118.607 - mean_squared_error: 237.215 - mean_q: -136.191
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.2920
# 50 episodes - episode_reward: -1258.401 [-1737.765, -751.212] - loss: 151.707 - mean_squared_error: 303.413 - mean_q: -122.603
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.1624
# 50 episodes - episode_reward: -1232.473 [-1936.286, -909.159] - loss: 157.907 - mean_squared_error: 315.814 - mean_q: -98.180
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.7324
# 50 episodes - episode_reward: -1346.486 [-1687.476, -1035.824] - loss: 205.356 - mean_squared_error: 410.711 - mean_q: -60.713
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -7.0609
# 50 episodes - episode_reward: -1412.172 [-1774.679, -1058.929] - loss: 251.390 - mean_squared_error: 502.780 - mean_q: -4.871
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -7.1767
# 50 episodes - episode_reward: -1435.337 [-1735.841, -1159.445] - loss: 354.689 - mean_squared_error: 709.377 - mean_q: 55.307
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.9923
# 50 episodes - episode_reward: -1398.456 [-1735.972, -1103.619] - loss: 489.377 - mean_squared_error: 978.754 - mean_q: 113.480
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.8292
# 50 episodes - episode_reward: -1365.832 [-1748.420, -956.878] - loss: 615.378 - mean_squared_error: 1230.756 - mean_q: 169.735
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -5.5966
# 50 episodes - episode_reward: -1119.323 [-1729.623, -745.774] - loss: 1027.969 - mean_squared_error: 2055.939 - mean_q: 271.296
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.5406
# 50 episodes - episode_reward: -1108.119 [-1608.146, -866.038] - loss: 1679.860 - mean_squared_error: 3359.720 - mean_q: 446.930
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.1840
# 50 episodes - episode_reward: -1036.804 [-1329.762, -719.219] - loss: 2646.708 - mean_squared_error: 5293.415 - mean_q: 661.866
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.0008
# 50 episodes - episode_reward: -1000.162 [-1508.028, -722.180] - loss: 3874.586 - mean_squared_error: 7749.172 - mean_q: 885.313
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.0788
# 50 episodes - episode_reward: -1015.763 [-1776.813, -652.032] - loss: 4627.388 - mean_squared_error: 9254.776 - mean_q: 1069.980
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.9535
# 50 episodes - episode_reward: -1190.697 [-1739.586, -550.544] - loss: 4597.898 - mean_squared_error: 9195.796 - mean_q: 1116.390
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -6.4594
# 50 episodes - episode_reward: -1291.878 [-1533.362, -965.836] - loss: 3952.599 - mean_squared_error: 7905.198 - mean_q: 1080.553
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.6834
# 50 episodes - episode_reward: -1336.682 [-1740.309, -904.714] - loss: 3650.808 - mean_squared_error: 7301.615 - mean_q: 1021.099
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.0546
# 50 episodes - episode_reward: -1210.927 [-1682.818, -306.649] - loss: 3467.182 - mean_squared_error: 6934.364 - mean_q: 971.619
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.3639
# 50 episodes - episode_reward: -1072.772 [-1735.772, -306.950] - loss: 3091.167 - mean_squared_error: 6182.335 - mean_q: 931.011
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -5.4158
# 50 episodes - episode_reward: -1083.154 [-1665.796, -294.773] - loss: 2531.910 - mean_squared_error: 5063.821 - mean_q: 870.383
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.0171
# 50 episodes - episode_reward: -1203.426 [-1452.567, -765.154] - loss: 2098.257 - mean_squared_error: 4196.515 - mean_q: 807.265
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.0351
# 50 episodes - episode_reward: -1207.019 [-1409.017, -900.052] - loss: 1755.376 - mean_squared_error: 3510.751 - mean_q: 745.223
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.0818
# 50 episodes - episode_reward: -1216.368 [-1388.936, -925.880] - loss: 1389.738 - mean_squared_error: 2779.476 - mean_q: 684.017
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.9394
# 50 episodes - episode_reward: -1187.885 [-1389.835, -840.451] - loss: 1152.655 - mean_squared_error: 2305.309 - mean_q: 603.878
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -6.2849
# 50 episodes - episode_reward: -1256.985 [-1692.327, -300.162] - loss: 800.543 - mean_squared_error: 1601.086 - mean_q: 514.817
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -5.8264
# 50 episodes - episode_reward: -1165.273 [-1559.764, -661.675] - loss: 650.452 - mean_squared_error: 1300.904 - mean_q: 438.275
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -3.7291
# 50 episodes - episode_reward: -745.814 [-1318.606, -202.949] - loss: 631.119 - mean_squared_error: 1262.239 - mean_q: 395.798
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.3044
# 50 episodes - episode_reward: -660.888 [-1268.635, -203.127] - loss: 657.803 - mean_squared_error: 1315.606 - mean_q: 383.291
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -3.0914
# 50 episodes - episode_reward: -618.283 [-1122.119, -313.224] - loss: 680.182 - mean_squared_error: 1360.363 - mean_q: 371.589
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -3.3306
# 50 episodes - episode_reward: -666.111 [-1654.158, -313.646] - loss: 651.647 - mean_squared_error: 1303.294 - mean_q: 373.469
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -5.0638
# 50 episodes - episode_reward: -1012.758 [-1628.092, -311.269] - loss: 658.010 - mean_squared_error: 1316.020 - mean_q: 382.628
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.3400
# 50 episodes - episode_reward: -1268.005 [-1491.168, -1049.603] - loss: 585.133 - mean_squared_error: 1170.267 - mean_q: 349.949
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.4265
# 50 episodes - episode_reward: -1285.292 [-1608.434, -932.193] - loss: 426.102 - mean_squared_error: 852.204 - mean_q: 300.087
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.7753
# 50 episodes - episode_reward: -1355.053 [-1930.995, -1101.984] - loss: 336.176 - mean_squared_error: 672.351 - mean_q: 249.295
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.6299
# 50 episodes - episode_reward: -1325.977 [-1705.404, -771.367] - loss: 243.876 - mean_squared_error: 487.752 - mean_q: 195.294
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.9352
# 50 episodes - episode_reward: -1187.034 [-1444.224, -664.863] - loss: 179.404 - mean_squared_error: 358.808 - mean_q: 150.812
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.3281
# 50 episodes - episode_reward: -1065.627 [-1210.148, -861.405] - loss: 142.278 - mean_squared_error: 284.555 - mean_q: 129.322
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -5.4308
# 50 episodes - episode_reward: -1086.151 [-1317.570, -929.259] - loss: 130.913 - mean_squared_error: 261.825 - mean_q: 119.703
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -5.6860
# 50 episodes - episode_reward: -1137.191 [-1338.003, -965.882] - loss: 148.531 - mean_squared_error: 297.062 - mean_q: 128.698
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.1535
# 50 episodes - episode_reward: -1230.705 [-1742.555, -864.793] - loss: 185.154 - mean_squared_error: 370.307 - mean_q: 148.812
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -6.2951
# 50 episodes - episode_reward: -1259.012 [-1612.205, -937.120] - loss: 203.021 - mean_squared_error: 406.043 - mean_q: 155.715
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -5.8769
# 50 episodes - episode_reward: -1175.386 [-1739.056, -890.700] - loss: 217.519 - mean_squared_error: 435.038 - mean_q: 149.688
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -6.0043
# done, took 5985.313 seconds
# Finish Learning. We start test phase.

# %%
#agent.fit(env, lam=l, nb_steps=50000, visualize=True, verbose=1, nb_max_episode_steps=200)
print('Finish Learning. We start test phase.')
agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Finish Learning. We start test phase.
# Testing for 5 episodes ...
# Episode 1: reward: -1082.827, steps: 200
# Episode 2: reward: -938.004, steps: 200
# Episode 3: reward: -1167.238, steps: 200
# Episode 4: reward: -1078.541, steps: 200
# Episode 5: reward: -1142.512, steps: 200

# %%
agent.fit(env, lam=l, nb_steps=10000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
#  5249/10000 [==============>...............] - ETA: 30s - reward: nandone, took 33.188 seconds

# %%
agent.save_weights('0.5free_model_verygood.h5')

# %% [markdown]
# $\lambda = 1$だと15万ステップ学習してもダメ
#
# $\lambda = 0.1$だと1万5千くらいから立ち始める。その時はたってからは毎回通信。

# %%
for i in range(11):
    l = i*0.2
    def agent(a_shape, s_shape):
        actor = actor_net(a_shape, s_shape)
        critic,  critic_action_input = critic_net(a_shape, s_shape)
        memory = SequentialMemory(limit = 50000, window_length = 1)
        agent = eventDDPGAgent(
            a_shape[0],
            actor,
            critic,
            critic_action_input,
            memory
        )
        return agent

    a = agent((3,), env.observation_space.shape)
    a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
    a.fit(env, lam=l, nb_steps=50000, visualize=1, verbose=1, nb_max_episode_steps=200)
    a.save_weights(f'learned_models/normal{l}.h5')
# Out:
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 152s 15ms/step - reward: -7.6021
# 50 episodes - episode_reward: -1520.418 [-1848.082, -926.173] - loss: 3.034 - mean_absolute_error: 0.515 - mean_q: -32.362
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6.1389
# 50 episodes - episode_reward: -1227.779 [-1853.759, -752.904] - loss: 19.983 - mean_absolute_error: 1.015 - mean_q: -85.907
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 168s 17ms/step - reward: -4.3081
# 50 episodes - episode_reward: -861.618 [-1656.482, -226.366] - loss: 39.277 - mean_absolute_error: 1.756 - mean_q: -112.669
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3.9846
# 50 episodes - episode_reward: -796.920 [-1477.454, -451.134] - loss: 53.780 - mean_absolute_error: 2.436 - mean_q: -125.479
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3.5808
# done, took 820.047 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 169s 17ms/step - reward: -6.9265
# 50 episodes - episode_reward: -1385.296 [-1793.580, -958.647] - loss: 2.422 - mean_absolute_error: 0.507 - mean_q: -30.773
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6.4775
# 50 episodes - episode_reward: -1295.506 [-1660.541, -771.035] - loss: 16.305 - mean_absolute_error: 0.975 - mean_q: -82.472
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.9276
# 50 episodes - episode_reward: -985.513 [-1277.214, -23.609] - loss: 35.243 - mean_absolute_error: 1.585 - mean_q: -118.089
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.3162
# 50 episodes - episode_reward: -863.241 [-1526.610, -22.312] - loss: 51.568 - mean_absolute_error: 2.012 - mean_q: -142.503
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 138s 14ms/step - reward: -3.0766
# done, took 806.960 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 94s 9ms/step - reward: -6.8396
# 50 episodes - episode_reward: -1367.927 [-1842.018, -802.512] - loss: 2.179 - mean_absolute_error: 0.448 - mean_q: -29.767
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: -5.8350
# 50 episodes - episode_reward: -1166.993 [-1545.299, -56.587] - loss: 16.105 - mean_absolute_error: 0.942 - mean_q: -79.090
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: -3.9622
# 50 episodes - episode_reward: -792.435 [-1470.038, -53.082] - loss: 32.951 - mean_absolute_error: 1.602 - mean_q: -108.587
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 80s 8ms/step - reward: -3.0114
# 50 episodes - episode_reward: -602.277 [-1331.238, -56.860] - loss: 45.169 - mean_absolute_error: 2.113 - mean_q: -119.309
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 148s 15ms/step - reward: -3.2255
# done, took 489.464 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 170s 17ms/step - reward: -6.6729
# 50 episodes - episode_reward: -1334.571 [-1830.241, -734.704] - loss: 1.943 - mean_absolute_error: 0.504 - mean_q: -27.631
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -5.2680
# 50 episodes - episode_reward: -1053.591 [-1466.354, -527.913] - loss: 14.001 - mean_absolute_error: 1.028 - mean_q: -73.800
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -2.5724
# 50 episodes - episode_reward: -514.483 [-1350.451, -72.423] - loss: 26.681 - mean_absolute_error: 1.633 - mean_q: -93.336
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.6016
# 50 episodes - episode_reward: -920.329 [-1303.512, -301.871] - loss: 35.657 - mean_absolute_error: 2.171 - mean_q: -101.557
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 169s 17ms/step - reward: -4.7704
# done, took 838.365 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 170s 17ms/step - reward: -6.6949
# 50 episodes - episode_reward: -1338.972 [-1825.693, -865.638] - loss: 2.533 - mean_absolute_error: 0.558 - mean_q: -27.291
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6.2555
# 50 episodes - episode_reward: -1251.105 [-1730.692, -682.787] - loss: 14.034 - mean_absolute_error: 1.063 - mean_q: -75.143
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3.7248
# 50 episodes - episode_reward: -744.962 [-1567.315, -296.714] - loss: 33.162 - mean_absolute_error: 1.910 - mean_q: -105.035
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.5632
# 50 episodes - episode_reward: -912.637 [-1613.496, -120.750] - loss: 43.838 - mean_absolute_error: 2.551 - mean_q: -116.764
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -4.6130
# done, took 836.444 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 171s 17ms/step - reward: -7.2607
# 50 episodes - episode_reward: -1452.132 [-1896.382, -1014.270] - loss: 2.710 - mean_absolute_error: 0.561 - mean_q: -30.879
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 168s 17ms/step - reward: -6.1511
# 50 episodes - episode_reward: -1230.227 [-1741.070, -490.540] - loss: 16.476 - mean_absolute_error: 1.075 - mean_q: -80.265
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -5.0315
# 50 episodes - episode_reward: -1006.291 [-1652.869, -547.885] - loss: 34.289 - mean_absolute_error: 1.882 - mean_q: -112.503
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 143s 14ms/step - reward: -4.6580
# 50 episodes - episode_reward: -931.604 [-1689.278, -535.096] - loss: 51.408 - mean_absolute_error: 2.544 - mean_q: -129.796
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: -5.0606
# done, took 748.119 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: -6.8751
# 50 episodes - episode_reward: -1375.017 [-1869.416, -977.412] - loss: 3.003 - mean_absolute_error: 0.630 - mean_q: -29.523
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: -6.5544
# 50 episodes - episode_reward: -1310.890 [-1741.991, -807.589] - loss: 17.223 - mean_absolute_error: 1.081 - mean_q: -81.376
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: -5.7740
# 50 episodes - episode_reward: -1154.808 [-1598.778, -665.128] - loss: 39.847 - mean_absolute_error: 1.802 - mean_q: -121.463
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 98s 10ms/step - reward: -6.1639
# 50 episodes - episode_reward: -1232.789 [-1604.357, -962.908] - loss: 61.756 - mean_absolute_error: 2.466 - mean_q: -149.861
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: -6.2856
# done, took 489.033 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: -7.2125
# 50 episodes - episode_reward: -1442.499 [-1945.023, -737.797] - loss: 2.727 - mean_absolute_error: 0.628 - mean_q: -29.996
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: -6.4870
# 50 episodes - episode_reward: -1297.395 [-1766.722, -854.976] - loss: 18.239 - mean_absolute_error: 1.172 - mean_q: -82.044
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: -6.2200
# 50 episodes - episode_reward: -1244.000 [-1799.134, -804.532] - loss: 37.778 - mean_absolute_error: 1.847 - mean_q: -119.928
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: -5.5366
# 50 episodes - episode_reward: -1107.320 [-1343.298, -851.263] - loss: 57.968 - mean_absolute_error: 2.463 - mean_q: -145.937
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 105s 10ms/step - reward: -5.4941
# done, took 518.219 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 114s 11ms/step - reward: -7.1733
# 50 episodes - episode_reward: -1434.669 [-1958.030, -740.277] - loss: 3.324 - mean_absolute_error: 0.638 - mean_q: -31.406
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 149s 15ms/step - reward: -6.7973
# 50 episodes - episode_reward: -1359.464 [-1770.383, -1016.542] - loss: 20.893 - mean_absolute_error: 1.180 - mean_q: -85.954
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 148s 15ms/step - reward: -6.6217
# 50 episodes - episode_reward: -1324.330 [-1734.293, -777.904] - loss: 46.382 - mean_absolute_error: 1.749 - mean_q: -134.099
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 117s 12ms/step - reward: -6.1058
# 50 episodes - episode_reward: -1221.157 [-1689.485, -262.294] - loss: 69.329 - mean_absolute_error: 2.007 - mean_q: -162.902
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: -6.2247
# done, took 637.321 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 102s 10ms/step - reward: -7.1459
# 50 episodes - episode_reward: -1429.170 [-1913.444, -949.538] - loss: 2.232 - mean_absolute_error: 0.651 - mean_q: -29.575
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 133s 13ms/step - reward: -6.5019
# 50 episodes - episode_reward: -1300.373 [-1734.675, -644.505] - loss: 15.871 - mean_absolute_error: 1.145 - mean_q: -80.055
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 128s 13ms/step - reward: -5.6845
# 50 episodes - episode_reward: -1136.890 [-1644.355, -302.340] - loss: 36.972 - mean_absolute_error: 1.725 - mean_q: -119.976
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 122s 12ms/step - reward: -6.2013
# 50 episodes - episode_reward: -1240.256 [-1718.371, -523.167] - loss: 63.401 - mean_absolute_error: 2.175 - mean_q: -152.729
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 140s 14ms/step - reward: -5.4404
# done, took 624.828 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 170s 17ms/step - reward: -6.8628
# 50 episodes - episode_reward: -1372.568 [-1827.537, -954.353] - loss: 2.521 - mean_absolute_error: 0.707 - mean_q: -29.889
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -6.6865
# 50 episodes - episode_reward: -1337.309 [-1741.633, -768.716] - loss: 14.999 - mean_absolute_error: 1.117 - mean_q: -78.690
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 123s 12ms/step - reward: -5.8406
# 50 episodes - episode_reward: -1168.113 [-1659.201, -770.333] - loss: 39.343 - mean_absolute_error: 1.923 - mean_q: -118.606
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 124s 12ms/step - reward: -5.5608
# 50 episodes - episode_reward: -1112.152 [-1788.749, -612.351] - loss: 57.550 - mean_absolute_error: 2.469 - mean_q: -142.914
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -4.6330
# done, took 651.197 seconds

# %%
agent.fit(env, lam=l, nb_steps=150000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 150000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -1.5935
# 50 episodes - episode_reward: -318.692 [-727.146, -1.055] - loss: 30.884 - mean_squared_error: 61.767 - mean_q: -66.899
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -1.6722
# 50 episodes - episode_reward: -334.447 [-644.433, -0.792] - loss: 22.827 - mean_squared_error: 45.653 - mean_q: -39.455
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.0309
# 50 episodes - episode_reward: -406.185 [-1731.487, -0.861] - loss: 20.777 - mean_squared_error: 41.554 - mean_q: -27.843
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.3320
# 50 episodes - episode_reward: -466.399 [-1734.120, -1.240] - loss: 19.490 - mean_squared_error: 38.980 - mean_q: -20.356
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.4213
# 50 episodes - episode_reward: -484.259 [-1214.853, -2.351] - loss: 17.543 - mean_squared_error: 35.086 - mean_q: -18.006
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: -2.9297
# 50 episodes - episode_reward: -585.942 [-1327.066, -1.363] - loss: 18.398 - mean_squared_error: 36.797 - mean_q: -18.254
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -2.7039
# 50 episodes - episode_reward: -540.785 [-1430.529, -2.663] - loss: 13.138 - mean_squared_error: 26.276 - mean_q: -17.249
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.5461
# 50 episodes - episode_reward: -709.227 [-1706.684, -1.296] - loss: 14.086 - mean_squared_error: 28.172 - mean_q: -21.296
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 676s 68ms/step - reward: -2.7057
# 50 episodes - episode_reward: -541.134 [-1457.064, -0.427] - loss: 14.624 - mean_squared_error: 29.247 - mean_q: -25.297
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -3.0200
# 50 episodes - episode_reward: -603.997 [-1735.811, -1.230] - loss: 15.225 - mean_squared_error: 30.451 - mean_q: -26.373
#
# Interval 11 (100000 steps performed)
#  1046/10000 [==>...........................] - ETA: 1:13 - reward: -2.4960done, took 664.227 seconds

# %%
agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Testing for 5 episodes ...
# Episode 1: reward: -392.520, steps: 200
# Episode 2: reward: -400.598, steps: 200
# Episode 3: reward: -25.208, steps: 200
# Episode 4: reward: -505.319, steps: 200
# Episode 5: reward: -1006.071, steps: 200

# %%
np.clip(2,-1,1)
# Out:
# 1
