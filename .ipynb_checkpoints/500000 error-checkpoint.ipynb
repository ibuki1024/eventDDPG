# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Model
from keras.layers import concatenate, Dense, Input, Flatten
from keras.optimizers import *
import gym
from rl.agents import eventDDPGAgent
from rl.memory import SequentialMemory
# Out:
# Using TensorFlow backend.
# /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/pandas/compat/__init__.py:84: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# GymのPendulum環境を作成
env = gym.make("Pendulum-v0")

# 取りうる”打ち手”のアクション数と値の定義
nb_actions = 2
ACT_ID_TO_VALUE = {0: [-1], 1: [+1]}

# %%
def actor_net(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input)
    x = Dense(64, activation="relu")(x)
    x = Dense(64, activation="relu")(x)
    x = Dense(3, activation="linear")(x)
    actor = Model(inputs=action_input, outputs=x)
    return actor

def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(64, activation="relu")(x)
    x = Dense(64, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

# %%
def agent(a_shape, s_shape):
    actor = actor_net(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = eventDDPGAgent(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        clip_com=0.01
    )
    return agent

# %%
#通信によるコストの強さを設定
l = 1.
agent = agent((3,), env.observation_space.shape) #agent((actor output dim),(state_dim))
opt = 'adam'

if opt == 'adam':
    #adam optimizer
    agent.compile(Adam(lr=0.001, clipnorm=1., decay = 0), metrics=["mse"])
elif opt == 'adadelta':
    #adadelta optimizer
    agent.compile(Adadelta(), metrics=['mse'])
elif opt == 'adagrad':
    #adagrad optimizer
    agent.compile(Adagrad(), metrics=['mse'])
else:
    assert False

agent.fit(env, lam=l, nb_steps=1000000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
print('Finish Learning. We start test phase.')
#agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1012 22:08:36.348351 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1012 22:08:36.372925 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1012 22:08:36.394973 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4158: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1012 22:08:36.537600 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1012 22:08:36.538554 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1012 22:08:36.784991 140735584400256 deprecation_wrapper.py:119] From /Users/admin/.pyenv/versions/3.6.6/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Training for 1000000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 47s 5ms/step - reward: -6.7810
# 50 episodes - episode_reward: -1356.206 [-1865.798, -875.504] - loss: 2.071 - mean_squared_error: 4.143 - mean_q: -28.601
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 53s 5ms/step - reward: -6.7682
# 50 episodes - episode_reward: -1353.638 [-1706.877, -712.338] - loss: 14.791 - mean_squared_error: 29.582 - mean_q: -67.645
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 52s 5ms/step - reward: -6.6789
# 50 episodes - episode_reward: -1335.780 [-1706.028, -712.236] - loss: 31.998 - mean_squared_error: 63.995 - mean_q: -69.658
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 54s 5ms/step - reward: -7.2419
# 50 episodes - episode_reward: -1448.373 [-1682.203, -1064.841] - loss: 19.663 - mean_squared_error: 39.327 - mean_q: -62.180
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -7.9787
# 50 episodes - episode_reward: -1595.746 [-1863.502, -305.877] - loss: 67.649 - mean_squared_error: 135.298 - mean_q: -60.877
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -7.4169
# 50 episodes - episode_reward: -1483.376 [-1668.693, -1047.545] - loss: 98.631 - mean_squared_error: 197.262 - mean_q: -27.930
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.4010
# 50 episodes - episode_reward: -1480.195 [-1669.051, -961.865] - loss: 20.524 - mean_squared_error: 41.049 - mean_q: -76.972
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.2448
# 50 episodes - episode_reward: -1448.964 [-1671.036, -625.482] - loss: 52.037 - mean_squared_error: 104.074 - mean_q: -132.350
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.1986
# 50 episodes - episode_reward: -1439.723 [-1669.251, -842.077] - loss: 94.730 - mean_squared_error: 189.460 - mean_q: -179.101
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.8387
# 50 episodes - episode_reward: -1567.746 [-1865.045, -866.234] - loss: 160.188 - mean_squared_error: 320.376 - mean_q: -206.231
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.6651
# 50 episodes - episode_reward: -1533.020 [-1965.700, -1101.614] - loss: 240.347 - mean_squared_error: 480.693 - mean_q: -219.419
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.4200
# 50 episodes - episode_reward: -1483.991 [-1743.118, -892.129] - loss: 220.749 - mean_squared_error: 441.498 - mean_q: -234.122
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -7.6798
# 50 episodes - episode_reward: -1535.962 [-1996.876, -967.028] - loss: 204.623 - mean_squared_error: 409.246 - mean_q: -258.691
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -6.6233
# 50 episodes - episode_reward: -1324.654 [-1661.115, -789.045] - loss: 233.562 - mean_squared_error: 467.124 - mean_q: -285.013
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -6.7986
# 50 episodes - episode_reward: -1359.720 [-1533.800, -888.527] - loss: 234.512 - mean_squared_error: 469.024 - mean_q: -301.353
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -6.9328
# 50 episodes - episode_reward: -1386.566 [-1678.621, -968.260] - loss: 287.796 - mean_squared_error: 575.592 - mean_q: -317.588
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -7.0651
# 50 episodes - episode_reward: -1413.020 [-1702.900, -955.122] - loss: 379.388 - mean_squared_error: 758.776 - mean_q: -304.902
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.1739
# 50 episodes - episode_reward: -1434.771 [-1670.653, -1057.853] - loss: 284.970 - mean_squared_error: 569.940 - mean_q: -287.877
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -6.9940
# 50 episodes - episode_reward: -1398.807 [-1666.253, -505.289] - loss: 258.053 - mean_squared_error: 516.107 - mean_q: -255.029
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -7.0574
# 50 episodes - episode_reward: -1411.474 [-1667.060, -769.478] - loss: 206.302 - mean_squared_error: 412.604 - mean_q: -275.859
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.1916
# 50 episodes - episode_reward: -1438.327 [-1659.585, -762.318] - loss: 226.203 - mean_squared_error: 452.406 - mean_q: -299.307
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -7.2404
# 50 episodes - episode_reward: -1448.072 [-1805.158, -1034.612] - loss: 1135.433 - mean_squared_error: 2270.867 - mean_q: -278.629
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.2361
# 50 episodes - episode_reward: -1447.226 [-1856.311, -1043.932] - loss: 502.397 - mean_squared_error: 1004.793 - mean_q: -220.041
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.3587
# 50 episodes - episode_reward: -1471.730 [-1847.763, -1173.569] - loss: 257.611 - mean_squared_error: 515.222 - mean_q: -202.176
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.5993
# 50 episodes - episode_reward: -1519.867 [-1854.376, -658.567] - loss: 186.509 - mean_squared_error: 373.018 - mean_q: -205.038
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.6912
# 50 episodes - episode_reward: -1538.243 [-1829.446, -1088.170] - loss: 203.273 - mean_squared_error: 406.547 - mean_q: -210.078
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -8.0585
# 50 episodes - episode_reward: -1611.691 [-1865.266, -432.110] - loss: 8171343.000 - mean_squared_error: 16342686.000 - mean_q: 548.820
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -7.2454
# 50 episodes - episode_reward: -1449.084 [-1786.585, -1074.512] - loss: 683159682831364390912.000 - mean_squared_error: 1366319365662728781824.000 - mean_q: 2864365568.000
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -8.2266
# 50 episodes - episode_reward: -1645.328 [-1864.476, -1046.904] - loss: 2122305111439687706214400.000 - mean_squared_error: 4244610222879375412428800.000 - mean_q: 164232396800.000
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -8.2503
# 50 episodes - episode_reward: -1650.056 [-1862.858, -948.874] - loss: 54258727286203174401081344.000 - mean_squared_error: 108517454572406348802162688.000 - mean_q: 1427807010816.000
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -7.9920
# 50 episodes - episode_reward: -1598.397 [-1865.039, -1074.117] - loss: 453061073354902705369251840.000 - mean_squared_error: 906122146709805410738503680.000 - mean_q: 5939586924544.000
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -8.0871
# 50 episodes - episode_reward: -1617.416 [-1863.619, -938.866] - loss: 2040906443608499681398620160.000 - mean_squared_error: 4081812887216999362797240320.000 - mean_q: 17166262861824.000
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -8.3328
# 50 episodes - episode_reward: -1666.555 [-1865.207, -1157.642] - loss: 6461757500392452711373602816.000 - mean_squared_error: 12923515000784905422747205632.000 - mean_q: 39336636579840.000
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.3784
# 50 episodes - episode_reward: -1675.686 [-1862.582, -1166.506] - loss: 16231620085815024983377707008.000 - mean_squared_error: 32463240171630049966755414016.000 - mean_q: 79621294915584.000
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -8.3242
# 50 episodes - episode_reward: -1664.834 [-1863.189, -946.018] - loss: 35703803610038926426717028352.000 - mean_squared_error: 71407607220077852853434056704.000 - mean_q: 145184960544768.000
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.1601
# 50 episodes - episode_reward: -1632.029 [-1864.245, -927.277] - loss: 69858397116440602783919374336.000 - mean_squared_error: 139716794232881205567838748672.000 - mean_q: 238400649035776.000
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 55s 6ms/step - reward: -8.2692
# 50 episodes - episode_reward: -1653.831 [-1863.955, -1047.326] - loss: 124848036127514532301609369600.000 - mean_squared_error: 249696072255029064603218739200.000 - mean_q: 365996544098304.000
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -8.0623
# 50 episodes - episode_reward: -1612.465 [-1865.198, -940.336] - loss: 211301967155081439950952988672.000 - mean_squared_error: 422603934310162879901905977344.000 - mean_q: 528368822910976.000
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.2428
# 50 episodes - episode_reward: -1648.555 [-1865.088, -942.323] - loss: 330419335997769931871418843136.000 - mean_squared_error: 660838671995539863742837686272.000 - mean_q: 743828004798464.000
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.3045
# 50 episodes - episode_reward: -1660.894 [-1864.119, -1057.807] - loss: 471729768358159225130942726144.000 - mean_squared_error: 943459536716318450261885452288.000 - mean_q: 1023030943809536.000
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -8.4780
# 50 episodes - episode_reward: -1695.603 [-1865.779, -1255.874] - loss: 673636285164116602271953846272.000 - mean_squared_error: 1347272570328233204543907692544.000 - mean_q: 1344491864719360.000
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.0455
# 50 episodes - episode_reward: -1609.098 [-1863.566, -924.461] - loss: 951293376027421247313981472768.000 - mean_squared_error: 1902586752054842494627962945536.000 - mean_q: 1724261462966272.000
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -7.9886
# 50 episodes - episode_reward: -1597.730 [-1864.179, -932.920] - loss: 1326886605347799164599484284928.000 - mean_squared_error: 2653773210695598329198968569856.000 - mean_q: 2129243190329344.000
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.0628
# 50 episodes - episode_reward: -1612.569 [-1864.598, -1009.978] - loss: 1750193643358863540237967032320.000 - mean_squared_error: 3500387286717727080475934064640.000 - mean_q: 2597627359133696.000
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.1192
# 50 episodes - episode_reward: -1623.847 [-1864.878, -940.828] - loss: 2108390656808578121442418229248.000 - mean_squared_error: 4216781313617156242884836458496.000 - mean_q: 3185699381575680.000
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.1666
# 50 episodes - episode_reward: -1633.323 [-1863.712, -854.082] - loss: 2607066663886242034691489136640.000 - mean_squared_error: 5214133327772484069382978273280.000 - mean_q: 3877937514283008.000
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -8.4194
# 50 episodes - episode_reward: -1683.889 [-1865.935, -1111.510] - loss: 3197772300097797045693714530304.000 - mean_squared_error: 6395544600195594091387429060608.000 - mean_q: 4716741674401792.000
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -8.1507
# 50 episodes - episode_reward: -1630.133 [-1863.291, -1150.162] - loss: 4216203447075380450139326906368.000 - mean_squared_error: 8432406894150760900278653812736.000 - mean_q: 5633138445254656.000
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -7.8577
# 50 episodes - episode_reward: -1571.533 [-1863.609, -928.415] - loss: 5578373005815814922688551452672.000 - mean_squared_error: 11156746011631629845377102905344.000 - mean_q: 6605599571705856.000
#
# Interval 50 (490000 steps performed)
#  8387/10000 [========================>.....] - ETA: 9s - reward: -8.3349done, took 2883.550 seconds
# Finish Learning. We start test phase.

# %%
#agent.fit(env, lam=l, nb_steps=50000, visualize=True, verbose=1, nb_max_episode_steps=200)
print('Finish Learning. We start test phase.')
agent.test(env, lam=l, nb_episodes=5, visualize=1, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Finish Learning. We start test phase.
# Testing for 5 episodes ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a05d9a84b478> in <module>
#       1 #agent.fit(env, lam=l, nb_steps=50000, visualize=True, verbose=1, nb_max_episode_steps=200)
#       2 print('Finish Learning. We start test phase.')
# ----> 3 agent.test(env, lam=l, nb_episodes=5, visualize=1, nb_max_episode_steps=200, graph=True,action_view=0)
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/site-packages/rl/eventcore.py in test(self, env, nb_episodes, lam, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose, graph, action_view)
#     430                 if nb_max_episode_steps and episode_step >= nb_max_episode_steps - 1:
#     431                     done = True
# --> 432                 his.append([np.arcsin(observation[1]), np.clip(action, -self.max_torque, self.max_torque), gama])
#     433                 self.backward(reward, terminal=done)
#     434                 episode_reward += reward
#
# AttributeError: 'eventDDPGAgent' object has no attribute 'max_torque'

# %%
agent.fit(env, lam=l, nb_steps=10000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 54s 5ms/step - reward: -2.7868
# done, took 53.769 seconds

# %%
agent.save_weights('0.4free_model.h5')

# %% [markdown]
# $\lambda = 1$だと15万ステップ学習してもダメ
#
# $\lambda = 0.1$だと1万5千くらいから立ち始める。その時はたってからは毎回通信。

# %%
for i in range(11):
    l = i*0.2
    def agent(a_shape, s_shape):
        actor = actor_net(a_shape, s_shape)
        critic,  critic_action_input = critic_net(a_shape, s_shape)
        memory = SequentialMemory(limit = 50000, window_length = 1)
        agent = eventDDPGAgent(
            a_shape[0],
            actor,
            critic,
            critic_action_input,
            memory
        )
        return agent

    a = agent((3,), env.observation_space.shape)
    a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
    a.fit(env, lam=l, nb_steps=50000, visualize=1, verbose=1, nb_max_episode_steps=200)
    a.save_weights(f'learned_models/normal{l}.h5')
# Out:
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 152s 15ms/step - reward: -7.6021
# 50 episodes - episode_reward: -1520.418 [-1848.082, -926.173] - loss: 3.034 - mean_absolute_error: 0.515 - mean_q: -32.362
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6.1389
# 50 episodes - episode_reward: -1227.779 [-1853.759, -752.904] - loss: 19.983 - mean_absolute_error: 1.015 - mean_q: -85.907
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 168s 17ms/step - reward: -4.3081
# 50 episodes - episode_reward: -861.618 [-1656.482, -226.366] - loss: 39.277 - mean_absolute_error: 1.756 - mean_q: -112.669
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3.9846
# 50 episodes - episode_reward: -796.920 [-1477.454, -451.134] - loss: 53.780 - mean_absolute_error: 2.436 - mean_q: -125.479
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3.5808
# done, took 820.047 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 169s 17ms/step - reward: -6.9265
# 50 episodes - episode_reward: -1385.296 [-1793.580, -958.647] - loss: 2.422 - mean_absolute_error: 0.507 - mean_q: -30.773
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 140s 14ms/step - reward: -5.4404
# done, took 624.828 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 170s 17ms/step - reward: -6.8628
# 50 episodes - episode_reward: -1372.568 [-1827.537, -954.353] - loss: 2.521 - mean_absolute_error: 0.707 - mean_q: -29.889
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -6.6865
# 50 episodes - episode_reward: -1337.309 [-1741.633, -768.716] - loss: 14.999 - mean_absolute_error: 1.117 - mean_q: -78.690
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 123s 12ms/step - reward: -5.8406
# 50 episodes - episode_reward: -1168.113 [-1659.201, -770.333] - loss: 39.343 - mean_absolute_error: 1.923 - mean_q: -118.606
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 124s 12ms/step - reward: -5.5608
# 50 episodes - episode_reward: -1112.152 [-1788.749, -612.351] - loss: 57.550 - mean_absolute_error: 2.469 - mean_q: -142.914
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -4.6330
# done, took 651.197 seconds

# %%
agent.fit(env, lam=l, nb_steps=150000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 150000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -1.5935
# 50 episodes - episode_reward: -318.692 [-727.146, -1.055] - loss: 30.884 - mean_squared_error: 61.767 - mean_q: -66.899
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -1.6722
# 50 episodes - episode_reward: -334.447 [-644.433, -0.792] - loss: 22.827 - mean_squared_error: 45.653 - mean_q: -39.455
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.0309
# 50 episodes - episode_reward: -406.185 [-1731.487, -0.861] - loss: 20.777 - mean_squared_error: 41.554 - mean_q: -27.843
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.3320
# 50 episodes - episode_reward: -466.399 [-1734.120, -1.240] - loss: 19.490 - mean_squared_error: 38.980 - mean_q: -20.356
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.4213
# 50 episodes - episode_reward: -484.259 [-1214.853, -2.351] - loss: 17.543 - mean_squared_error: 35.086 - mean_q: -18.006
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: -2.9297
# 50 episodes - episode_reward: -585.942 [-1327.066, -1.363] - loss: 18.398 - mean_squared_error: 36.797 - mean_q: -18.254
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -2.7039
# 50 episodes - episode_reward: -540.785 [-1430.529, -2.663] - loss: 13.138 - mean_squared_error: 26.276 - mean_q: -17.249
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.5461
# 50 episodes - episode_reward: -709.227 [-1706.684, -1.296] - loss: 14.086 - mean_squared_error: 28.172 - mean_q: -21.296
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 676s 68ms/step - reward: -2.7057
# 50 episodes - episode_reward: -541.134 [-1457.064, -0.427] - loss: 14.624 - mean_squared_error: 29.247 - mean_q: -25.297
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -3.0200
# 50 episodes - episode_reward: -603.997 [-1735.811, -1.230] - loss: 15.225 - mean_squared_error: 30.451 - mean_q: -26.373
#
# Interval 11 (100000 steps performed)
#  1046/10000 [==>...........................] - ETA: 1:13 - reward: -2.4960done, took 664.227 seconds

# %%
agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Testing for 5 episodes ...
# Episode 1: reward: -1154.988, steps: 200
# Episode 2: reward: -1693.655, steps: 200
# Episode 3: reward: -1378.530, steps: 200
# Episode 4: reward: -1815.247, steps: 200
# Episode 5: reward: -1475.658, steps: 200

# %%
np.clip(2,-1,1)
# Out:
# 1
