# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../../module/')

from keras2.models import Model
from keras2.layers import concatenate, Dense, Input, Flatten
from keras2.optimizers import Adam
from util import *
import gym2
from rl2.agents import selfDDPGAgent, selfDDPGAgent2
from rl2.memory import SequentialMemory
# Out:
# Using TensorFlow backend.
# Using TensorFlow backend.

# %%
# GymのPendulum環境を作成
env = gym2.make("Pendulum-v2")

# 取りうる”打ち手”のアクション数と値の定義
nb_actios = 2
ACT_ID_TO_VALUE = {0: [-1], 1: [+1]}

# %%
def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

def branch_actor(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input) # 実質的なinput layer
    
    x1 = Dense(8, activation="relu")(x)
    x1 = Dense(8, activation="relu")(x1)
    x1 = Dense(1, activation="multiple_tanh")(x1) # action signal
    
    x2 = Dense(8, activation="relu")(x)
    x2 = Dense(8, activation="relu")(x2)
    x2 = Dense(1, activation="tau_output")(x2) # tau
    
    output = concatenate([x1, x2])
    actor = Model(inputs=action_input, outputs=output)
    return actor



def agent2(a_shape, s_shape):
    actor = branch_actor(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = selfDDPGAgent2(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        original_noise=True,
        action_clipper=[-10., 10.],
        tau_clipper=[0.001, 1.],
        batch_size=128,
    )
    return agent

# %%
#learning   
l = 5.
step = 200000  # num of interval
episode_step = step
a = agent2((2,), (2,))
actor_optimizer, critic_optimizer = Adam(lr=100., clipnorm=1.), Adam(lr=0.001, clipnorm=1.) # actorの方は何でもいい
optimizer = [actor_optimizer, critic_optimizer]
a.compile(optimizer=optimizer, metrics=["mae"], action_lr=0.001, tau_lr=0.0001)
a.actor.load_weights('../tmp.h5')
out = a.fit(env, l=l, nb_steps=step, visualize=0, verbose=1, nb_max_episode_steps=episode_step)
# Out:
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 217s 22ms/step - reward: -40.7149
# 3 episodes - episode_reward: -122351.860 [-183918.876, 91.165] - loss: 361829.679 - mean_absolute_error: 90.241 - mean_q: -538.648
#
# Interval 2 (10000 steps performed)
#    33/10000 [..............................] - ETA: 3:45 - reward: -9.7169done, took 217.490 seconds

# %% [markdown]
# ## 学習の内容を細かく確認し, conjectureの確からしさを検証する

# %% [markdown]
# #### 学習ログの確認

# %%
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
for i, em in enumerate(a.state_memory):
    if i>len(cycle):
        continue
    plt.scatter(em[0,0], em[0,1], marker='o', color=cycle[i])
    plt.scatter(em[-1,0], em[-1,1], marker='x', color=cycle[i])
    plt.plot(em[:,0], em[:,1], color=cycle[i], label=f'{i+1} th episode', alpha=0.5)
plt.xlabel('angle (rad)')
plt.ylabel('anglar velocity (rad/s)')
plt.title('state distribution of replay buffer')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.xlim(-10, 10)
plt.show()

# %% [markdown]
# #### 各エピソードの開始ステップのエージェントがそれぞれ同じ初期状態を出発した時の軌道の変化

# %%
steps = 0
compare_agents = []
for i, em in enumerate(a.state_memory):
    c = agent2((2,),(2,))
    set_NN_params(c.actor, a.params_log[steps])
    compare_agents.append(c)
    steps += em.shape[0]

# %%
env.reset()
initial_state = env.state
states = []
for ag in compare_agents:
    env.set_state(initial_state)
    episode_memory = []
    time_limit = 10
    # taus = []
    acc_time = 0
    while True:
        reward = 0
        x = env.state
        episode_memory.append(x)
        a_agent, tau = ag.forward(x)
        acc_time += tau
        action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
        dt = tau / action_repetition
        # print(tau, dt, action_repetition)
        for p in range(action_repetition):
            _,_,r,_ = env.step(np.array([a_agent]), dt, tau)
        if acc_time > time_limit:
            break
    states.append(np.array(episode_memory))

# %%
# compare path with same initial_state
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
for i, em in enumerate(states):
    plt.scatter(em[0,0], em[0,1], marker='o', color=cycle[i])
    plt.scatter(em[-1,0], em[-1,1], marker='x', color=cycle[i])
    plt.plot(em[:,0], em[:,1], color=cycle[i], label=f'{i+1} th episode', alpha=0.5)
plt.xlabel('angle (rad)')
plt.ylabel('anglar velocity (rad/s)')
plt.title('compare control performance of episode start agent')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.xlim(-2.5, 2.5)
plt.show()

# 2 th episodeの学習中にバグり始めた

# %% [markdown]
# #### どのように不安定化するのかをチェック

# %%
# 1581, 2460, 2500, 100033
# 2nd episode は 1581~2460

agents_second_episode_params = a.params_log[1581:2460]
agents_second_episode = []

for ag_params in agents_second_episode_params[:220][::22]: # 220ステップまでを55刻み
    c = agent2((2,),(2,))
    set_NN_params(c.actor, ag_params)
    agents_second_episode.append(c)

# %%
states = []
for ag in agents_second_episode:
    env.set_state(initial_state)
    episode_memory = []
    time_limit = 10
    acc_time = 0
    while True:
        reward = 0
        x = env.state
        episode_memory.append(x)
        a_agent, tau = ag.forward(x)
        acc_time += tau
        action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
        dt = tau / action_repetition
        # print(tau, dt, action_repetition)
        for p in range(action_repetition):
            _,_,r,_ = env.step(np.array([a_agent]), dt, tau)
        if acc_time > time_limit:
            break
    states.append(np.array(episode_memory))

# %%
# compare path with same initial_state
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
for i, em in enumerate(states):
    plt.scatter(em[0,0], em[0,1], marker='o', color=cycle[i])
    plt.scatter(em[-1,0], em[-1,1], marker='x', color=cycle[i])
    plt.plot(em[:,0], em[:,1], color=cycle[i], alpha=0.5, label=f'{i}')
plt.xlabel('angle (rad)')
plt.ylabel('anglar velocity (rad/s)')
plt.title('compare control performance of 2nd episode')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
#plt.xlim(-2.5, 2.5)
plt.show()

#132~154の間

# %% [markdown]
# 132~154ステップ目の間で不安定化した

# %%
agents_second_episode_params = a.params_log[1581:2460]
agents_second_episode = []

for ag_params in agents_second_episode_params[132:152][::2]: # 220ステップまでを55刻み
    c = agent2((2,),(2,))
    set_NN_params(c.actor, ag_params)
    agents_second_episode.append(c)

# %%
states = []
for ag in agents_second_episode:
    env.set_state(initial_state)
    episode_memory = []
    time_limit = 10
    acc_time = 0
    while True:
        reward = 0
        x = env.state
        episode_memory.append(x)
        a_agent, tau = ag.forward(x)
        acc_time += tau
        action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
        dt = tau / action_repetition
        # print(tau, dt, action_repetition)
        for p in range(action_repetition):
            _,_,r,_ = env.step(np.array([a_agent]), dt, tau)
        if acc_time > time_limit:
            break
    states.append(np.array(episode_memory))

# %%
# compare path with same initial_state
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
for i, em in enumerate(states):
    plt.scatter(em[0,0], em[0,1], marker='o', color=cycle[i])
    plt.scatter(em[-1,0], em[-1,1], marker='x', color=cycle[i])
    plt.plot(em[:,0], em[:,1], color=cycle[i], alpha=0.5, label=f'{i}')
plt.xlabel('angle (rad)')
plt.ylabel('anglar velocity (rad/s)')
plt.title('compare control performance of 2nd episode')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.xlim(-10, 2.5)
plt.show()

# %% [markdown]
# #### 132ステップ目と, 152ステップ目とではどのくらいの差が出るのか
# 152の方も, 初期状態によっては不安定化しないかも

# %%
print(initial_state)

iss = np.zeros((5,2))
for i in range(5):
    env.reset()
    iss[i] = env.state

ag1, ag2 = agent2((2,),(2,)), agent2((2,),(2,))
set_NN_params(ag1.actor, agents_second_episode_params[132])
set_NN_params(ag2.actor, agents_second_episode_params[152])
# Out:
# [-1.22769281 -0.11200919]

# %%
states = []
for ag in [ag1, ag2]:
    for _ in range(5):
        env.set_state(iss[_])
        episode_memory = []
        time_limit = 10
        # taus = []
        acc_time = 0
        while True:
            reward = 0
            x = env.state
            episode_memory.append(x)
            a_agent, tau = ag.forward(x)
            acc_time += tau
            action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
            dt = tau / action_repetition
            # print(tau, dt, action_repetition)
            for p in range(action_repetition):
                _,_,r,_ = env.step(np.array([a_agent]), dt, tau)
            if acc_time > time_limit:
                break
        states.append(np.array(episode_memory))

# %%
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']

for i in range(5):
    em1, em2 = states[i], states[5+i] #ag1, ag2
    plt.scatter(em1[0,0], em1[0,1], marker='o', color=cycle[0])
    plt.scatter(em1[-1,0], em1[-1,1], marker='x', color=cycle[0])
    if i < 4:
        plt.plot(em1[:,0], em1[:,1], color=cycle[0], alpha=0.3+0.1*i)
    else:
        plt.plot(em1[:,0], em1[:,1], color=cycle[0], alpha=0.3+0.1*i, label='132')
        
    plt.scatter(em2[0,0], em2[0,1], marker='o', color=cycle[1])
    plt.scatter(em2[-1,0], em2[-1,1], marker='x', color=cycle[1])
    if i < 4:
        plt.plot(em2[:,0], em2[:,1], color=cycle[1], alpha=0.3+0.1*i)
    else:
        plt.plot(em2[:,0], em2[:,1], color=cycle[1], alpha=0.3+0.1*i, label='152')
plt.xlabel('angle (rad)')
plt.ylabel('anglar velocity (rad/s)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.title('state distribution: young v.s. elder')
plt.show()

# %% [markdown]
# じわじわと不安定化に向かっている

# %%
dif = agents_second_episode_params[132] - agents_second_episode_params[152]
print(np.linalg.norm(dif)/dif.shape[0]) # 1パラメータあたりこれくらい
print(np.average(abs(agents_second_episode_params[132]))) # 方策パラメータの平均値
# Out:
# 0.001554613920219855
# 0.4035510213446936

# %% [markdown]
# #### 初期方策は初期状態にたいしてどのように制御するか

# %%
# 学習せずにインタラクションだけを繰り返す

states = []
for _ in range(10):
    env.reset()
    episode_memory = []
    time_limit = 10
    # taus = []
    acc_time = 0
    while True:
        reward = 0
        x = env.state
        episode_memory.append(x)
        a_agent, tau = a.forward(x)
        acc_time += tau
        action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
        dt = tau / action_repetition
        # print(tau, dt, action_repetition)
        for p in range(action_repetition):
            _,_,r,_ = env.step(np.array([a_agent]), dt, tau)
        if acc_time > time_limit:
            break
    states.append(np.array(episode_memory))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-85fe198a81bb> in <module>
#      12         x = env.state
#      13         episode_memory.append(x)
# ---> 14         a_agent, tau = a.forward(x)
#      15         acc_time += tau
#      16         action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
#
# ~/Documents/studyM2/projects/eventddpg/module/rl2/agents/selfddpg.py in forward(self, observation)
#     258         state = self.memory.get_recent_state(observation)
#     259         #TODO: change the law of selecting action
# --> 260         action = self.select_action(state)
#     261         #clip
#     262         action.clip(min=np.array([self.action_clipper[0], self.tau_clipper[0]]),\
#
# ~/Documents/studyM2/projects/eventddpg/module/rl2/agents/selfddpg.py in select_action(self, state)
#     242     def select_action(self, state):
#     243         batch = self.process_state_batch([state])
# --> 244         action = self.actor.predict_on_batch(batch).flatten()
#     245         if self.training and self.original_noise:
#     246             action = self._add_original_noise(action)
#
# ~/Documents/studyM2/projects/eventddpg/module/keras2/engine/training.py in predict_on_batch(self, x)
#    1272             ins = x
#    1273         self._make_predict_function()
# -> 1274         outputs = self.predict_function(ins)
#    1275         return unpack_singleton(outputs)
#    1276
#
# ~/Documents/studyM2/projects/eventddpg/module/keras2/backend/tensorflow_backend.py in __call__(self, inputs)
#    2723
#    2724             # のここ
# -> 2725             return self._call(inputs)
#    2726         else:
#    2727             if py_any(is_tensor(x) for x in inputs):
#
# ~/Documents/studyM2/projects/eventddpg/module/keras2/backend/tensorflow_backend.py in _call(self, inputs)
#    2642             raise TypeError('`inputs` should be a list or tuple.')
#    2643
# -> 2644         session = get_session()
#    2645         feed_arrays = []
#    2646         array_vals = []
#
# ~/Documents/studyM2/projects/eventddpg/module/keras2/backend/tensorflow_backend.py in get_session()
#     195         session = _SESSION
#     196     if not _MANUAL_VAR_INIT:
# --> 197         with session.graph.as_default():
#     198             variables = tf.global_variables()
#     199             candidate_vars = []
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    5649     try:
#    5650       with super(_DefaultGraphStack,
# -> 5651                  self).get_controller(default) as g, context.graph_mode():
#    5652         yield g
#    5653     finally:
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/contextlib.py in helper(*args, **kwds)
#     235             <cleanup>
#     236     """
# --> 237     @wraps(func)
#     238     def helper(*args, **kwds):
#     239         return _GeneratorContextManager(func, args, kwds)
#
# KeyboardInterrupt:

# %%
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
for i, em in enumerate(states):
    plt.scatter(em[0,0], em[0,1], marker='o', color=cycle[i])
    plt.scatter(em[-1,0], em[-1,1], marker='x', color=cycle[i])
    plt.plot(em[:,0], em[:,1], color=cycle[i])
    #plt.scatter(em[-1,0], em[-1,1], marker='x')
plt.xlabel('angle (rad)')
plt.ylabel('anglar velocity (rad/s)')
plt.title('state distribution of initial policy')
plt.show()

# %%
states = []
indices = np.array(range(45600,49999))
print(indices.shape)
for e in a.memory.sample(len(indices), batch_idxs=indices):
    states.append(e.state0[0])
states = np.array(states)
plt.scatter(states[:,0], states[:,1], color='blue', marker='.', label='most_recent')

states = []
indices = np.array(range(41200,45599))
print(indices.shape)
for e in a.memory.sample(len(indices), batch_idxs=indices):
    states.append(e.state0[0])
states = np.array(states)
plt.scatter(states[:,0], states[:,1], color='red', marker='.', label='short_time_ago')

plt.xlabel('angle (rad)')
plt.ylabel('anglar_velocity (rad/s)')
plt.legend()
plt.show()
# 急に+∞のmemoryが増えちゃった = ρπの破滅
# Out:
# (4399,)
# (4399,)

# %%
states = []
indices = np.array(range(1,9999))
print(indices.shape)
for e in a.memory.sample(len(indices), batch_idxs=indices):
    states.append(e.state0[0])
states = np.array(states)
plt.scatter(states[:,0], states[:,1], color='blue', marker='.', label='most_recent')
# Out:
# (9998,)

# %%
# %matplotlib inline
def rad_clip(th):
    r = abs(th)
    while r > np.pi:
        r -= 2 * np.pi
    th = np.sign(th) * r
    return th

l = 5.
env.reset()
env.set_state(np.array([-0.9, 0.1]))
states = []
time_limit = 10
time_log = []
taus = []
acc_time = 0
episode_reward = 0
while True:
    reward = 0
    x = env.state
    states.append([rad_clip(x[0]), x[1]])
    a_agent, tau = a.forward(x)
    taus.append(tau)
    acc_time += tau
    time_log.append(acc_time)
    action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
    dt = tau / action_repetition
    # print(tau, dt, action_repetition)
    for p in range(action_repetition):
        _,_,r,_ = env.step(np.array([a_agent]), dt, tau)
        reward += r
    reward *= dt
    reward += - 0.01 * a_agent**2 + l * tau
    episode_reward += reward
    if acc_time > time_limit:
        break
states = np.array(states)

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.xlabel('steps')
plt.ylabel('theta')
plt.plot(time_log, states[:,0])
plt.subplot(1,2,2)
plt.xlabel('steps')
plt.ylabel('theta_dot')
plt.plot(time_log, states[:,1])
plt.show()

# %%
plt.plot(taus)

# %%
plt.plot(out.history['episode_reward'])

# %%
plt.hist(grads, bins=100)
plt.show()

# %%
mem = a.memory.sample(50000)
states = []
actions = []
for m in mem:
    states.append(m.state0[0])
    actions.append(m.action)
states = np.array(states)
actions = np.array(actions)

# %%
actor = branch_actor((2,),(2,))

# %%
memory = []
l = 5.
for i in range(5000):
    env.reset()
    state0 = env.state
    a_agent, tau = actor.predict_on_batch(np.array([[state0]]))[0]
    memory.append([state0[0], state0[1], tau])
memory = np.array(memory)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)
ax.set_xlabel('theta')
ax.set_ylabel('theta_dot')
ax.set_zlabel('tau')
ax.set_zlim3d(0.001,1.0)

ax.scatter3D(memory[:,0], memory[:,1], memory[:,2], marker='.', alpha=0.4)

# %%
from util import make_standup_agent
actor = make_standup_agent(actor, 0.01, env, verbose=True)
# Out:
# WARNING:tensorflow:From ../../module/keras2/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# 30000/30000 [==============================] - 1s 34us/step - loss: 3.0028
# Epoch 2/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.1366
# Epoch 3/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0697
# Epoch 4/50
# 30000/30000 [==============================] - 0s 16us/step - loss: 0.0600: 0s - loss
# Epoch 5/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0565
# Epoch 6/50
# 30000/30000 [==============================] - 0s 16us/step - loss: 0.0543
# Epoch 7/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0520
# Epoch 8/50
# 30000/30000 [==============================] - 0s 16us/step - loss: 0.0500
# Epoch 9/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0480
# Epoch 10/50
# 30000/30000 [==============================] - 0s 17us/step - loss: 0.0468
# Epoch 11/50
# 30000/30000 [==============================] - 1s 20us/step - loss: 0.0454
# Epoch 12/50
# 30000/30000 [==============================] - 1s 18us/step - loss: 0.0443
# Epoch 13/50
# 30000/30000 [==============================] - 0s 17us/step - loss: 0.0438
# Epoch 14/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0428
# Epoch 15/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0424
# Epoch 16/50
# 30000/30000 [==============================] - 1s 19us/step - loss: 0.0417
# Epoch 17/50
# 30000/30000 [==============================] - 1s 21us/step - loss: 0.0413
# Epoch 18/50
# 30000/30000 [==============================] - 1s 21us/step - loss: 0.0412
# Epoch 19/50
# 30000/30000 [==============================] - 1s 21us/step - loss: 0.0406
# Epoch 20/50
# 30000/30000 [==============================] - 1s 20us/step - loss: 0.0404
# Epoch 21/50
# 30000/30000 [==============================] - 1s 24us/step - loss: 0.0402
# Epoch 22/50
# 30000/30000 [==============================] - 0s 16us/step - loss: 0.0399
# Epoch 23/50
# 30000/30000 [==============================] - 0s 16us/step - loss: 0.0397
# Epoch 24/50
# 30000/30000 [==============================] - 1s 19us/step - loss: 0.0397
# Epoch 25/50
# 30000/30000 [==============================] - 1s 20us/step - loss: 0.0398
# Epoch 26/50
# 30000/30000 [==============================] - 1s 22us/step - loss: 0.0393
# Epoch 27/50
# 30000/30000 [==============================] - 0s 17us/step - loss: 0.0391
# Epoch 28/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0390: 0s - loss:
# Epoch 29/50
# 30000/30000 [==============================] - 1s 18us/step - loss: 0.0389
# Epoch 30/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0389
# Epoch 31/50
# 30000/30000 [==============================] - 1s 19us/step - loss: 0.0388
# Epoch 32/50
# 30000/30000 [==============================] - 1s 19us/step - loss: 0.0388
# Epoch 33/50
# 30000/30000 [==============================] - 1s 20us/step - loss: 0.0385
# Epoch 34/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0384
# Epoch 35/50
# 30000/30000 [==============================] - 1s 19us/step - loss: 0.0385
# Epoch 36/50
# 30000/30000 [==============================] - 1s 21us/step - loss: 0.0384
# Epoch 37/50
# 30000/30000 [==============================] - 1s 22us/step - loss: 0.0382
# Epoch 38/50
# 30000/30000 [==============================] - 1s 23us/step - loss: 0.0385
# Epoch 39/50
# 30000/30000 [==============================] - 0s 17us/step - loss: 0.0383
# Epoch 40/50
# 30000/30000 [==============================] - 1s 22us/step - loss: 0.0381
# Epoch 41/50
# 30000/30000 [==============================] - 1s 21us/step - loss: 0.0383
# Epoch 42/50
# 30000/30000 [==============================] - 0s 16us/step - loss: 0.0379
# Epoch 43/50
# 30000/30000 [==============================] - 1s 17us/step - loss: 0.0380
# Epoch 44/50
# 30000/30000 [==============================] - 1s 20us/step - loss: 0.0382
# Epoch 45/50
# 30000/30000 [==============================] - 1s 23us/step - loss: 0.0379
# Epoch 46/50
# 30000/30000 [==============================] - 0s 16us/step - loss: 0.0381
# Epoch 47/50
# 30000/30000 [==============================] - 1s 22us/step - loss: 0.0381
# Epoch 48/50
# 30000/30000 [==============================] - 1s 18us/step - loss: 0.0380
# Epoch 49/50
# 30000/30000 [==============================] - 1s 19us/step - loss: 0.0379
# Epoch 50/50
# 30000/30000 [==============================] - 1s 18us/step - loss: 0.0380

# %%
memory = []
l = 5.
ma = np.array([50.,50.])
for i in range(5000):
    state0 = np.random.uniform(low=-ma, high=ma)
    a_agent, tau = a.actor.predict_on_batch(np.array([[state0]]))[0]
    memory.append([state0[0], state0[1], tau])
memory = np.array(memory)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)
ax.set_xlabel('theta')
ax.set_ylabel('theta_dot')
ax.set_zlabel('tau')
ax.set_zlim3d(0.001,1.0)

ax.scatter3D(memory[:,0], memory[:,1], memory[:,2], marker='.', alpha=0.4)

# %%
critic = critic_net((2,),(2,))[0]
critic.compile(Adam(lr=0.001, clipnorm=1.), loss='mean_squared_error')
epoch = 5000
gamma = 0.99
arr = np.array(range(a.memory.nb_entries))
losses = []
for _ in range(epoch):
    # make mini_batch
    mem = a.memory.sample(a.batch_size)
    state0_batch = []
    action_batch = []
    reward_batch = []
    state1_batch = []
    for m in mem:
        state0_batch.append(m[0])
        action_batch.append(m[1])
        reward_batch.append([m[2]])
        state1_batch.append(m[3])
    state0_batch, action_batch, reward_batch, state1_batch = \
    np.array(state0_batch), np.array(action_batch), np.array(reward_batch), np.array(state1_batch)

    # TD error
    next_action = a.actor.predict_on_batch(state1_batch)
    state1_batch_with_action = [next_action, state1_batch]
    r_second = gamma * critic.predict_on_batch(state1_batch_with_action)
    r = reward_batch + r_second
    
    # learn
    critic_input_batch = [action_batch, state0_batch]
    loss = critic.train_on_batch(critic_input_batch, r)
    losses.append(loss)
plt.plot(losses)
plt.xlabel('epochs')
plt.ylabel('critic_loss')
plt.show()

# %%
b = agent2((2,), (2,))
actor_optimizer, critic_optimizer = Adam(lr=0.00001, clipnorm=1.), Adam(lr=0.001, clipnorm=1.)
optimizer = [actor_optimizer, critic_optimizer]
b.compile(optimizer=optimizer, metrics=["mae"], action_lr=0.0001, tau_lr=0.001)
b.actor = make_standup_agent(b.actor, .01, env, verbose=False)

# %%
high = np.pi*np.ones(2,)
for _ in range(10):
    x = np.random.uniform(low=-high, high=high)
    print(a.forward(x))
    print(b.forward(x))
    print()
# Out:
# [-9.999739    0.99985254]
# [7.5273170e+00 1.1540558e-03]
#
# [-9.9993334e+00  1.6408312e-03]
# [-9.9987640e+00  1.0019746e-03]
#
# [-9.996586   0.9999012]
# [-9.9658031e+00  1.3005352e-03]
#
# [-9.979913  0.992833]
# [-4.9645996   0.00899488]
#
# [-9.997153    0.98591346]
# [-9.9988823e+00  1.4370666e-03]
#
# [-9.986576   0.9879084]
# [8.350636e+00 7.411491e-03]
#
# [-9.990459   0.9998548]
# [-9.8650093e+00  1.0889925e-03]
#
# [-9.999501   0.9999189]
# [9.9987040e+00 1.0350916e-03]
#
# [-9.9999485   0.99451745]
# [9.9657211e+00 3.3374643e-03]
#
# [-9.999114   0.9999795]
# [9.9980927e+00 1.0244658e-03]

# %%
ap = NN_params(a.actor)
bp = NN_params(b.actor)
dif = bp - ap

# %%
b.actor = make_standup_agent(b.actor, 1., env, verbose=False)

# %%
high = np.pi*np.ones(2,)
for _ in range(10):
    x = np.random.uniform(low=-high, high=high)
    print(b.forward(x))

    print()
# Out:
# [9.999999  0.9999999]
#
# [10.  1.]
#
# [-9.955486   0.9999957]
#
# [-9.993748   0.9999999]
#
# [9.999975  0.9999995]
#
# [-8.448686    0.99998426]
#
# [-9.999074    0.99999976]
#
# [-9.894086  1.      ]
#
# [10.  1.]
#
# [10.          0.99999976]

# %%
b.original_noise
b.training

with b.training = True:
    x = np.random.uniform(low=-high, high=high)
    b.forward(x)
# Out:
#   File "<ipython-input-136-b0bb18ebf488>", line 4
#     with b.training = True:
#                     ^
# SyntaxError: invalid syntax
