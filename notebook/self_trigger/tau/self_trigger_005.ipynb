# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../../../module/')

import keras2
from keras2.models import Model
from keras2.layers import concatenate, Dense, Input, Flatten
from keras2.optimizers import Adam
from util import moving_average, dlqr, discretized_system, lqr
import gym2
from rl2.agents import selfDDPGAgent
from rl2.memory import SequentialMemory
# Out:
# Using TensorFlow backend.
# Using TensorFlow backend.

# %%
# GymのPendulum環境を作成
env = gym2.make("Pendulum-v2")
clip = 10.

# 取りうる”打ち手”のアクション数と値の定義
nb_actios = 2
ACT_ID_TO_VALUE = {0: [-1], 1: [+1]}

# %%
def actor_net(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input)
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(2, activation="self_trigger_output")(x)
    actor = Model(inputs=action_input, outputs=x)
    # actor.summary()
    # actor.set_weights(_actor_initial_weight(actor))
    return actor

def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

# %%
def agent(a_shape, s_shape):
    actor = actor_net(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = selfDDPGAgent(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        clip_com = 0.01
    )
    return agent

# %%
#safe learning
histories = []
for i in range(3):    
    l = .05
    step = 200000  # num of interval
    episode_step = step
    a = agent((2,), (2,))
    a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
    a.actor.load_weights('../saved_agent/self_trigger.h5')
    # a.load_weights('../learned_models_vol2/0.5standup-agent.h5')
    # a.load_weights('../../learned_models_stab/lqr_optimal_agent.h5')
    out = a.fit(env, l=l, nb_steps=step, visualize=0, verbose=1, nb_max_episode_steps=episode_step)
    histories.append(out)
    a.actor.save_weights(f'./../saved_agent/self_trigger_005_{i}.h5')
# Out:
# WARNING:tensorflow:From ../../../module/keras2/backend/tensorflow_backend.py:82: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From ../../../module/keras2/backend/tensorflow_backend.py:525: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From ../../../module/keras2/backend/tensorflow_backend.py:4146: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From ../../../module/keras2/backend/tensorflow_backend.py:182: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From ../../../module/keras2/backend/tensorflow_backend.py:189: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From ../../../module/keras2/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 103s 10ms/step - reward: -0.8859
# 1 episodes - episode_reward: -8858.647 [-8858.647, -8858.647] - loss: 0.013 - mean_absolute_error: 0.067 - mean_q: -18.889
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 120s 12ms/step - reward: -3.0459
# 1 episodes - episode_reward: -30458.502 [-30458.502, -30458.502] - loss: 3.263 - mean_absolute_error: 0.163 - mean_q: -85.499
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 119s 12ms/step - reward: -3.0896
# 1 episodes - episode_reward: -30896.229 [-30896.229, -30896.229] - loss: 4.919 - mean_absolute_error: 0.237 - mean_q: -145.385
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 148s 15ms/step - reward: -2.8231
# 1 episodes - episode_reward: -28231.409 [-28231.409, -28231.409] - loss: 11.854 - mean_absolute_error: 0.278 - mean_q: -160.761
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 156s 16ms/step - reward: -2.5110
# 1 episodes - episode_reward: -25109.925 [-25109.925, -25109.925] - loss: 8.730 - mean_absolute_error: 0.254 - mean_q: -147.216
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 144s 14ms/step - reward: -2.6541
# 1 episodes - episode_reward: -26541.478 [-26541.478, -26541.478] - loss: 15.434 - mean_absolute_error: 0.291 - mean_q: -172.675
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 142s 14ms/step - reward: -2.9014
# 1 episodes - episode_reward: -29014.231 [-29014.231, -29014.231] - loss: 19.968 - mean_absolute_error: 0.294 - mean_q: -172.637
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 140s 14ms/step - reward: -2.7101
# 1 episodes - episode_reward: -27100.564 [-27100.564, -27100.564] - loss: 10.576 - mean_absolute_error: 0.236 - mean_q: -153.335
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 138s 14ms/step - reward: -2.9047
# 1 episodes - episode_reward: -29047.399 [-29047.399, -29047.399] - loss: 13.642 - mean_absolute_error: 0.235 - mean_q: -143.979
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 165s 17ms/step - reward: -2.8124
# 1 episodes - episode_reward: -28123.532 [-28123.532, -28123.532] - loss: 8.654 - mean_absolute_error: 0.222 - mean_q: -153.481
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 141s 14ms/step - reward: -2.4304
# 1 episodes - episode_reward: -24304.366 [-24304.366, -24304.366] - loss: 8.218 - mean_absolute_error: 0.215 - mean_q: -157.163
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 142s 14ms/step - reward: -2.7353
# 1 episodes - episode_reward: -27353.275 [-27353.275, -27353.275] - loss: 9.444 - mean_absolute_error: 0.206 - mean_q: -178.998
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 144s 14ms/step - reward: -2.4484
# 1 episodes - episode_reward: -24484.232 [-24484.232, -24484.232] - loss: 17.566 - mean_absolute_error: 0.240 - mean_q: -185.708
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 155s 15ms/step - reward: -2.3544
# 1 episodes - episode_reward: -23543.668 [-23543.668, -23543.668] - loss: 15.894 - mean_absolute_error: 0.229 - mean_q: -189.903
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 150s 15ms/step - reward: -1.8769
# 1 episodes - episode_reward: -18769.457 [-18769.457, -18769.457] - loss: 20.013 - mean_absolute_error: 0.239 - mean_q: -189.974
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 153s 15ms/step - reward: -2.6393
# 1 episodes - episode_reward: -26392.912 [-26392.912, -26392.912] - loss: 20.974 - mean_absolute_error: 0.227 - mean_q: -195.382
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 153s 15ms/step - reward: -1.1290
# 1 episodes - episode_reward: -11289.890 [-11289.890, -11289.890] - loss: 22.581 - mean_absolute_error: 0.221 - mean_q: -195.299
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 154s 15ms/step - reward: -1.4888
# 1 episodes - episode_reward: -14887.796 [-14887.796, -14887.796] - loss: 18.537 - mean_absolute_error: 0.207 - mean_q: -177.208
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 140s 14ms/step - reward: -2.4575
# 1 episodes - episode_reward: -24574.862 [-24574.862, -24574.862] - loss: 21.154 - mean_absolute_error: 0.208 - mean_q: -170.212
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 142s 14ms/step - reward: -2.0661
# done, took 2850.891 seconds
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 124s 12ms/step - reward: -2.1848
# 1 episodes - episode_reward: -21847.806 [-21847.806, -21847.806] - loss: 0.090 - mean_absolute_error: 0.204 - mean_q: 64.214
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 115s 11ms/step - reward: -3.0775
# 1 episodes - episode_reward: -30775.447 [-30775.447, -30775.447] - loss: 8.988 - mean_absolute_error: 0.412 - mean_q: 136.170
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 97s 10ms/step - reward: -3.0541
# 1 episodes - episode_reward: -30541.270 [-30541.270, -30541.270] - loss: 5.832 - mean_absolute_error: 0.340 - mean_q: 127.350
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 100s 10ms/step - reward: -3.0661
# 1 episodes - episode_reward: -30660.793 [-30660.793, -30660.793] - loss: 4.802 - mean_absolute_error: 0.271 - mean_q: 98.282
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 104s 10ms/step - reward: -3.0785
# 1 episodes - episode_reward: -30785.063 [-30785.063, -30785.063] - loss: 1.589 - mean_absolute_error: 0.175 - mean_q: 66.333
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: -3.0780
# 1 episodes - episode_reward: -30779.730 [-30779.730, -30779.730] - loss: 0.396 - mean_absolute_error: 0.131 - mean_q: 35.963
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: -3.0523
# 1 episodes - episode_reward: -30523.151 [-30523.151, -30523.151] - loss: 0.079 - mean_absolute_error: 0.127 - mean_q: 5.055
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: -3.0524
# 1 episodes - episode_reward: -30523.892 [-30523.892, -30523.892] - loss: 0.363 - mean_absolute_error: 0.128 - mean_q: -22.659
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: -3.0325
# 1 episodes - episode_reward: -30325.490 [-30325.490, -30325.490] - loss: 1.241 - mean_absolute_error: 0.140 - mean_q: -49.411
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 105s 10ms/step - reward: -3.0611
# 1 episodes - episode_reward: -30610.552 [-30610.552, -30610.552] - loss: 3.818 - mean_absolute_error: 0.165 - mean_q: -73.368
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: -3.0634
# 1 episodes - episode_reward: -30634.371 [-30634.371, -30634.371] - loss: 2.999 - mean_absolute_error: 0.152 - mean_q: -95.924
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: -3.0779
# 1 episodes - episode_reward: -30779.072 [-30779.072, -30779.072] - loss: 8.227 - mean_absolute_error: 0.178 - mean_q: -115.928
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 105s 11ms/step - reward: -3.0583
# 1 episodes - episode_reward: -30583.448 [-30583.448, -30583.448] - loss: 7.582 - mean_absolute_error: 0.172 - mean_q: -134.603
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 105s 11ms/step - reward: -3.0602
# 1 episodes - episode_reward: -30601.615 [-30601.615, -30601.615] - loss: 9.024 - mean_absolute_error: 0.191 - mean_q: -151.196
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 105s 11ms/step - reward: -3.0819
# 1 episodes - episode_reward: -30819.167 [-30819.167, -30819.167] - loss: 14.540 - mean_absolute_error: 0.212 - mean_q: -167.177
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 108s 11ms/step - reward: -3.0763
# 1 episodes - episode_reward: -30763.305 [-30763.305, -30763.305] - loss: 19.631 - mean_absolute_error: 0.247 - mean_q: -180.662
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 105s 11ms/step - reward: -3.0762
# 1 episodes - episode_reward: -30762.057 [-30762.057, -30762.057] - loss: 13.898 - mean_absolute_error: 0.227 - mean_q: -193.949
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 104s 10ms/step - reward: -3.0609
# 1 episodes - episode_reward: -30609.260 [-30609.260, -30609.260] - loss: 18.164 - mean_absolute_error: 0.241 - mean_q: -204.439
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: -3.0573
# 1 episodes - episode_reward: -30573.028 [-30573.028, -30573.028] - loss: 25.128 - mean_absolute_error: 0.262 - mean_q: -214.188
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 106s 11ms/step - reward: -3.0874
# done, took 2128.693 seconds
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 93s 9ms/step - reward: -5.9253
# 3 episodes - episode_reward: -19744.481 [-31527.405, -5479.703] - loss: 687.961 - mean_absolute_error: 5.734 - mean_q: -39.958
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: -0.0702
# 1 episodes - episode_reward: -450.030 [-450.030, -450.030] - loss: 281.914 - mean_absolute_error: 3.063 - mean_q: -35.134
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 103s 10ms/step - reward: -0.4839
# 1 episodes - episode_reward: -2344.239 [-2344.239, -2344.239] - loss: 167.733 - mean_absolute_error: 1.894 - mean_q: -13.513
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 107s 11ms/step - reward: -2.1960
# 1 episodes - episode_reward: -23543.723 [-23543.723, -23543.723] - loss: 122.254 - mean_absolute_error: 1.441 - mean_q: 42.647
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 192s 19ms/step - reward: -1.6298
# 1 episodes - episode_reward: -15868.143 [-15868.143, -15868.143] - loss: 83.464 - mean_absolute_error: 1.167 - mean_q: 59.748
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 155s 15ms/step - reward: -1.7314
# 1 episodes - episode_reward: -18243.042 [-18243.042, -18243.042] - loss: 43.944 - mean_absolute_error: 0.756 - mean_q: 71.699
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 155s 16ms/step - reward: -1.2672
# 1 episodes - episode_reward: -12798.167 [-12798.167, -12798.167] - loss: 5.660 - mean_absolute_error: 0.368 - mean_q: 74.968
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 155s 15ms/step - reward: -1.1696
# 1 episodes - episode_reward: -11663.899 [-11663.899, -11663.899] - loss: 4.965 - mean_absolute_error: 0.497 - mean_q: 42.483
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 156s 16ms/step - reward: -1.6048
# 1 episodes - episode_reward: -12007.883 [-12007.883, -12007.883] - loss: 1.605 - mean_absolute_error: 0.433 - mean_q: 25.698
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 159s 16ms/step - reward: -3.0598
# 1 episodes - episode_reward: -30673.901 [-30673.901, -30673.901] - loss: 0.607 - mean_absolute_error: 0.311 - mean_q: 19.353
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 159s 16ms/step - reward: -3.0540
# 1 episodes - episode_reward: -30405.492 [-30405.492, -30405.492] - loss: 0.363 - mean_absolute_error: 0.303 - mean_q: 7.824
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 160s 16ms/step - reward: -3.0812
# 1 episodes - episode_reward: -30881.377 [-30881.377, -30881.377] - loss: 0.148 - mean_absolute_error: 0.267 - mean_q: -11.327
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 154s 15ms/step - reward: -3.0665
# 1 episodes - episode_reward: -30637.815 [-30637.815, -30637.815] - loss: 0.362 - mean_absolute_error: 0.239 - mean_q: -36.664
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 158s 16ms/step - reward: -3.0704
# 1 episodes - episode_reward: -30735.017 [-30735.017, -30735.017] - loss: 1.306 - mean_absolute_error: 0.200 - mean_q: -65.279
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 161s 16ms/step - reward: -3.0708
# 1 episodes - episode_reward: -30624.748 [-30624.748, -30624.748] - loss: 3.067 - mean_absolute_error: 0.211 - mean_q: -89.275
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 160s 16ms/step - reward: -3.0897
# 1 episodes - episode_reward: -30919.229 [-30919.229, -30919.229] - loss: 4.143 - mean_absolute_error: 0.198 - mean_q: -110.191
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 159s 16ms/step - reward: -3.0817
# 1 episodes - episode_reward: -30840.790 [-30840.790, -30840.790] - loss: 4.495 - mean_absolute_error: 0.196 - mean_q: -128.930
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 160s 16ms/step - reward: -3.0655
# 1 episodes - episode_reward: -30757.049 [-30757.049, -30757.049] - loss: 6.502 - mean_absolute_error: 0.203 - mean_q: -146.239
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 161s 16ms/step - reward: -3.0467
# 1 episodes - episode_reward: -30397.021 [-30397.021, -30397.021] - loss: 13.251 - mean_absolute_error: 0.219 - mean_q: -162.101
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 137s 14ms/step - reward: -3.0631
# done, took 2947.103 seconds

# %%
for history in histories:
    his = history.history
    n_episodes = len(his['episode_reward'])
    x_axis = range(n_episodes)
    print(n_episodes)
    plt.plot(x_axis, his['episode_average_tau'])
    plt.xlabel('episodes')
    plt.ylabel('average_tau')
    plt.show()
    plt.plot(x_axis, his['episode_reward'])
    plt.xlabel('episodes')
    plt.ylabel('episode_reward')
    plt.show()
# Out:
# 20
# 20
# 22

# %%
import csv
with open(f'./csv/005.csv', 'w') as f:
    writer = csv.writer(f)
    for history in histories:
        his = history.history
        writer.writerow(his['episode_average_tau'])
        writer.writerow(his['episode_reward'])

# %%
#safe learning
histories = []
for i in range(3):    
    l = .5
    step = 200000  # num of interval
    episode_step = step
    a = agent((2,), (2,))
    a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
    a.actor.load_weights('./saved_agent/self_trigger.h5')
    # a.load_weights('../learned_models_vol2/0.5standup-agent.h5')
    # a.load_weights('../../learned_models_stab/lqr_optimal_agent.h5')
    out = a.fit(env, l=l, nb_steps=step, visualize=0, verbose=1, nb_max_episode_steps=episode_step)
    histories.append(out)
    a.actor.save_weights(f'./saved_agent/self_trigger_05_{i}.h5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 1, 2)              0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2)                 0
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                48
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 354
# Trainable params: 354
# Non-trainable params: 0
# _________________________________________________________________
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -0.1333
# 1 episodes - episode_reward: -1332.598 [-1332.598, -1332.598] - loss: 0.005 - mean_absolute_error: 0.050 - mean_q: 5.441
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: -2.9838
# 1 episodes - episode_reward: -29838.059 [-29838.059, -29838.059] - loss: 0.384 - mean_absolute_error: 0.097 - mean_q: 34.742
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: -2.9427
# 1 episodes - episode_reward: -29427.397 [-29427.397, -29427.397] - loss: 2.389 - mean_absolute_error: 0.197 - mean_q: 68.427
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: -3.0542
# 1 episodes - episode_reward: -30542.282 [-30542.282, -30542.282] - loss: 1.886 - mean_absolute_error: 0.189 - mean_q: 59.038
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: -0.7555
# 1 episodes - episode_reward: -7554.800 [-7554.800, -7554.800] - loss: 0.824 - mean_absolute_error: 0.149 - mean_q: 36.563
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -3.0688
# 1 episodes - episode_reward: -30688.420 [-30688.420, -30688.420] - loss: 0.422 - mean_absolute_error: 0.216 - mean_q: 13.080
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: -3.0571
# 1 episodes - episode_reward: -30571.075 [-30571.075, -30571.075] - loss: 4.291 - mean_absolute_error: 1.743 - mean_q: -1.435
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: -3.0628
# 1 episodes - episode_reward: -30628.084 [-30628.084, -30628.084] - loss: 4.379 - mean_absolute_error: 1.818 - mean_q: -8.856
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: -3.0735
# 1 episodes - episode_reward: -30735.347 [-30735.347, -30735.347] - loss: 1.307 - mean_absolute_error: 0.562 - mean_q: -20.997
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 1.6177e-04
# 1 episodes - episode_reward: 1.612 [1.612, 1.612] - loss: 0.728 - mean_absolute_error: 0.098 - mean_q: -42.636
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: -1.9279
# 1 episodes - episode_reward: -19278.816 [-19278.816, -19278.816] - loss: 1.480 - mean_absolute_error: 0.129 - mean_q: -57.725
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: -0.0022
# 1 episodes - episode_reward: -22.230 [-22.230, -22.230] - loss: 2.022 - mean_absolute_error: 0.194 - mean_q: -63.444
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: -0.0065
# 1 episodes - episode_reward: -65.014 [-65.014, -65.014] - loss: 2.916 - mean_absolute_error: 0.150 - mean_q: -53.498
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: -2.9421
# 1 episodes - episode_reward: -29420.807 [-29420.807, -29420.807] - loss: 2.928 - mean_absolute_error: 0.125 - mean_q: -43.330
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: -3.0888
# 1 episodes - episode_reward: -30887.932 [-30887.932, -30887.932] - loss: 3.132 - mean_absolute_error: 0.127 - mean_q: -56.535
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: -3.0492
# 1 episodes - episode_reward: -30491.792 [-30491.792, -30491.792] - loss: 4.527 - mean_absolute_error: 0.159 - mean_q: -90.679
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: -0.6272
# 1 episodes - episode_reward: -6271.645 [-6271.645, -6271.645] - loss: 9.667 - mean_absolute_error: 0.206 - mean_q: -104.408
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: -3.0803
# 1 episodes - episode_reward: -30802.578 [-30802.578, -30802.578] - loss: 9.298 - mean_absolute_error: 0.233 - mean_q: -123.263
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: -3.0774
# 1 episodes - episode_reward: -30774.134 [-30774.134, -30774.134] - loss: 11.908 - mean_absolute_error: 0.294 - mean_q: -163.103
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: -0.1432
# done, took 1738.476 seconds

# %%
n_episodes = len(out.history['episode_reward'])
x_axis = range(n_episodes)
print(n_episodes)
plt.plot(x_axis, out.history['episode_average_tau'])
plt.show()
plt.plot(x_axis, out.history['episode_reward'])
plt.show()
# Out:
# 20

# %%
n_episodes = len(out.history['episode_average_tau'])
x_axis = range(n_episodes)
plt.plot(x_axis, out.history['episode_average_tau'])
plt.show()
plt.plot(x_axis, out.history['episode_reward'])
plt.show()

# %%
a.test(env, l=l, nb_max_episode_steps=episode_step, visualize=0)
# Out:
# Testing for 1 episodes ...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-16-9892b65296c1> in <module>
# ----> 1 a.test(env, l=l, nb_max_episode_steps=episode_step, visualize=0)
#
# ~/Documents/studyM2/projects/eventddpg/module/rl2/selfcore.py in test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose, l)
#     428                 reward *= dt  # make sum to integral
#     429                 reward += tau * 0.01 * action[0]**2 + l * tau  # add tau reward
# --> 430                 his.append([env.state[0], env.state[1], action, cbf, tau])
#     431                 if nb_max_episode_steps and episode_step >= nb_max_episode_steps - 1:
#     432                     done = True
#
# UnboundLocalError: local variable 'cbf' referenced before assignment

# %%
titles = ['theta(rad)', 'theta_dot(rad/s)', 'input(Nm)', 'cbf compensation', 'interval(s)'] 
history = a.data_log[0]
x_axis = range(history.shape[0])
plt.figure(figsize=(8,8))
plt.subplots_adjust(wspace=0.4, hspace=0.6)
for i in range(history.shape[1]):
    data = history[:,i]
    plt.subplot(history.shape[1],1,i+1)
    plt.title(titles[i])
    plt.plot(x_axis, data)
plt.show()

# %%
print(out.history['episode_reward'])
observation = np.array([1.65,1])
a.forward(observation)
# Out:
# [0.2545098288126665, 0.2529258853115166, 0.25112259682202187, 0.25301912382581254, 0.252364068340555, 0.45092301604120333, 0.2906436879077258, 2.0687690286856086, 2.708959010967242, 2.722884273142362, 2.7071587111365782, 2.6749177980192265, 2.6706366152152534, 2.6380343698641324, 2.651115618509404, 2.441861273527565, 2.41434140116133, 2.344908014481406]
# array([-9.999897,  0.011   ], dtype=float32)

# %%
def rad_clip(th):
    r = abs(th)
    while r > np.pi:
        r -= np.pi
    th = np.sign(th) * r
    return th

env.reset()
states = []
reward = 0
for i in range(500):
    x = env.state
    states.append([rad_clip(x[0]), x[1]])
    a_agent, tau = a.forward(x)
    action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
    dt = tau / action_repetition
    # print(tau, dt, action_repetition)
    for p in range(action_repetition):
        _,_,r,_ = env.step(np.array([a_agent]), dt, tau)
        reward += r
    reward += - 0.01 * a_agent**2 + l * tau
states = np.array(states)

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.xlabel('steps')
plt.ylabel('theta')
plt.plot(range(states.shape[0]), states[:,0])
plt.subplot(1,2,2)
plt.xlabel('steps')
plt.ylabel('theta_dot')
plt.plot(range(states.shape[0]), states[:,1])
plt.show()

# %%
_5output = out

# %%
_05output = out
