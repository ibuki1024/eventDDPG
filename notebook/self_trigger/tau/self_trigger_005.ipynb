# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../../../module/')

import keras2
from keras2.models import Model
from keras2.layers import concatenate, Dense, Input, Flatten
from keras2.optimizers import Adam
from util import moving_average, dlqr, discretized_system, lqr
import gym2
from rl2.agents import selfDDPGAgent
from rl2.memory import SequentialMemory
# Out:
# Using TensorFlow backend.
# Using TensorFlow backend.

# %%
# GymのPendulum環境を作成
env = gym2.make("Pendulum-v2")
clip = 10.

# 取りうる”打ち手”のアクション数と値の定義
nb_actios = 2
ACT_ID_TO_VALUE = {0: [-1], 1: [+1]}

# %%
def actor_net(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input)
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(2, activation="self_trigger_output")(x)
    actor = Model(inputs=action_input, outputs=x)
    # actor.summary()
    # actor.set_weights(_actor_initial_weight(actor))
    return actor

def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

# %%
def agent(a_shape, s_shape):
    actor = actor_net(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = selfDDPGAgent(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        clip_com = 0.01
    )
    return agent

# %%
#safe learning
histories = []
for i in range(3):    
    l = .05
    step = 200000  # num of interval
    episode_step = step
    a = agent((2,), (2,))
    a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
    a.actor.load_weights('../saved_agent/self_trigger.h5')
    # a.load_weights('../learned_models_vol2/0.5standup-agent.h5')
    # a.load_weights('../../learned_models_stab/lqr_optimal_agent.h5')
    out = a.fit(env, l=l, nb_steps=step, visualize=0, verbose=1, nb_max_episode_steps=episode_step)
    histories.append(out)
    a.actor.save_weights(f'./../saved_agent/self_trigger_005_{i}.h5')
# Out:
# WARNING:tensorflow:From /Users/takeuchi_ibuki/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
#   937/10000 [=>............................] - ETA: 4s - reward: 3.4963e-05WARNING:tensorflow:From /Users/takeuchi_ibuki/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 10000/10000 [==============================] - 48s 5ms/step - reward: -8.3886e-04
# 1 episodes - episode_reward: -8.444 [-8.444, -8.444] - loss: 0.000 - mean_absolute_error: 0.007 - mean_q: -0.220
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 52s 5ms/step - reward: -0.0078
# 1 episodes - episode_reward: -78.447 [-78.447, -78.447] - loss: 0.000 - mean_absolute_error: 0.012 - mean_q: -0.537
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 53s 5ms/step - reward: -0.7010
# 1 episodes - episode_reward: -7009.980 [-7009.980, -7009.980] - loss: 0.002 - mean_absolute_error: 0.023 - mean_q: -3.316
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 55s 5ms/step - reward: -3.0743
# 1 episodes - episode_reward: -30742.963 [-30742.963, -30742.963] - loss: 1.081 - mean_absolute_error: 0.083 - mean_q: -27.099
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -2.6459
# 1 episodes - episode_reward: -26459.481 [-26459.481, -26459.481] - loss: 3.274 - mean_absolute_error: 0.150 - mean_q: -67.432
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -2.9706
# 1 episodes - episode_reward: -29706.434 [-29706.434, -29706.434] - loss: 6.831 - mean_absolute_error: 0.234 - mean_q: -103.123
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -1.5000
# 1 episodes - episode_reward: -15000.208 [-15000.208, -15000.208] - loss: 13.428 - mean_absolute_error: 0.268 - mean_q: -144.742
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -2.0240
# 1 episodes - episode_reward: -20239.726 [-20239.726, -20239.726] - loss: 13.570 - mean_absolute_error: 0.303 - mean_q: -172.758
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.4392
# 1 episodes - episode_reward: -14391.608 [-14391.608, -14391.608] - loss: 18.280 - mean_absolute_error: 0.321 - mean_q: -185.383
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -1.9303
# 1 episodes - episode_reward: -19302.494 [-19302.494, -19302.494] - loss: 13.713 - mean_absolute_error: 0.268 - mean_q: -170.051
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.8092
# 1 episodes - episode_reward: -18092.194 [-18092.194, -18092.194] - loss: 21.121 - mean_absolute_error: 0.288 - mean_q: -160.301
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -0.5755
# 1 episodes - episode_reward: -5755.216 [-5755.216, -5755.216] - loss: 16.037 - mean_absolute_error: 0.275 - mean_q: -145.811
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.9091
# 1 episodes - episode_reward: -19091.282 [-19091.282, -19091.282] - loss: 10.865 - mean_absolute_error: 0.252 - mean_q: -135.486
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -3.0742
# 1 episodes - episode_reward: -30741.798 [-30741.798, -30741.798] - loss: 18.676 - mean_absolute_error: 0.268 - mean_q: -144.698
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.0244
# 1 episodes - episode_reward: -10244.518 [-10244.518, -10244.518] - loss: 20.409 - mean_absolute_error: 0.298 - mean_q: -162.656
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.8656
# 1 episodes - episode_reward: -18655.556 [-18655.556, -18655.556] - loss: 15.000 - mean_absolute_error: 0.243 - mean_q: -152.353
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.7985
# 1 episodes - episode_reward: -17984.847 [-17984.847, -17984.847] - loss: 11.895 - mean_absolute_error: 0.223 - mean_q: -158.431
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.2198
# 1 episodes - episode_reward: -12197.509 [-12197.509, -12197.509] - loss: 16.489 - mean_absolute_error: 0.301 - mean_q: -175.420
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -2.2138
# 1 episodes - episode_reward: -22138.492 [-22138.492, -22138.492] - loss: 16.974 - mean_absolute_error: 0.291 - mean_q: -165.613
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -2.5518
# done, took 1115.212 seconds
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 50s 5ms/step - reward: -10.2182
# 7 episodes - episode_reward: -14227.636 [-23616.343, 0.496] - loss: 0.428 - mean_absolute_error: 0.019 - mean_q: -0.256
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 54s 5ms/step - reward: -23.5943
# 11 episodes - episode_reward: -21566.259 [-26053.374, -17349.627] - loss: 7103.105 - mean_absolute_error: 22.065 - mean_q: -358.005
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 54s 5ms/step - reward: -2.9624
# 1 episodes - episode_reward: -30506.816 [-30506.816, -30506.816] - loss: 8651.219 - mean_absolute_error: 28.110 - mean_q: -963.500
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -1.1950
# 1 episodes - episode_reward: -11949.532 [-11949.532, -11949.532] - loss: 6000.942 - mean_absolute_error: 19.742 - mean_q: -1071.531
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.2217
# 1 episodes - episode_reward: -12235.991 [-12235.991, -12235.991] - loss: 4791.226 - mean_absolute_error: 14.967 - mean_q: -969.246
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -0.6691
# 1 episodes - episode_reward: -6876.011 [-6876.011, -6876.011] - loss: 3484.140 - mean_absolute_error: 13.768 - mean_q: -955.269
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -0.4670
# 1 episodes - episode_reward: -4020.192 [-4020.192, -4020.192] - loss: 578.305 - mean_absolute_error: 3.158 - mean_q: -856.264
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -1.0995
# 1 episodes - episode_reward: -11693.182 [-11693.182, -11693.182] - loss: 292.359 - mean_absolute_error: 2.098 - mean_q: -633.430
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -0.5754
# 1 episodes - episode_reward: -5892.873 [-5892.873, -5892.873] - loss: 199.085 - mean_absolute_error: 1.700 - mean_q: -429.450
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -0.0892
# 1 episodes - episode_reward: -55.071 [-55.071, -55.071] - loss: 139.546 - mean_absolute_error: 1.318 - mean_q: -286.131
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -1.1643
# 1 episodes - episode_reward: -10286.099 [-10286.099, -10286.099] - loss: 59.886 - mean_absolute_error: 0.994 - mean_q: -247.193
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -2.5700
# 1 episodes - episode_reward: -24295.455 [-24295.455, -24295.455] - loss: 64.037 - mean_absolute_error: 0.922 - mean_q: -221.740
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -2.7227
# 1 episodes - episode_reward: -30841.712 [-30841.712, -30841.712] - loss: 52.293 - mean_absolute_error: 0.970 - mean_q: -180.318
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -0.5960
# 1 episodes - episode_reward: -2471.001 [-2471.001, -2471.001] - loss: 24.053 - mean_absolute_error: 0.894 - mean_q: -167.909
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.0358
# 1 episodes - episode_reward: -30315.071 [-30315.071, -30315.071] - loss: 57.368 - mean_absolute_error: 1.053 - mean_q: -205.661
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.0579
# 1 episodes - episode_reward: -30497.578 [-30497.578, -30497.578] - loss: 62.607 - mean_absolute_error: 1.360 - mean_q: -209.224
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.0747
# 1 episodes - episode_reward: -30836.593 [-30836.593, -30836.593] - loss: 47.866 - mean_absolute_error: 1.476 - mean_q: -220.422
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.0452
# 1 episodes - episode_reward: -30462.804 [-30462.804, -30462.804] - loss: 64.391 - mean_absolute_error: 1.496 - mean_q: -226.286
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.0509
# 1 episodes - episode_reward: -30419.258 [-30419.258, -30419.258] - loss: 37.272 - mean_absolute_error: 1.375 - mean_q: -266.969
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.0825
# done, took 1132.463 seconds
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 50s 5ms/step - reward: -0.4993
# 1 episodes - episode_reward: -4993.032 [-4993.032, -4993.032] - loss: 0.237 - mean_absolute_error: 0.326 - mean_q: 7.192
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 56s 6ms/step - reward: -49.8617
# 16 episodes - episode_reward: -31069.784 [-31828.334, -25063.389] - loss: 364.040 - mean_absolute_error: 6.296 - mean_q: 6.230
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 55s 6ms/step - reward: -0.5694
# 2 episodes - episode_reward: -1380.555 [-1934.812, -826.297] - loss: 461.802 - mean_absolute_error: 5.577 - mean_q: 10.738
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -2.3515
# 1 episodes - episode_reward: -18126.623 [-18126.623, -18126.623] - loss: 454.195 - mean_absolute_error: 4.401 - mean_q: 113.892
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.0615
# 1 episodes - episode_reward: -30590.132 [-30590.132, -30590.132] - loss: 362.290 - mean_absolute_error: 3.754 - mean_q: 198.073
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0573
# 1 episodes - episode_reward: -30643.578 [-30643.578, -30643.578] - loss: 366.995 - mean_absolute_error: 3.373 - mean_q: 239.208
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0701
# 1 episodes - episode_reward: -30493.469 [-30493.469, -30493.469] - loss: 142.680 - mean_absolute_error: 2.168 - mean_q: 276.577
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.0839
# 1 episodes - episode_reward: -30934.541 [-30934.541, -30934.541] - loss: 21.306 - mean_absolute_error: 1.232 - mean_q: 291.125
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.0615
# 1 episodes - episode_reward: -30731.508 [-30731.508, -30731.508] - loss: 21.251 - mean_absolute_error: 1.143 - mean_q: 256.404
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0566
# 1 episodes - episode_reward: -30483.968 [-30483.968, -30483.968] - loss: 11.323 - mean_absolute_error: 0.980 - mean_q: 204.684
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0737
# 1 episodes - episode_reward: -30659.023 [-30659.023, -30659.023] - loss: 6.123 - mean_absolute_error: 0.828 - mean_q: 157.098
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -3.0768
# 1 episodes - episode_reward: -30824.137 [-30824.137, -30824.137] - loss: 3.793 - mean_absolute_error: 0.681 - mean_q: 112.954
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0674
# 1 episodes - episode_reward: -30703.730 [-30703.730, -30703.730] - loss: 0.965 - mean_absolute_error: 0.519 - mean_q: 73.025
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0556
# 1 episodes - episode_reward: -30639.460 [-30639.460, -30639.460] - loss: 0.269 - mean_absolute_error: 0.444 - mean_q: 36.970
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0524
# 1 episodes - episode_reward: -30462.408 [-30462.408, -30462.408] - loss: 0.301 - mean_absolute_error: 0.362 - mean_q: 4.136
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -3.0574
# 1 episodes - episode_reward: -30593.726 [-30593.726, -30593.726] - loss: 1.774 - mean_absolute_error: 0.330 - mean_q: -25.848
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0619
# 1 episodes - episode_reward: -30550.733 [-30550.733, -30550.733] - loss: 2.016 - mean_absolute_error: 0.295 - mean_q: -52.630
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -3.0555
# 1 episodes - episode_reward: -30695.472 [-30695.472, -30695.472] - loss: 5.276 - mean_absolute_error: 0.292 - mean_q: -77.101
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -3.0507
# 1 episodes - episode_reward: -30396.094 [-30396.094, -30396.094] - loss: 7.993 - mean_absolute_error: 0.294 - mean_q: -98.549
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.0713
# done, took 1178.520 seconds

# %%
for history in histories:
    his = history.history
    n_episodes = len(his['episode_reward'])
    x_axis = range(n_episodes)
    print(n_episodes)
    plt.plot(x_axis, his['episode_average_tau'])
    plt.xlabel('episodes')
    plt.ylabel('average_tau')
    plt.show()
    plt.plot(x_axis, his['episode_reward'])
    plt.xlabel('episodes')
    plt.ylabel('episode_reward')
    plt.show()
# Out:
# 20
# 36
# 36

# %%
import csv
with open(f'./csv/005.csv', 'w') as f:
    writer = csv.writer(f)
    for history in histories:
        his = history.history
        writer.writerow(his['episode_average_tau'])
        writer.writerow(his['episode_reward'])

# %%
#safe learning
histories = []
for i in range(3):    
    l = .5
    step = 200000  # num of interval
    episode_step = step
    a = agent((2,), (2,))
    a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
    a.actor.load_weights('./saved_agent/self_trigger.h5')
    # a.load_weights('../learned_models_vol2/0.5standup-agent.h5')
    # a.load_weights('../../learned_models_stab/lqr_optimal_agent.h5')
    out = a.fit(env, l=l, nb_steps=step, visualize=0, verbose=1, nb_max_episode_steps=episode_step)
    histories.append(out)
    a.actor.save_weights(f'./saved_agent/self_trigger_05_{i}.h5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 1, 2)              0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 2)                 0
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                48
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 354
# Trainable params: 354
# Non-trainable params: 0
# _________________________________________________________________
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -0.1333
# 1 episodes - episode_reward: -1332.598 [-1332.598, -1332.598] - loss: 0.005 - mean_absolute_error: 0.050 - mean_q: 5.441
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: -2.9838
# 1 episodes - episode_reward: -29838.059 [-29838.059, -29838.059] - loss: 0.384 - mean_absolute_error: 0.097 - mean_q: 34.742
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 81s 8ms/step - reward: -2.9427
# 1 episodes - episode_reward: -29427.397 [-29427.397, -29427.397] - loss: 2.389 - mean_absolute_error: 0.197 - mean_q: 68.427
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 83s 8ms/step - reward: -3.0542
# 1 episodes - episode_reward: -30542.282 [-30542.282, -30542.282] - loss: 1.886 - mean_absolute_error: 0.189 - mean_q: 59.038
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: -0.7555
# 1 episodes - episode_reward: -7554.800 [-7554.800, -7554.800] - loss: 0.824 - mean_absolute_error: 0.149 - mean_q: 36.563
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -3.0688
# 1 episodes - episode_reward: -30688.420 [-30688.420, -30688.420] - loss: 0.422 - mean_absolute_error: 0.216 - mean_q: 13.080
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 110s 11ms/step - reward: -3.0571
# 1 episodes - episode_reward: -30571.075 [-30571.075, -30571.075] - loss: 4.291 - mean_absolute_error: 1.743 - mean_q: -1.435
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: -3.0628
# 1 episodes - episode_reward: -30628.084 [-30628.084, -30628.084] - loss: 4.379 - mean_absolute_error: 1.818 - mean_q: -8.856
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 96s 10ms/step - reward: -3.0735
# 1 episodes - episode_reward: -30735.347 [-30735.347, -30735.347] - loss: 1.307 - mean_absolute_error: 0.562 - mean_q: -20.997
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 95s 9ms/step - reward: 1.6177e-04
# 1 episodes - episode_reward: 1.612 [1.612, 1.612] - loss: 0.728 - mean_absolute_error: 0.098 - mean_q: -42.636
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: -1.9279
# 1 episodes - episode_reward: -19278.816 [-19278.816, -19278.816] - loss: 1.480 - mean_absolute_error: 0.129 - mean_q: -57.725
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: -0.0022
# 1 episodes - episode_reward: -22.230 [-22.230, -22.230] - loss: 2.022 - mean_absolute_error: 0.194 - mean_q: -63.444
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: -0.0065
# 1 episodes - episode_reward: -65.014 [-65.014, -65.014] - loss: 2.916 - mean_absolute_error: 0.150 - mean_q: -53.498
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 91s 9ms/step - reward: -2.9421
# 1 episodes - episode_reward: -29420.807 [-29420.807, -29420.807] - loss: 2.928 - mean_absolute_error: 0.125 - mean_q: -43.330
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 88s 9ms/step - reward: -3.0888
# 1 episodes - episode_reward: -30887.932 [-30887.932, -30887.932] - loss: 3.132 - mean_absolute_error: 0.127 - mean_q: -56.535
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: -3.0492
# 1 episodes - episode_reward: -30491.792 [-30491.792, -30491.792] - loss: 4.527 - mean_absolute_error: 0.159 - mean_q: -90.679
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: -0.6272
# 1 episodes - episode_reward: -6271.645 [-6271.645, -6271.645] - loss: 9.667 - mean_absolute_error: 0.206 - mean_q: -104.408
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 89s 9ms/step - reward: -3.0803
# 1 episodes - episode_reward: -30802.578 [-30802.578, -30802.578] - loss: 9.298 - mean_absolute_error: 0.233 - mean_q: -123.263
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 86s 9ms/step - reward: -3.0774
# 1 episodes - episode_reward: -30774.134 [-30774.134, -30774.134] - loss: 11.908 - mean_absolute_error: 0.294 - mean_q: -163.103
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: -0.1432
# done, took 1738.476 seconds

# %%
n_episodes = len(out.history['episode_reward'])
x_axis = range(n_episodes)
print(n_episodes)
plt.plot(x_axis, out.history['episode_average_tau'])
plt.show()
plt.plot(x_axis, out.history['episode_reward'])
plt.show()
# Out:
# 20

# %%
n_episodes = len(out.history['episode_average_tau'])
x_axis = range(n_episodes)
plt.plot(x_axis, out.history['episode_average_tau'])
plt.show()
plt.plot(x_axis, out.history['episode_reward'])
plt.show()

# %%
a.test(env, l=l, nb_max_episode_steps=episode_step, visualize=0)
# Out:
# Testing for 1 episodes ...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-16-9892b65296c1> in <module>
# ----> 1 a.test(env, l=l, nb_max_episode_steps=episode_step, visualize=0)
#
# ~/Documents/studyM2/projects/eventddpg/module/rl2/selfcore.py in test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose, l)
#     428                 reward *= dt  # make sum to integral
#     429                 reward += tau * 0.01 * action[0]**2 + l * tau  # add tau reward
# --> 430                 his.append([env.state[0], env.state[1], action, cbf, tau])
#     431                 if nb_max_episode_steps and episode_step >= nb_max_episode_steps - 1:
#     432                     done = True
#
# UnboundLocalError: local variable 'cbf' referenced before assignment

# %%
titles = ['theta(rad)', 'theta_dot(rad/s)', 'input(Nm)', 'cbf compensation', 'interval(s)'] 
history = a.data_log[0]
x_axis = range(history.shape[0])
plt.figure(figsize=(8,8))
plt.subplots_adjust(wspace=0.4, hspace=0.6)
for i in range(history.shape[1]):
    data = history[:,i]
    plt.subplot(history.shape[1],1,i+1)
    plt.title(titles[i])
    plt.plot(x_axis, data)
plt.show()

# %%
print(out.history['episode_reward'])
observation = np.array([1.65,1])
a.forward(observation)
# Out:
# [0.2545098288126665, 0.2529258853115166, 0.25112259682202187, 0.25301912382581254, 0.252364068340555, 0.45092301604120333, 0.2906436879077258, 2.0687690286856086, 2.708959010967242, 2.722884273142362, 2.7071587111365782, 2.6749177980192265, 2.6706366152152534, 2.6380343698641324, 2.651115618509404, 2.441861273527565, 2.41434140116133, 2.344908014481406]
# array([-9.999897,  0.011   ], dtype=float32)

# %%
def rad_clip(th):
    r = abs(th)
    while r > np.pi:
        r -= np.pi
    th = np.sign(th) * r
    return th

env.reset()
states = []
reward = 0
for i in range(500):
    x = env.state
    states.append([rad_clip(x[0]), x[1]])
    a_agent, tau = a.forward(x)
    action_repetition = int(np.ceil(200 * tau))  # minimum natural number which makes `dt` smaller than 0.005
    dt = tau / action_repetition
    # print(tau, dt, action_repetition)
    for p in range(action_repetition):
        _,_,r,_ = env.step(np.array([a_agent]), dt, tau)
        reward += r
    reward += - 0.01 * a_agent**2 + l * tau
states = np.array(states)

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.xlabel('steps')
plt.ylabel('theta')
plt.plot(range(states.shape[0]), states[:,0])
plt.subplot(1,2,2)
plt.xlabel('steps')
plt.ylabel('theta_dot')
plt.plot(range(states.shape[0]), states[:,1])
plt.show()

# %%
_5output = out

# %%
_05output = out
