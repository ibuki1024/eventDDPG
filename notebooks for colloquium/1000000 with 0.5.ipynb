# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Model
from keras.layers import concatenate, Dense, Input, Flatten
from keras.optimizers import *
import gym
from rl.agents import eventDDPGAgent
from rl.memory import SequentialMemory

# %%
# GymのPendulum環境を作成
env = gym.make("Pendulum-v0")

# 取りうる”打ち手”のアクション数と値の定義
nb_actions = 2
ACT_ID_TO_VALUE = {0: [-1], 1: [+1]}

# %%
def actor_net(a_shape, s_shape):
    action_input = Input(shape=(1,)+s_shape)
    x = Flatten()(action_input)
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(3, activation="tanh")(x)
    actor = Model(inputs=action_input, outputs=x)
    return actor

def critic_net(a_shape , s_shape):
    action_input = Input(a_shape)
    observation_input = Input(shape=(1,)+s_shape)
    flattened_observation = Flatten()(observation_input)
    x = concatenate([action_input, flattened_observation])
    x = Dense(16, activation="relu")(x)
    x = Dense(16, activation="relu")(x)
    x = Dense(1, activation="linear")(x)
    critic = Model(inputs=[action_input, observation_input], outputs=x)
    return (critic, action_input)

# %%
def agent(a_shape, s_shape):
    actor = actor_net(a_shape, s_shape)
    critic,  critic_action_input = critic_net(a_shape, s_shape)
    memory = SequentialMemory(limit = 50000, window_length = 1)
    agent = eventDDPGAgent(
        a_shape[0],
        actor,
        critic,
        critic_action_input,
        memory,
        clip_com=0.01
    )
    return agent

# %%
#通信によるコストの強さを設定
l = .5
agent = agent((3,), env.observation_space.shape) #agent((actor output dim),(state_dim))
opt = 'adam'

if opt == 'adam':
    #adam optimizer
    agent.compile(Adam(lr=0.001, clipnorm=1., decay = 0), metrics=["mse"])
elif opt == 'adadelta':
    #adadelta optimizer
    agent.compile(Adadelta(), metrics=['mse'])
elif opt == 'adagrad':
    #adagrad optimizer
    agent.compile(Adagrad(), metrics=['mse'])
else:
    assert False

agent.fit(env, lam=l, nb_steps=1000000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
print('Finish Learning. We start test phase.')
#agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200)
# Out:
# Training for 1000000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -7.0092
# 50 episodes - episode_reward: -1401.835 [-1861.289, -773.706] - loss: 3.045 - mean_squared_error: 6.089 - mean_q: -28.094
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -5.6029
# 50 episodes - episode_reward: -1120.586 [-1563.163, -160.258] - loss: 14.397 - mean_squared_error: 28.794 - mean_q: -74.581
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -2.4293
# 50 episodes - episode_reward: -485.858 [-1565.038, -53.924] - loss: 27.819 - mean_squared_error: 55.637 - mean_q: -98.325
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -4.1528
# 50 episodes - episode_reward: -830.560 [-1505.033, -97.738] - loss: 37.608 - mean_squared_error: 75.217 - mean_q: -111.856
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 58s 6ms/step - reward: -4.3284
# 50 episodes - episode_reward: -865.684 [-1507.273, -98.688] - loss: 52.551 - mean_squared_error: 105.102 - mean_q: -126.806
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -3.8958
# 50 episodes - episode_reward: -779.152 [-1373.573, -62.780] - loss: 54.592 - mean_squared_error: 109.184 - mean_q: -129.499
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.9971
# 50 episodes - episode_reward: -799.429 [-1667.605, -49.989] - loss: 54.154 - mean_squared_error: 108.308 - mean_q: -116.887
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.4088
# 50 episodes - episode_reward: -681.759 [-1703.496, -73.892] - loss: 51.956 - mean_squared_error: 103.912 - mean_q: -115.928
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.9162
# 50 episodes - episode_reward: -783.249 [-1670.009, -205.554] - loss: 57.213 - mean_squared_error: 114.427 - mean_q: -119.371
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -4.2611
# 50 episodes - episode_reward: -852.229 [-1705.693, -49.410] - loss: 62.762 - mean_squared_error: 125.524 - mean_q: -111.947
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -2.5039
# 50 episodes - episode_reward: -500.787 [-1660.088, -170.989] - loss: 60.081 - mean_squared_error: 120.162 - mean_q: -97.123
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -2.0528
# 50 episodes - episode_reward: -410.555 [-1131.057, -49.377] - loss: 45.364 - mean_squared_error: 90.728 - mean_q: -77.916
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.1705
# 50 episodes - episode_reward: -634.103 [-1383.029, -41.550] - loss: 35.593 - mean_squared_error: 71.186 - mean_q: -59.861
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -2.1780
# 50 episodes - episode_reward: -435.607 [-1323.916, -39.159] - loss: 28.654 - mean_squared_error: 57.309 - mean_q: -42.479
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.7356
# 50 episodes - episode_reward: -547.123 [-1192.940, -156.556] - loss: 24.077 - mean_squared_error: 48.153 - mean_q: -31.193
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -3.0732
# 50 episodes - episode_reward: -614.638 [-1723.516, -45.778] - loss: 19.933 - mean_squared_error: 39.865 - mean_q: -28.338
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -2.4938
# 50 episodes - episode_reward: -498.762 [-1285.446, -39.072] - loss: 21.439 - mean_squared_error: 42.878 - mean_q: -31.069
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -4.8216
# 50 episodes - episode_reward: -964.324 [-1722.030, -50.538] - loss: 23.314 - mean_squared_error: 46.628 - mean_q: -37.671
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -5.8144
# 50 episodes - episode_reward: -1162.875 [-1742.265, -751.282] - loss: 29.031 - mean_squared_error: 58.063 - mean_q: -57.138
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.5913
# 50 episodes - episode_reward: -1118.256 [-1712.183, -639.942] - loss: 39.085 - mean_squared_error: 78.171 - mean_q: -79.137
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.7667
# 50 episodes - episode_reward: -1153.330 [-1723.141, -649.696] - loss: 42.282 - mean_squared_error: 84.564 - mean_q: -95.266
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -5.7067
# 50 episodes - episode_reward: -1141.342 [-1735.501, -740.078] - loss: 58.233 - mean_squared_error: 116.467 - mean_q: -113.402
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.2995
# 50 episodes - episode_reward: -1059.909 [-1777.891, -287.951] - loss: 61.788 - mean_squared_error: 123.576 - mean_q: -122.709
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -5.4568
# 50 episodes - episode_reward: -1091.367 [-1657.773, -153.820] - loss: 62.745 - mean_squared_error: 125.490 - mean_q: -121.659
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -4.9128
# 50 episodes - episode_reward: -982.555 [-1710.144, -177.657] - loss: 53.537 - mean_squared_error: 107.075 - mean_q: -111.174
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.6415
# 50 episodes - episode_reward: -728.295 [-1697.481, -55.950] - loss: 55.704 - mean_squared_error: 111.408 - mean_q: -104.450
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.6843
# 50 episodes - episode_reward: -736.853 [-1707.139, -62.526] - loss: 45.162 - mean_squared_error: 90.324 - mean_q: -91.269
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -2.9099
# 50 episodes - episode_reward: -581.971 [-1656.727, -59.402] - loss: 39.490 - mean_squared_error: 78.980 - mean_q: -84.494
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 59s 6ms/step - reward: -3.4515
# 50 episodes - episode_reward: -690.292 [-1466.237, -178.825] - loss: 34.520 - mean_squared_error: 69.040 - mean_q: -72.559
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -2.5748
# 50 episodes - episode_reward: -514.964 [-1457.930, -70.813] - loss: 29.002 - mean_squared_error: 58.004 - mean_q: -64.249
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -3.8900
# 50 episodes - episode_reward: -778.007 [-1579.421, -52.756] - loss: 23.876 - mean_squared_error: 47.752 - mean_q: -57.982
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.4126
# 50 episodes - episode_reward: -1082.513 [-1755.929, -746.114] - loss: 25.583 - mean_squared_error: 51.166 - mean_q: -67.702
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -5.2585
# 50 episodes - episode_reward: -1051.699 [-1646.628, -760.256] - loss: 26.363 - mean_squared_error: 52.727 - mean_q: -74.142
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -5.3980
# 50 episodes - episode_reward: -1079.601 [-1653.135, -840.919] - loss: 29.734 - mean_squared_error: 59.469 - mean_q: -84.545
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -5.5719
# 50 episodes - episode_reward: -1114.371 [-1723.108, -823.019] - loss: 35.660 - mean_squared_error: 71.321 - mean_q: -96.215
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: -5.7327
# 50 episodes - episode_reward: -1146.548 [-1739.544, -613.856] - loss: 44.229 - mean_squared_error: 88.458 - mean_q: -113.299
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.9210
# 50 episodes - episode_reward: -1184.200 [-1698.272, -729.196] - loss: 47.225 - mean_squared_error: 94.450 - mean_q: -118.735
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -5.7927
# 50 episodes - episode_reward: -1158.540 [-1698.363, -683.363] - loss: 53.331 - mean_squared_error: 106.662 - mean_q: -125.458
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -5.6581
# 50 episodes - episode_reward: -1131.616 [-1598.909, -764.125] - loss: 62.136 - mean_squared_error: 124.272 - mean_q: -134.738
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -5.3130
# 50 episodes - episode_reward: -1062.604 [-1570.468, -649.225] - loss: 57.890 - mean_squared_error: 115.780 - mean_q: -136.784
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -4.8589
# 50 episodes - episode_reward: -971.774 [-1579.210, -659.001] - loss: 54.330 - mean_squared_error: 108.660 - mean_q: -132.907
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -4.8243
# 50 episodes - episode_reward: -964.853 [-1589.269, -638.725] - loss: 51.643 - mean_squared_error: 103.285 - mean_q: -134.025
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -4.7106
# 50 episodes - episode_reward: -942.112 [-1625.334, -524.740] - loss: 51.471 - mean_squared_error: 102.942 - mean_q: -133.725
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -4.6271
# 50 episodes - episode_reward: -925.420 [-1596.315, -439.300] - loss: 53.170 - mean_squared_error: 106.340 - mean_q: -125.375
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -4.9877
# 50 episodes - episode_reward: -997.544 [-1669.609, -571.602] - loss: 64.250 - mean_squared_error: 128.499 - mean_q: -119.224
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -5.5889
# 50 episodes - episode_reward: -1117.787 [-1644.035, -527.672] - loss: 74.227 - mean_squared_error: 148.454 - mean_q: -111.868
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.4589
# 50 episodes - episode_reward: -1091.774 [-1611.231, -515.837] - loss: 76.168 - mean_squared_error: 152.336 - mean_q: -99.465
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -4.2039
# 50 episodes - episode_reward: -840.790 [-1558.102, -501.115] - loss: 74.824 - mean_squared_error: 149.648 - mean_q: -83.980
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -4.6993
# 50 episodes - episode_reward: -939.853 [-1506.306, -629.094] - loss: 72.564 - mean_squared_error: 145.127 - mean_q: -64.968
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -4.9469
# 50 episodes - episode_reward: -989.373 [-1733.304, -517.639] - loss: 77.175 - mean_squared_error: 154.351 - mean_q: -46.197
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -4.6070
# 50 episodes - episode_reward: -921.403 [-1560.225, -421.739] - loss: 81.163 - mean_squared_error: 162.325 - mean_q: -22.169
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -5.1744
# 50 episodes - episode_reward: -1034.879 [-1383.774, -607.842] - loss: 86.563 - mean_squared_error: 173.126 - mean_q: 2.533
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -5.5289
# 50 episodes - episode_reward: -1105.778 [-1371.704, -660.889] - loss: 85.445 - mean_squared_error: 170.889 - mean_q: 25.611
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -5.8413
# 50 episodes - episode_reward: -1168.269 [-1353.987, -822.120] - loss: 80.340 - mean_squared_error: 160.681 - mean_q: 44.713
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: -5.7817
# 50 episodes - episode_reward: -1156.337 [-1360.202, -701.431] - loss: 92.160 - mean_squared_error: 184.319 - mean_q: 71.338
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -5.7192
# 50 episodes - episode_reward: -1143.836 [-1374.940, -910.221] - loss: 114.218 - mean_squared_error: 228.436 - mean_q: 103.233
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -6.4269
# 50 episodes - episode_reward: -1285.378 [-1506.803, -1020.367] - loss: 144.999 - mean_squared_error: 289.998 - mean_q: 128.981
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -6.1000
# 50 episodes - episode_reward: -1219.995 [-1723.522, -862.701] - loss: 186.188 - mean_squared_error: 372.376 - mean_q: 146.325
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -5.9304
# 50 episodes - episode_reward: -1186.083 [-1462.903, -841.281] - loss: 201.629 - mean_squared_error: 403.259 - mean_q: 160.851
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 75s 7ms/step - reward: -6.1220
# 50 episodes - episode_reward: -1224.408 [-1428.771, -897.230] - loss: 198.218 - mean_squared_error: 396.436 - mean_q: 164.001
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -6.1097
# 50 episodes - episode_reward: -1221.934 [-1393.176, -775.357] - loss: 187.230 - mean_squared_error: 374.460 - mean_q: 162.702
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -6.3352
# 50 episodes - episode_reward: -1267.036 [-1497.752, -841.889] - loss: 211.930 - mean_squared_error: 423.860 - mean_q: 178.409
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -6.4265
# 50 episodes - episode_reward: -1285.304 [-1736.088, -1037.249] - loss: 250.401 - mean_squared_error: 500.802 - mean_q: 203.251
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: -6.5623
# 50 episodes - episode_reward: -1312.452 [-1732.027, -928.367] - loss: 313.575 - mean_squared_error: 627.150 - mean_q: 225.107
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -6.4467
# 50 episodes - episode_reward: -1289.336 [-1732.481, -1009.432] - loss: 432.121 - mean_squared_error: 864.242 - mean_q: 254.638
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -6.5612
# 50 episodes - episode_reward: -1312.240 [-1719.241, -889.172] - loss: 581.324 - mean_squared_error: 1162.649 - mean_q: 287.650
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -6.5430
# 50 episodes - episode_reward: -1308.607 [-1731.230, -961.756] - loss: 742.985 - mean_squared_error: 1485.970 - mean_q: 330.153
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -5.8984
# 50 episodes - episode_reward: -1179.678 [-1726.426, -213.233] - loss: 951.428 - mean_squared_error: 1902.856 - mean_q: 392.093
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -4.2854
# 50 episodes - episode_reward: -857.072 [-1630.812, -61.563] - loss: 1481.075 - mean_squared_error: 2962.150 - mean_q: 493.857
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.1990
# 50 episodes - episode_reward: -1039.791 [-1764.779, -70.427] - loss: 1854.100 - mean_squared_error: 3708.200 - mean_q: 612.124
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 76s 8ms/step - reward: -5.4487
# 50 episodes - episode_reward: -1089.742 [-1706.744, -66.208] - loss: 2163.565 - mean_squared_error: 4327.130 - mean_q: 682.958
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 65s 6ms/step - reward: -5.6252
# 50 episodes - episode_reward: -1125.048 [-1663.737, -392.377] - loss: 2358.076 - mean_squared_error: 4716.151 - mean_q: 749.958
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -5.7862
# 50 episodes - episode_reward: -1157.243 [-1485.042, -389.761] - loss: 2387.190 - mean_squared_error: 4774.379 - mean_q: 806.541
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -5.6730
# 50 episodes - episode_reward: -1134.600 [-1682.790, -57.755] - loss: 2566.219 - mean_squared_error: 5132.439 - mean_q: 831.484
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -6.7792
# 50 episodes - episode_reward: -1355.842 [-1722.874, -1020.899] - loss: 2180.003 - mean_squared_error: 4360.005 - mean_q: 776.841
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -6.2994
# 50 episodes - episode_reward: -1259.884 [-1592.089, -955.807] - loss: 1996.740 - mean_squared_error: 3993.479 - mean_q: 752.149
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -5.2253
# 50 episodes - episode_reward: -1045.063 [-1711.371, -40.039] - loss: 1741.088 - mean_squared_error: 3482.177 - mean_q: 709.530
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -4.3515
# 50 episodes - episode_reward: -870.300 [-1587.493, -36.415] - loss: 1685.403 - mean_squared_error: 3370.805 - mean_q: 688.943
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -5.2011
# 50 episodes - episode_reward: -1040.212 [-1535.845, -37.046] - loss: 1544.856 - mean_squared_error: 3089.711 - mean_q: 674.533
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.2318
# 50 episodes - episode_reward: -1046.355 [-1660.737, -33.082] - loss: 1481.886 - mean_squared_error: 2963.773 - mean_q: 661.831
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -5.3171
# 50 episodes - episode_reward: -1063.420 [-1705.725, -30.014] - loss: 1295.381 - mean_squared_error: 2590.762 - mean_q: 628.717
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -5.4391
# 50 episodes - episode_reward: -1087.822 [-1644.010, -28.778] - loss: 1119.539 - mean_squared_error: 2239.079 - mean_q: 582.994
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -5.8354
# 50 episodes - episode_reward: -1167.085 [-1734.421, -124.831] - loss: 895.274 - mean_squared_error: 1790.548 - mean_q: 520.915
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -5.9800
# 50 episodes - episode_reward: -1196.003 [-1666.160, -264.519] - loss: 666.538 - mean_squared_error: 1333.076 - mean_q: 453.090
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -6.2413
# 50 episodes - episode_reward: -1248.255 [-1670.107, -632.842] - loss: 523.774 - mean_squared_error: 1047.547 - mean_q: 393.420
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -6.0623
# 50 episodes - episode_reward: -1212.453 [-1736.769, -746.985] - loss: 379.597 - mean_squared_error: 759.194 - mean_q: 326.561
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: -4.7494
# 50 episodes - episode_reward: -949.882 [-1711.246, -39.480] - loss: 259.460 - mean_squared_error: 518.920 - mean_q: 272.702
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -4.8601
# 50 episodes - episode_reward: -972.019 [-1709.312, -161.440] - loss: 224.795 - mean_squared_error: 449.591 - mean_q: 233.237
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -4.8243
# 50 episodes - episode_reward: -964.864 [-1516.470, -52.717] - loss: 181.901 - mean_squared_error: 363.803 - mean_q: 194.010
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -3.5213
# 50 episodes - episode_reward: -704.269 [-1266.952, -172.578] - loss: 146.659 - mean_squared_error: 293.319 - mean_q: 160.603
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -2.4678
# 50 episodes - episode_reward: -493.568 [-1247.841, -51.512] - loss: 132.799 - mean_squared_error: 265.599 - mean_q: 143.704
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -4.7330
# 50 episodes - episode_reward: -946.599 [-1738.381, -57.042] - loss: 115.444 - mean_squared_error: 230.888 - mean_q: 128.573
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -3.9472
# 50 episodes - episode_reward: -789.449 [-1738.273, -42.209] - loss: 87.537 - mean_squared_error: 175.075 - mean_q: 99.947
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 69s 7ms/step - reward: -3.9319
# 50 episodes - episode_reward: -786.381 [-1731.315, -36.359] - loss: 70.564 - mean_squared_error: 141.128 - mean_q: 74.135
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 73s 7ms/step - reward: -4.6458
# 50 episodes - episode_reward: -929.167 [-1666.049, -38.318] - loss: 59.935 - mean_squared_error: 119.869 - mean_q: 52.322
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -4.3699
# 50 episodes - episode_reward: -873.987 [-1712.165, -627.364] - loss: 49.437 - mean_squared_error: 98.874 - mean_q: 28.540
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -4.2760
# 50 episodes - episode_reward: -855.205 [-1658.188, -521.940] - loss: 39.839 - mean_squared_error: 79.677 - mean_q: 10.007
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 72s 7ms/step - reward: -2.9207
# 50 episodes - episode_reward: -584.137 [-1463.321, -101.239] - loss: 39.937 - mean_squared_error: 79.874 - mean_q: 7.141
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -2.5201
# 50 episodes - episode_reward: -504.019 [-1712.820, -64.749] - loss: 38.789 - mean_squared_error: 77.578 - mean_q: 12.361
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 71s 7ms/step - reward: -2.7158
# done, took 6767.440 seconds
# Finish Learning. We start test phase.

# %%
#agent.fit(env, lam=l, nb_steps=50000, visualize=True, verbose=1, nb_max_episode_steps=200)
print('Finish Learning. We start test phase.')
agent.test(env, lam=l, nb_episodes=5, visualize=1, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Finish Learning. We start test phase.
# Testing for 5 episodes ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-a05d9a84b478> in <module>
#       1 #agent.fit(env, lam=l, nb_steps=50000, visualize=True, verbose=1, nb_max_episode_steps=200)
#       2 print('Finish Learning. We start test phase.')
# ----> 3 agent.test(env, lam=l, nb_episodes=5, visualize=1, nb_max_episode_steps=200, graph=True,action_view=0)
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/site-packages/rl/eventcore.py in test(self, env, nb_episodes, lam, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose, graph, action_view)
#     430                 if nb_max_episode_steps and episode_step >= nb_max_episode_steps - 1:
#     431                     done = True
# --> 432                 his.append([np.arcsin(observation[1]), np.clip(action, -self.max_torque, self.max_torque), gama])
#     433                 self.backward(reward, terminal=done)
#     434                 episode_reward += reward
#
# AttributeError: 'eventDDPGAgent' object has no attribute 'max_torque'

# %%
agent.fit(env, lam=l, nb_steps=10000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
#  5249/10000 [==============>...............] - ETA: 30s - reward: nandone, took 33.188 seconds

# %%
agent.save_weights('0.4free_model.h5')

# %% [markdown]
# $\lambda = 1$だと15万ステップ学習してもダメ
#
# $\lambda = 0.1$だと1万5千くらいから立ち始める。その時はたってからは毎回通信。

# %%
for i in range(11):
    l = i*0.2
    def agent(a_shape, s_shape):
        actor = actor_net(a_shape, s_shape)
        critic,  critic_action_input = critic_net(a_shape, s_shape)
        memory = SequentialMemory(limit = 50000, window_length = 1)
        agent = eventDDPGAgent(
            a_shape[0],
            actor,
            critic,
            critic_action_input,
            memory
        )
        return agent

    a = agent((3,), env.observation_space.shape)
    a.compile(Adam(lr=0.001, clipnorm=1.), metrics=["mae"])
    a.fit(env, lam=l, nb_steps=50000, visualize=1, verbose=1, nb_max_episode_steps=200)
    a.save_weights(f'learned_models/normal{l}.h5')
# Out:
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 152s 15ms/step - reward: -7.6021
# 50 episodes - episode_reward: -1520.418 [-1848.082, -926.173] - loss: 3.034 - mean_absolute_error: 0.515 - mean_q: -32.362
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -6.1389
# 50 episodes - episode_reward: -1227.779 [-1853.759, -752.904] - loss: 19.983 - mean_absolute_error: 1.015 - mean_q: -85.907
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 168s 17ms/step - reward: -4.3081
# 50 episodes - episode_reward: -861.618 [-1656.482, -226.366] - loss: 39.277 - mean_absolute_error: 1.756 - mean_q: -112.669
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 167s 17ms/step - reward: -3
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 140s 14ms/step - reward: -5.4404
# done, took 624.828 seconds
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 170s 17ms/step - reward: -6.8628
# 50 episodes - episode_reward: -1372.568 [-1827.537, -954.353] - loss: 2.521 - mean_absolute_error: 0.707 - mean_q: -29.889
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -6.6865
# 50 episodes - episode_reward: -1337.309 [-1741.633, -768.716] - loss: 14.999 - mean_absolute_error: 1.117 - mean_q: -78.690
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 123s 12ms/step - reward: -5.8406
# 50 episodes - episode_reward: -1168.113 [-1659.201, -770.333] - loss: 39.343 - mean_absolute_error: 1.923 - mean_q: -118.606
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 124s 12ms/step - reward: -5.5608
# 50 episodes - episode_reward: -1112.152 [-1788.749, -612.351] - loss: 57.550 - mean_absolute_error: 2.469 - mean_q: -142.914
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -4.6330
# done, took 651.197 seconds

# %%
agent.fit(env, lam=l, nb_steps=150000, visualize=0, verbose=1, nb_max_episode_steps=200, loss_graph=1)
# Out:
# Training for 150000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -1.5935
# 50 episodes - episode_reward: -318.692 [-727.146, -1.055] - loss: 30.884 - mean_squared_error: 61.767 - mean_q: -66.899
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -1.6722
# 50 episodes - episode_reward: -334.447 [-644.433, -0.792] - loss: 22.827 - mean_squared_error: 45.653 - mean_q: -39.455
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.0309
# 50 episodes - episode_reward: -406.185 [-1731.487, -0.861] - loss: 20.777 - mean_squared_error: 41.554 - mean_q: -27.843
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.3320
# 50 episodes - episode_reward: -466.399 [-1734.120, -1.240] - loss: 19.490 - mean_squared_error: 38.980 - mean_q: -20.356
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -2.4213
# 50 episodes - episode_reward: -484.259 [-1214.853, -2.351] - loss: 17.543 - mean_squared_error: 35.086 - mean_q: -18.006
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 74s 7ms/step - reward: -2.9297
# 50 episodes - episode_reward: -585.942 [-1327.066, -1.363] - loss: 18.398 - mean_squared_error: 36.797 - mean_q: -18.254
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -2.7039
# 50 episodes - episode_reward: -540.785 [-1430.529, -2.663] - loss: 13.138 - mean_squared_error: 26.276 - mean_q: -17.249
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 57s 6ms/step - reward: -3.5461
# 50 episodes - episode_reward: -709.227 [-1706.684, -1.296] - loss: 14.086 - mean_squared_error: 28.172 - mean_q: -21.296
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 676s 68ms/step - reward: -2.7057
# 50 episodes - episode_reward: -541.134 [-1457.064, -0.427] - loss: 14.624 - mean_squared_error: 29.247 - mean_q: -25.297
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 70s 7ms/step - reward: -3.0200
# 50 episodes - episode_reward: -603.997 [-1735.811, -1.230] - loss: 15.225 - mean_squared_error: 30.451 - mean_q: -26.373
#
# Interval 11 (100000 steps performed)
#  1046/10000 [==>...........................] - ETA: 1:13 - reward: -2.4960done, took 664.227 seconds

# %%
agent.test(env, lam=l, nb_episodes=5, visualize=0, nb_max_episode_steps=200, graph=True,action_view=0)
# Out:
# Testing for 5 episodes ...
# Episode 1: reward: -392.520, steps: 200
# Episode 2: reward: -400.598, steps: 200
# Episode 3: reward: -25.208, steps: 200
# Episode 4: reward: -505.319, steps: 200
# Episode 5: reward: -1006.071, steps: 200

# %%
np.clip(2,-1,1)
# Out:
# 1
